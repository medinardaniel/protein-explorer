# %% [markdown]
# # Train Mondo Annotations

# %%
from transformers import AutoTokenizer, AutoModel
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import numpy as np
import torch.optim as optim
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from fetch import *
import pandas as pd

# %% [markdown]
# ## Load model and tokenizer

# %%
def split_data(embeddings, labels):
    # Split data into 80% training and 20% test
    embeddings_train, embeddings_temp, labels_train, labels_temp = train_test_split(
        embeddings, labels, test_size=0.20, random_state=42)

    # Split the 20% test into 15% validation and 5% test
    embeddings_val, embeddings_test, labels_val, labels_test = train_test_split(
        embeddings_temp, labels_temp, test_size=0.25, random_state=42)  # 0.25 * 0.20 = 0.05

    return embeddings_train, labels_train, embeddings_val, labels_val, embeddings_test, labels_test

# %% [markdown]
# ## Prepare dataset

# %%
class ProteinDataset(Dataset):
    def __init__(self, embeddings, labels):
        self.embeddings = embeddings
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.embeddings[idx], self.labels[idx]

# %% [markdown]
# ## Create a classifier

# %%
class ProteinTaggingModel(nn.Module):
    def __init__(self, embedding_size, num_labels, dropout_rate=0.1):
        super(ProteinTaggingModel, self).__init__()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc1 = nn.Linear(embedding_size, embedding_size)  # Adjust this to your combined embedding size
        self.relu = nn.ReLU()
        self.norm1 = nn.LayerNorm(embedding_size)
        self.fc2 = nn.Linear(embedding_size, embedding_size)
        self.norm2 = nn.LayerNorm(embedding_size)
        self.classifier = nn.Linear(embedding_size, num_labels)
        self.output_fc = nn.Linear(num_labels, num_labels)
        self.sigmoid = nn.Sigmoid()

    def forward(self, embeddings):
        x = self.dropout(embeddings)
        x = self.relu(self.fc1(x))
        x = self.norm1(x + embeddings)  # Ensure `embeddings` is broadcastable with `x`
        x = self.relu(self.fc2(x))
        x = self.norm2(x + embeddings)  # Ensure `embeddings` is broadcastable with `x`
        logits = self.classifier(x)
        logits = self.output_fc(logits)
        predictions = self.sigmoid(logits)
        return predictions

# %% [markdown]
# ## Train model

# %%
# load dataset
embedding_types = ['func_embedding']
combine_method = 'concat'
embeddings, labels, annotations_vocab = fetch_data_multi(embedding_types, combine_method, include_empty=True)

# split data
embeddings_train, labels_train, embeddings_val, labels_val, embeddings_test, labels_test = split_data(embeddings, labels)

# dataloaders
train_dataset = ProteinDataset(embeddings_train, labels_train)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

val_dataset = ProteinDataset(embeddings_val, labels_val)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

# %%
# Setup DataLoader, Model, Loss, and Optimizer
dataset = ProteinDataset(embeddings, labels)

model = ProteinTaggingModel(embedding_size=embeddings.shape[1], num_labels=labels.shape[1])

criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

def train_and_validate(model, train_loader, val_loader, criterion, optimizer, epochs):
    for epoch in range(epochs):
        model.train()
        total_train_loss = 0
        for embeddings, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(embeddings)
            loss = criterion(outputs, labels.float())
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

        model.eval()
        total_val_loss = 0
        with torch.no_grad():
            for embeddings, labels in val_loader:
                outputs = model(embeddings)
                loss = criterion(outputs, labels.float())
                total_val_loss += loss.item()

        print(f'Epoch {epoch+1}, Training Loss: {total_train_loss / len(train_loader)}, Validation Loss: {total_val_loss / len(val_loader)}')

# %%
# Start training
train_and_validate(model, train_loader, val_loader, criterion, optimizer, epochs=60)
# Out:
# Epoch 1, Training Loss: 0.01277017981608616, Validation Loss: 0.007581576297910798
# Epoch 2, Training Loss: 0.00575825486700537, Validation Loss: 0.0050104453863687075
# Epoch 39, Training Loss: 0.0014533422003640325, Validation Loss: 0.002908267678279701
# Epoch 40, Training Loss: 0.001572477472430577, Validation Loss: 0.0026370955516263495
# Epoch 41, Training Loss: 0.001431360675586128, Validation Loss: 0.0026893147800521717
# Epoch 42, Training Loss: 0.0014415085804931047, Validation Loss: 0.0026103532418226267
# Epoch 43, Training Loss: 0.001399732671796219, Validation Loss: 0.0027286632584765653
# Epoch 44, Training Loss: 0.0014153246898351778, Validation Loss: 0.002758402836860608
# Epoch 45, Training Loss: 0.0014684772538397675, Validation Loss: 0.002770676580566099
# Epoch 46, Training Loss: 0.001407406733177871, Validation Loss: 0.002729920679448937
# Epoch 47, Training Loss: 0.001411547051302206, Validation Loss: 0.0027618505290419554
# Epoch 48, Training Loss: 0.0013997543185664948, Validation Loss: 0.0028546324839340584
# Epoch 49, Training Loss: 0.0014115258409083931, Validation Loss: 0.0028383543908392507
# Epoch 50, Training Loss: 0.0013765888944901271, Validation Loss: 0.002806968242045652
# Epoch 51, Training Loss: 0.0013932182784574523, Validation Loss: 0.0028555512885849875
# Epoch 52, Training Loss: 0.0013926998157629312, Validation Loss: 0.0028252734389042
# Epoch 53, Training Loss: 0.0013944562598040666, Validation Loss: 0.0029362199125681936
# Epoch 54, Training Loss: 0.0013710654260902272, Validation Loss: 0.0028419437055361907
# Epoch 55, Training Loss: 0.0013661819210942644, Validation Loss: 0.0028535302461276065
# Epoch 56, Training Loss: 0.0013773638012790613, Validation Loss: 0.0028376873855907717
# Epoch 57, Training Loss: 0.001375014910796444, Validation Loss: 0.002838953386603651
# Epoch 58, Training Loss: 0.001353291462750964, Validation Loss: 0.002887330996720675
# Epoch 59, Training Loss: 0.0014349775513288314, Validation Loss: 0.0027870637347724363
# Epoch 60, Training Loss: 0.0013432545011570047, Validation Loss: 0.0028482371270857035

# %% [markdown]
# ## Evaluation

# %%
def evaluate_model(model, test_loader):
    model.eval()
    predictions = []
    truths = []
    with torch.no_grad():
        for embeddings, labels in test_loader:
            outputs = model(embeddings)
            predicted = torch.round(outputs)
            predictions.extend(predicted.cpu().numpy())
            truths.extend(labels.cpu().numpy())

    accuracy = accuracy_score(truths, predictions)
    precision = precision_score(truths, predictions, average='macro', zero_division=1)
    recall = recall_score(truths, predictions, average='macro', zero_division=1)
    f1 = f1_score(truths, predictions, average='macro', zero_division=1)

    return accuracy, precision, recall, f1

test_dataset = ProteinDataset(embeddings_test, labels_test)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
accuracy, precision, recall, f1 = evaluate_model(model, test_loader)
print(f'Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1 Score: {f1}')
# Out:
# Accuracy: 0.7270463741051977, Precision: 0.9840962258118077, Recall: 0.9629705100511545, F1 Score: 0.9579605931359665

# %% [markdown]
# ## Inference

# %%
def create_reverse_vocab(annotations_vocab):
    return {idx: label for label, idx in annotations_vocab.items()}

def convert_to_labels(binary_vector, reverse_vocab):
    labels = [reverse_vocab[i] for i, value in enumerate(binary_vector) if value == 1]
    return labels

def intersection_and_difference(true_labels, predicted_labels):
    # Calculate intersection and differences of two label lists
    true_set = set(true_labels)
    predicted_set = set(predicted_labels)
    intersection = true_set & predicted_set
    incorrect = predicted_set - true_set
    return len(intersection), len(true_set), len(predicted_set), len(incorrect)

import torch

def predict_and_evaluate(model, test_loader, annotations_vocab, num_samples=10):
    model.eval()
    total_intersection = 0
    total_true_labels = 0
    total_predicted_labels = 0
    total_incorrect = 0
    num_zero_prediction = 0  # To track samples with zero predicted labels
    sample_data = []
    reverse_vocab = create_reverse_vocab(annotations_vocab)

    with torch.no_grad():
        for embeddings, labels in test_loader:
            outputs = model(embeddings)
            predicted = torch.round(outputs)  # Using 0.5 as a threshold
            # Convert binary vectors to MONDO names
            predicted_labels = [convert_to_labels(pred, reverse_vocab) for pred in predicted.cpu().numpy()]
            true_labels = [convert_to_labels(true, reverse_vocab) for true in labels.cpu().numpy()]
            
            for true, pred in zip(true_labels, predicted_labels):
                inter, true_count, pred_count, incorrect = intersection_and_difference(true, pred)
                total_intersection += inter
                total_true_labels += true_count
                total_predicted_labels += pred_count
                total_incorrect += incorrect
                if len(pred) == 0:
                    num_zero_prediction += 1  # Increment if no labels were predicted
            
            # Collect samples for display
            if len(sample_data) < num_samples:
                sample_data.extend(zip(embeddings, true_labels, predicted_labels))
            if len(sample_data) >= num_samples:
                break
    
    # Calculate averages
    num_samples = len(test_loader.dataset)
    average_correct = (total_intersection / num_samples) * 100
    average_incorrect = (total_incorrect / num_samples) * 100
    print(f"Average percentage of correct MONDO names per sample: {average_correct:.2f}%")
    print(f"Average percentage of incorrect MONDO names per sample: {average_incorrect:.2f}%")
    print(f"Number of samples with zero predicted labels: {num_zero_prediction}")

    return sample_data, num_zero_prediction

# Example usage assuming model, test_loader, and annotations_vocab are defined
sample_data, num_zero_prediction = predict_and_evaluate(model, test_loader, annotations_vocab, num_samples=10)

# Print the samples and the total number of zero predicted labels
for idx, (embedding, true_label, predicted_label) in enumerate(sample_data):
    print(f"Sample {idx+1}")
    print(f"True MONDO Names: {true_label}")
    print(f"Predicted MONDO Names: {predicted_label}\n")
print(f"Total samples with zero predictions: {num_zero_prediction}")
# Out:
# Average percentage of correct MONDO names per sample: 44.76%
# Average percentage of incorrect MONDO names per sample: 1.56%
# Number of samples with zero predicted labels: 9
# Sample 1
# True MONDO Names: []
# Predicted MONDO Names: ['large cell medulloblastoma', 'malignant ependymoma', 'atypical teratoid rhabdoid tumor', 'medulloblastoma', 'tuberculosis', 'glioblastoma', 'lung adenocarcinoma']
#
# Sample 2
# True MONDO Names: ['osteosarcoma', 'ovarian cancer']
# Predicted MONDO Names: ['osteosarcoma', 'ovarian cancer']
#
# Sample 3
# True MONDO Names: ['classic maple syrup urine disease', 'inherited organic acidemia', 'intermediate maple syrup urine disease', 'maple syrup urine disease', 'prostate carcinoma', 'colorectal cancer', 'myocardial infarction', 'intermittent maple syrup urine disease', 'osteoarthritis', 'inborn errors of metabolism', 'intellectual disability', 'heart disease']
# Predicted MONDO Names: ['classic maple syrup urine disease', 'inherited organic acidemia', 'intermediate maple syrup urine disease', 'maple syrup urine disease', 'prostate carcinoma', 'colorectal cancer', 'myocardial infarction', 'intermittent maple syrup urine disease', 'osteoarthritis', 'inborn errors of metabolism', 'intellectual disability', 'heart disease']
#
# Sample 4
# True MONDO Names: ['peripheral nervous system disease', 'attention deficit hyperactivity disorder, inattentive type', 'lymphoplasmacytic lymphoma', 'peripheral neuropathy', 'malignant pancreatic neoplasm', 'gastric carcinoma', 'exocrine pancreatic carcinoma', 'tuberculosis', 'ovarian cancer', 'gastric cancer', 'hepatocellular carcinoma']
# Predicted MONDO Names: ['lymphoplasmacytic lymphoma', 'peripheral neuropathy', 'gastric carcinoma', 'exocrine pancreatic carcinoma', 'ovarian cancer']
#
# Sample 5
# True MONDO Names: ['large cell medulloblastoma', 'malignant ependymoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'esophageal adenocarcinoma', 'nephrosclerosis', 'breast carcinoma', 'atypical teratoid rhabdoid tumor', 'medulloblastoma', 'breast cancer', 'pituitary cancer', 'glioblastoma', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'oligodendroglioma', 'astrocytic tumor', 'primitive neuroectodermal tumor', 'cystic fibrosis']
# Predicted MONDO Names: ['large cell medulloblastoma', 'malignant ependymoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'esophageal adenocarcinoma', 'nephrosclerosis', 'breast carcinoma', 'atypical teratoid rhabdoid tumor', 'medulloblastoma', 'breast cancer', 'pituitary cancer', 'glioblastoma', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'oligodendroglioma', 'astrocytic tumor', 'primitive neuroectodermal tumor', 'cystic fibrosis']
#
# Sample 6
# True MONDO Names: ['leukodystrophy', 'hydrops fetalis', 'hemangioma', 'lysosomal storage disease', 'Fabry disease', 'sphingolipidosis', 'angiokeratoma', 'dilated cardiomyopathy', 'medulloblastoma', 'breast fibroadenoma', 'malignant colon neoplasm', 'Charcot-Marie-Tooth disease', 'cerebrovascular disorder', 'ovarian cancer', 'glioblastoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'inborn errors of metabolism', 'subependymal giant cell astrocytoma', 'hypertrophic cardiomyopathy']
# Predicted MONDO Names: ['leukodystrophy', 'hydrops fetalis', 'hemangioma', 'lysosomal storage disease', 'Fabry disease', 'sphingolipidosis', 'angiokeratoma', 'dilated cardiomyopathy', 'medulloblastoma', 'breast fibroadenoma', 'malignant colon neoplasm', 'Charcot-Marie-Tooth disease', 'cerebrovascular disorder', 'ovarian cancer', 'glioblastoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'inborn errors of metabolism', 'subependymal giant cell astrocytoma', 'hypertrophic cardiomyopathy']
#
# Sample 7
# True MONDO Names: ['childhood acute lymphoblastic leukemia', 'Duchenne muscular dystrophy', 'osteosarcoma', 'chronic kidney disease', 'melancholia', 'malignant pancreatic neoplasm', 'pancreatic ductal adenocarcinoma', 'plasma cell myeloma', 'leukemia, acute lymphocytic, susceptibility to, 1', 'juvenile dermatomyositis', 'medulloblastoma', 'breast cancer', 'swine influenza', 'endogenous depression', 'anxiety disorder', 'ovarian cancer', 'myopathy', 'rheumatoid arthritis', 'neurotic disorder', 'intellectual disability, autosomal dominant 42', 'subependymal giant cell astrocytoma', 'depressive disorder', 'intellectual disability', 'lung adenocarcinoma', 'myelodysplastic syndrome', 'Sjogren syndrome']
# Predicted MONDO Names: ['childhood acute lymphoblastic leukemia', 'Duchenne muscular dystrophy', 'osteosarcoma', 'chronic kidney disease', 'melancholia', 'malignant pancreatic neoplasm', 'pancreatic ductal adenocarcinoma', 'plasma cell myeloma', 'leukemia, acute lymphocytic, susceptibility to, 1', 'juvenile dermatomyositis', 'medulloblastoma', 'swine influenza', 'endogenous depression', 'anxiety disorder', 'ovarian cancer', 'myopathy', 'rheumatoid arthritis', 'neurotic disorder', 'intellectual disability, autosomal dominant 42', 'subependymal giant cell astrocytoma', 'depressive disorder', 'lung adenocarcinoma', 'myelodysplastic syndrome', 'Sjogren syndrome']
#
# Sample 8
# True MONDO Names: ['malignant ependymoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'psoriasis', 'osteosarcoma', 'pilocytic astrocytoma', 'lung cancer', 'ovarian cancer', 'spondyloarthropathy', 'glioblastoma', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'subependymal giant cell astrocytoma', 'malignant mesothelioma']
# Predicted MONDO Names: ['malignant ependymoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'psoriasis', 'osteosarcoma', 'pilocytic astrocytoma', 'lung cancer', 'ovarian cancer', 'spondyloarthropathy', 'glioblastoma', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'subependymal giant cell astrocytoma', 'malignant mesothelioma']
#
# Sample 9
# True MONDO Names: []
# Predicted MONDO Names: []
#
# Sample 10
# True MONDO Names: ['peripheral arterial disease', 'malaria', 'allergic rhinitis', 'gastric carcinoma', 'exocrine pancreatic carcinoma', 'Graves disease', 'myocardial infarction', 'duodenal ulcer', 'idiopathic scoliosis', 'heart disease']
# Predicted MONDO Names: []
#
# Sample 11
# True MONDO Names: ['large cell medulloblastoma', 'malignant ependymoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'ductal breast carcinoma in situ', 'psoriasis', 'esophageal adenocarcinoma', 'nasopharyngeal carcinoma', 'malignant pancreatic neoplasm', 'IgA glomerulonephritis', 'breast carcinoma', 'adrenal cortex carcinoma', 'atypical teratoid rhabdoid tumor', 'pilocytic astrocytoma', 'medulloblastoma', 'interstitial lung disease', 'breast cancer', 'malignant colon neoplasm', 'lung cancer', 'endometriosis', 'non-small cell lung carcinoma', 'ovarian cancer', 'glioblastoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'invasive ductal breast carcinoma', 'malignant glioma', 'atopic eczema', 'hepatocellular carcinoma', 'primitive neuroectodermal tumor', 'lung adenocarcinoma', 'idiopathic pulmonary fibrosis', 'polycystic ovary syndrome', 'Sjogren syndrome', 'malignant mesothelioma']
# Predicted MONDO Names: ['large cell medulloblastoma', 'malignant ependymoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'ductal breast carcinoma in situ', 'psoriasis', 'esophageal adenocarcinoma', 'nasopharyngeal carcinoma', 'malignant pancreatic neoplasm', 'IgA glomerulonephritis', 'breast carcinoma', 'adrenal cortex carcinoma', 'atypical teratoid rhabdoid tumor', 'pilocytic astrocytoma', 'medulloblastoma', 'interstitial lung disease', 'breast cancer', 'malignant colon neoplasm', 'lung cancer', 'endometriosis', 'non-small cell lung carcinoma', 'ovarian cancer', 'glioblastoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'invasive ductal breast carcinoma', 'malignant glioma', 'atopic eczema', 'hepatocellular carcinoma', 'primitive neuroectodermal tumor', 'lung adenocarcinoma', 'idiopathic pulmonary fibrosis', 'polycystic ovary syndrome', 'Sjogren syndrome', 'malignant mesothelioma']
#
# Sample 12
# True MONDO Names: ['pancreatic intraductal papillary-mucinous carcinoma', 'mature T-cell and NK-cell non-Hodgkin lymphoma', 'diffuse large B-cell lymphoma', 'psoriasis', 'lymphoplasmacytic lymphoma', 'osteosarcoma', 'acquired metabolic disease', 'familial visceral amyloidosis', 'kidney disease', 'amyloidosis', 'schizophrenia', 'pilocytic astrocytoma', 'juvenile dermatomyositis', 'esophageal squamous cell carcinoma', 'Down syndrome', 'cancer', 'interstitial cystitis', 'lung cancer', 'autoimmune disease', 'periodic fever syndrome', 'ovarian cancer', 'lung carcinoma', 'glioblastoma', 'lymphatic system disease', 'pancreatic intraductal papillary-mucinous neoplasm', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 
ONDO Names: ['large cell medulloblastoma', 'malignant ependymoma', 'atrial fibrillation, familial, 1', 'Pick disease', 'atrial fibrillation, familial, 14', 'atypical teratoid rhabdoid tumor', 'pilocytic astrocytoma', 'medulloblastoma', 'atrial fibrillation', 'breast cancer', 'pituitary cancer', 'non-small cell lung carcinoma', 'lung carcinoma', 'glioblastoma', 'oligodendroglioma', 'malignant glioma', 'astrocytic tumor', 'Brugada syndrome', 'primitive neuroectodermal tumor', 'subependymal giant cell astrocytoma', 'lung adenocarcinoma', 'familial atrial fibrillation']
#
# Sample 17
# True MONDO Names: ['psoriasis', 'osteosarcoma', 'pancreatic ductal adenocarcinoma', 'plasma cell myeloma', 'atypical teratoid rhabdoid tumor', 'Parkinson disease', 'contact dermatitis', 'Stankiewicz-Isidor syndrome', 'lung cancer', 'non-small cell lung carcinoma', 'ovarian cancer', 'invasive ductal breast carcinoma', 'intellectual disability']
# Predicted MONDO Names: ['psoriasis', 'plasma cell myeloma', 'ovarian cancer', 'HIV infectious disease']
#
# Sample 18
# True MONDO Names: ['congenital anemia', 'diabetes mellitus', 'MALT lymphoma']
# Predicted MONDO Names: []
#
# Sample 19
# True MONDO Names: ['large cell medulloblastoma', 'malignant mesothelioma']
# Predicted MONDO Names: ['large cell medulloblastoma', 'malignant mesothelioma']
#
# Sample 20
# True MONDO Names: ['glycogen storage disease', 'diabetes mellitus', 'attention deficit hyperactivity disorder, inattentive type', 'glycogen storage disease due to lactate dehydrogenase M-subunit deficiency', 'cancer', 'myoglobinuria', 'rhabdomyolysis', 'cardiomyopathy', 'myocardial infarction', 'bipolar disorder', 'inborn errors of metabolism', 'major depressive disorder', 'lung adenocarcinoma']
# Predicted MONDO Names: ['glycogen storage disease', 'diabetes mellitus', 'attention deficit hyperactivity disorder, inattentive type', 'glycogen storage disease due to lactate dehydrogenase M-subunit deficiency', 'cancer', 'myoglobinuria', 'rhabdomyolysis', 'cardiomyopathy', 'myocardial infarction', 'bipolar disorder', 'inborn errors of metabolism', 'major depressive disorder', 'lung adenocarcinoma']
#
# Sample 21
# True MONDO Names: ['gemistocytic astrocytoma', 'large cell medulloblastoma', 'malignant ependymoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'coronary artery disease', 'astrocytoma (excluding glioblastoma)', 'thrombotic disease', 'pancreatitis', 'osteosarcoma', 'acute myeloid leukemia', 'acute liver failure', 'keratoconus', 'liver disease', 'anaplastic astrocytoma', 'childhood cerebral astrocytoma', 'vascular disease', 'nonsyndromic genetic deafness', 'protoplasmic astrocytoma', 'adrenal cortex carcinoma', 'ischemia reperfusion injury', 'gastric carcinoma', 'plasma cell myeloma', 'Parkinson disease', 'pilocytic astrocytoma', 'liver cancer', 'medulloblastoma', 'fibrillary astrocytoma', 'cirrhosis of liver', 'cancer', 'breast cancer', 'interstitial cystitis', 'autosomal recessive nonsyndromic deafness 39', 'Barrett esophagus', 'diabetic neuropathy', 'juvenile pilocytic astrocytoma', 'lung cancer', 'cardiomyopathy', 'polyomavirus infectious disease', 'tuberculosis', 'MALT lymphoma', 'liver neoplasm', 'squamous cell carcinoma', 'non-small cell lung carcinoma', 'ovarian cancer', 'pancreatic intraductal papillary-mucinous neoplasm', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 
 'pancreatic intraductal papillary-mucinous neoplasm', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'MHC class I deficiency', 'rheumatoid arthritis', 'acute kidney failure', 'hypoproteinemia, hypercatabolic', 'subependymal giant cell astrocytoma', 'ulcerative colitis', 'variant ABeta2M amyloidosis', 'lung adenocarcinoma', 'bone marrow disease', 'Sjogren syndrome', 'prostate cancer', 'heart disease']
# Predicted MONDO Names: ['pancreatic intraductal papillary-mucinous carcinoma', 'mature T-cell and NK-cell non-Hodgkin lymphoma', 'diffuse large B-cell lymphoma', 'psoriasis', 'lymphoplasmacytic lymphoma', 'osteosarcoma', 'acquired metabolic disease', 'familial visceral amyloidosis', 'kidney disease', 'amyloidosis', 'schizophrenia', 'pilocytic astrocytoma', 'juvenile dermatomyositis', 'esophageal squamous cell carcinoma', 'Down syndrome', 'cancer', 'interstitial cystitis', 'lung cancer', 'autoimmune disease', 'periodic fever syndrome', 'ovarian cancer', 'lung carcinoma', 'glioblastoma', 'lymphatic system disease', 'pancreatic intraductal papillary-mucinous neoplasm', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'MHC class I deficiency', 'rheumatoid arthritis', 'acute kidney failure', 'hypoproteinemia, hypercatabolic', 'subependymal giant cell astrocytoma', 'ulcerative colitis', 'variant ABeta2M amyloidosis', 'lung adenocarcinoma', 'bone marrow disease', 'Sjogren syndrome', 'prostate cancer', 'heart disease']
#
# Sample 23
# True MONDO Names: ['malignant ependymoma', 'esophageal adenocarcinoma', 'myoclonus, familial', 'atypical teratoid rhabdoid tumor', 'myoclonus, familial, 1', 'cutaneous lupus erythematosus', 'inborn mitochondrial metabolism disorder', 'astrocytic tumor', 'subependymal giant cell astrocytoma', 'Sjogren syndrome']
# Predicted MONDO Names: ['atrial fibrillation', 'systemic sclerosis']
#
# Sample 24
# True MONDO Names: ['peripheral nervous system disease', 'large cell medulloblastoma', 'psoriasis', 'peripheral neuropathy', 'hereditary sensory and autonomic neuropathy with spastic paraplegia', 'IgA glomerulonephritis', 'breast carcinoma', 'medulloblastoma', 'breast cancer', 'lung cancer', 'Charcot-Marie-Tooth disease', 'non-small cell lung carcinoma', 'ovarian cancer', 'pancreatic intraductal papillary-mucinous neoplasm', 'invasive ductal breast carcinoma', 'drug-induced liver injury', 'HIV infectious disease', 'intellectual disability', 'lung adenocarcinoma']
# Predicted MONDO Names: ['psoriasis', 'lymphoplasmacytic lymphoma', 'plasma cell myeloma', 'lung cancer', 'non-small cell lung carcinoma', 'ovarian cancer', 'dermatomyositis', 'HIV infectious disease', 'lung adenocarcinoma']
#
# Sample 25
# True MONDO Names: ['large cell medulloblastoma', 'cutaneous melanoma', 'malignant ependymoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'ductal breast carcinoma in situ', 'coronary artery disease', 'melanoma', 'psoriasis', 'heart failure', 'diabetes mellitus', 'esophageal adenocarcinoma', 'adenocarcinoma', 'atherosclerosis', 'osteosarcoma', 'maturity-onset diabetes of the young', 'acquired metabolic disease', 'liver disease', 'inborn carbohydrate metabolic disorder', "Crohn's colitis", 'malignant pancreatic neoplasm', 'Alzheimer disease', 'lipoatrophic diabetes', 'glomerulonephritis', 'obesity disorder', 'diabetic kidney disease', 'osteoarthritis susceptibility 1', 'kidney disease', 'cribriform carcinoma of breast', 'breast carcinoma', 'ischemia reperfusion injury', 'Hashimoto thyroiditis', 'thyroid gland carcinoma', 'schizophrenia', 'pustulosis palmaris et plantaris', 'glioma susceptibility 1', 'gliosarcoma', 'liver cancer', 'medulloblastoma', 'lipodystrophy', 'antiphospholipid
#
# Sample 34
# True MONDO Names: ['malignant ependymoma', 'Duchenne muscular dystrophy', 'Emery-Dreifuss muscular dystrophy', 'osteosarcoma', 'acute myeloid leukemia', 'malignant pancreatic neoplasm', 'pancreatic ductal adenocarcinoma', 'amyotrophic lateral sclerosis', 'juvenile dermatomyositis', 'medulloblastoma', 'sinusitis', 'Becker muscular dystrophy', 'limb-girdle muscular dystrophy', 'ovarian cancer', 'myopathy', 'glioblastoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'cystic fibrosis']
# Predicted MONDO Names: ['malignant ependymoma', 'Duchenne muscular dystrophy', 'Emery-Dreifuss muscular dystrophy', 'osteosarcoma', 'acute myeloid leukemia', 'malignant pancreatic neoplasm', 'pancreatic ductal adenocarcinoma', 'amyotrophic lateral sclerosis', 'juvenile dermatomyositis', 'medulloblastoma', 'sinusitis', 'Becker muscular dystrophy', 'limb-girdle muscular dystrophy', 'ovarian cancer', 'myopathy', 'glioblastoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'cystic fibrosis']
#
# Sample 35
# True MONDO Names: ['MELAS syndrome', 'Turner syndrome', 'anterior horn disease', 'heart failure', 'diabetes mellitus', 'atherosclerosis', 'lymphoplasmacytic lymphoma', 'maturity-onset diabetes of the young', 'hyperthyroidism', 'liver disease', 'nervous system disorder', 'muscular atrophy', 'intestinal schistosomiasis', 'melancholia', 'pancreatic ductal adenocarcinoma', 'amyotrophic lateral sclerosis', 'obesity disorder', 'ischemia reperfusion injury', 'dementia', 'schizophrenia', 'plasma cell myeloma', 'Parkinson disease', 'amyotrophic lateral sclerosis type 1', 'asthma', 'alcoholic fatty liver disease', 'arteriosclerosis disorder', 'Down syndrome', 'contact dermatitis', 'ischemic disease', 'iron deficiency anemia', 'transient ischemic attack', 'proteinuria', 'type 2 diabetes mellitus', 'myelomeningocele', 'retinal degeneration', 'motor neuron disease', 'Marfan syndrome', 'fetal growth restriction', 'brain ischemia', 'endogenous depression', 'cerebrovascular disorder', 'ovarian cancer', 'mixed glioma', 'hearing loss disorder', 'aortic disease', 'nutritional deficiency disease', 'ovarian neoplasm', 'spinal cord injury', 'hepatitis', 'progressive external ophthalmoplegia', 'acute kidney failure', 'neurodegenerative disease', 'myocardial infarction', 'drug-induced liver injury', 'malignant glioma', 'glioma', 'neurotic disorder', 'pulmonary fibrosis', 'bipolar disorder', 'congestive heart failure', 'hypertensive disorder', 'depressive disorder', 'nephrosis', 'hypotensive disorder', 'primary ovarian failure', 'idiopathic interstitial pneumonia', 'scrapie', 'perinatal asphyxia', 'diabetic retinopathy', 'fatty liver disease', 'lateral sclerosis', 'juvenile primary lateral sclerosis']
# Predicted MONDO Names: ['MELAS syndrome', 'Turner syndrome', 'anterior horn disease', 'heart failure', 'diabetes mellitus', 'atherosclerosis', 'lymphoplasmacytic lymphoma', 'maturity-onset diabetes of the young', 'hyperthyroidism', 'liver disease', 'nervous system disorder', 'muscular atrophy', 'intestinal schistosomiasis', 'melancholia', 'pancreatic ductal adenocarcinoma', 'amyotrophic lateral sclerosis', 'obesity disorder', 'ischemia reperfusion injury', 'dementia', 'schizophrenia', 'plasma cell myeloma', 'Parkinson disease', 'amyotrophic lateral sclerosis type 1', 'asthma', 'alcoholic fatty liver disease', 'arteriosclerosis disorder', 'Down syndrome', 'contact dermatitis', 'ischemic disease', 'iron deficiency anemia', 'transient ischemic attack', 'proteinuria', 'type 2 diabetes mellitus', 'myelomeningocele', 'retinal degeneration', 'motor neuron disease', 'Marfan syndrome', 'fetal growth restriction', 'brain ischemia', 'endogenous depression', 'cerebrovascular disorder', 'ovarian cancer', 'mixed glioma', 'hearing loss disorder', 'aortic disease', 'nutritional deficiency disease', 'ovarian neoplasm', 'spinal cord injury', 'hepatitis', 'progressive external ophthalmoplegia', 'acute kidney failure', 'neurodegenerative disease', 'myocardial infarction', 'drug-induced liver injury', 'malignant glioma', 'glioma', 'neurotic disorder', 'pulmonary fibrosis', 'bipolar disorder', 'congestive heart failure', 'hypertensive disorder', 'depressive disorder', 'nephrosis', 'hypotensive disorder', 'primary ovarian failure', 'idiopathic interstitial pneumonia', 'scrapie', 'perinatal asphyxia', 'diabetic retinopathy', 'fatty liver disease', 'lateral sclerosis', 'juvenile primary lateral sclerosis']
#
# Sample 36
# ...
#
# Sample 46
# True MONDO Names: ['large cell medulloblastoma', 'diabetes mellitus', 'acute myeloid leukemia', 'atypical teratoid rhabdoid tumor', 'medulloblastoma', 'breast cancer', 'lung cancer', 'MALT lymphoma', 'ovarian cancer', 'pancreatic intraductal papillary-mucinous neoplasm', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia']
# Predicted MONDO Names: ['diabetes mellitus', 'breast cancer', 'lung cancer', 'ovarian cancer']
#
# Sample 47
# True MONDO Names: ['diabetes mellitus', 'acute myeloid leukemia', 'plasma cell myeloma', 'malignant colon neoplasm', 'MALT lymphoma', 'ovarian cancer', 'myopathy', 'pancreatic intraductal papillary-mucinous neoplasm', 'osteoarthritis']
# Predicted MONDO Names: []
#
# Sample 48
# True MONDO Names: ['opiate dependence', 'coronary artery disease', 'myocardial ischemia']
# Predicted MONDO Names: []
#
# Sample 49
# True MONDO Names: ['malignant ependymoma', 'psoriasis', 'allergic rhinitis', 'osteosarcoma', 'gastric carcinoma', 'ovarian cancer', 'gastric cancer', 'glioblastoma', 'invasive ductal breast carcinoma', 'hepatocellular carcinoma', 'progressive supranuclear palsy', 'malignant mesothelioma']
# Predicted MONDO Names: ['malignant ependymoma', 'psoriasis', 'allergic rhinitis', 'osteosarcoma', 'gastric carcinoma', 'ovarian cancer', 'gastric cancer', 'glioblastoma', 'invasive ductal breast carcinoma', 'hepatocellular carcinoma', 'progressive supranuclear palsy', 'malignant mesothelioma']
#
# Sample 50
# True MONDO Names: ['diabetes mellitus', 'acute myeloid leukemia', 'plasma cell myeloma', 'malignant colon neoplasm', 'MALT lymphoma', 'ovarian cancer', 'myopathy', 'pancreatic intraductal papillary-mucinous neoplasm', 'osteoarthritis']
# Predicted MONDO Names: []
#
# Sample 51
cinoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'tubular adenocarcinoma', 'angle-closure glaucoma', 'granular cell carcinoma', 'hepatocellular carcinoma', 'osteopetrosis', 'ulcerative colitis', 'cystic fibrosis', 'hereditary diffuse gastric adenocarcinoma', 'intellectual disability', 'lung adenocarcinoma', 'autosomal recessive osteopetrosis 3', 'osteoporosis', 'epilepsy with generalized tonic-clonic seizures', 'malignant mesothelioma']
#
# Sample 53
# True MONDO Names: ['large cell medulloblastoma', 'psoriasis', 'hypereosinophilic syndrome', 'pneumonia', 'pneumonitis', 'asthma', 'dermatitis, atopic', 'allergic disease', 'interstitial cystitis', 'malignant colon neoplasm', 'lung cancer', 'brain ischemia', 'polyomavirus infectious disease', 'ovarian cancer', 'Crohn disease', 'atopic eczema', 'HIV infectious disease', 'pulmonary fibrosis', 'drug allergy', 'congestive heart failure', 'ulcerative colitis', 'susceptibility to HIV infection', 'idiopathic interstitial pneumonia', 'inflammatory bowel disease', 'rhinitis']
# Predicted MONDO Names: ['hypereosinophilic syndrome', 'pneumonia', 'pneumonitis', 'asthma', 'dermatitis, atopic', 'allergic disease', 'interstitial cystitis', 'malignant colon neoplasm', 'lung cancer', 'brain ischemia', 'polyomavirus infectious disease', 'ovarian cancer', 'Crohn disease', 'atopic eczema', 'HIV infectious disease', 'pulmonary fibrosis', 'drug allergy', 'congestive heart failure', 'ulcerative colitis', 'susceptibility to HIV infection', 'idiopathic interstitial pneumonia', 'inflammatory bowel disease', 'rhinitis']
#
# Sample 54
# True MONDO Names: []
# Predicted MONDO Names: []
#
# Sample 55
# True MONDO Names: ['large cell medulloblastoma', 'malignant ependymoma', 'osteosarcoma', 'plasma cell myeloma', 'atypical teratoid rhabdoid tumor', 'esophageal squamous cell carcinoma', 'breast cancer', 'ovarian cancer', 'glioblastoma', 'malignant glioma', 'astrocytic tumor', 'malignant mesothelioma']
# Predicted MONDO Names: ['large cell medulloblastoma', 'malignant ependymoma', 'osteosarcoma', 'plasma cell myeloma', 'atypical teratoid rhabdoid tumor', 'esophageal squamous cell carcinoma', 'breast cancer', 'ovarian cancer', 'glioblastoma', 'malignant glioma', 'astrocytic tumor', 'malignant mesothelioma']
#
# Sample 56
# True MONDO Names: ['osteosarcoma', 'Gaucher disease', 'malignant pancreatic neoplasm', 'pancreatic ductal adenocarcinoma', 'ovarian cancer', 'pancreatic intraductal papillary-mucinous neoplasm', 'astrocytic tumor']
# Predicted MONDO Names: ['osteosarcoma', 'Gaucher disease', 'malignant pancreatic neoplasm', 'pancreatic ductal adenocarcinoma', 'ovarian cancer', 'pancreatic intraductal papillary-mucinous neoplasm', 'astrocytic tumor']
#
# Sample 57
# True MONDO Names: ['congenital anemia', 'psoriasis', "hemolytic anemia due to pyrimidine 5' nucleotidase deficiency", 'congenital nonspherocytic hemolytic anemia', 'intellectual disability']
# Predicted MONDO Names: ['congenital anemia', 'psoriasis', "hemolytic anemia due to pyrimidine 5' nucleotidase deficiency", 'congenital nonspherocytic hemolytic anemia', 'intellectual disability']
#
# Sample 58
# True MONDO Names: ['thrombophilia', 'large cell medulloblastoma', 'thrombotic disease', 'congenital factor VII deficiency', 'pancreatic ductal adenocarcinoma', 'intracerebral hemorrhage', 'atypical teratoid rhabdoid tumor', 'medulloblastoma', 'congenital factor XI deficiency', 'factor VII deficiency', 'atrial fibrillation', 'disseminated intravascular coagulation', 'glioblastoma', 'myocardial infarction', 'malignant glioma', 'intracranial hemorrhage', 'hemorrhagic disease', 'malignant mesothelioma']
# Predicted MONDO Names: ['thrombophilia', 'large cell medulloblastoma', 'thrombotic disease', 'congenital factor VII deficiency', 'pancreatic ductal adenocarcinoma', 'intracerebral hemorrhage', 'atypical teratoid rhabdoid tumor', 'medulloblastoma', 'congenital factor XI deficiency', 'factor VII deficiency', 'atrial fibrillation', 'disseminated intravascular coagulation', 'glioblastoma', 'myocardial infarction', 'malignant glioma', 'intracranial hemorrhage', 'hemorrhagic disease', 'malignant mesothelioma']
#
# Sample 59
# True MONDO Names: ['large cell medulloblastoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'psoriasis', 'lymphoplasmacytic lymphoma', 'osteosarcoma', 'schizophrenia', 'gastric carcinoma', 'atypical teratoid rhabdoid tumor', 'medulloblastoma', 'lung cancer', 'tuberculosis', 'ovarian cancer', 'gastric cancer', 'myopathy', 'pancreatic intraductal papillary-mucinous neoplasm', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'dermatomyositis', 'HIV infectious disease', 'hepatocellular carcinoma', 'lung adenocarcinoma']
# Predicted MONDO Names: ['large cell medulloblastoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'psoriasis', 'lymphoplasmacytic lymphoma', 'osteosarcoma', 'schizophrenia', 'gastric carcinoma', 'atypical teratoid rhabdoid tumor', 'medulloblastoma', 'lung cancer', 'tuberculosis', 'ovarian cancer', 'gastric cancer', 'myopathy', 'pancreatic intraductal papillary-mucinous neoplasm', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'dermatomyositis', 'HIV infectious disease', 'hepatocellular carcinoma', 'lung adenocarcinoma']
#
# Sample 60
# True MONDO Names: ['malignant ependymoma', 'osteosarcoma', 'schizophrenia', 'atypical teratoid rhabdoid tumor', 'pilocytic astrocytoma', 'ovarian cancer', 'glioblastoma', 'malignant glioma', 'astrocytic tumor', 'prostate cancer', 'malignant mesothelioma']
# Predicted MONDO Names: ['psoriasis', 'lymphoplasmacytic lymphoma', 'plasma cell myeloma', 'lung cancer', 'non-small cell lung carcinoma', 'ovarian cancer', 'dermatomyositis', 'HIV infectious disease', 'lung adenocarcinoma']
#
# Sample 61
# True MONDO Names: ['malignant ependymoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'leukodystrophy', 'osteosarcoma', 'Pick disease', 'Grn-related frontotemporal lobar degeneration with Tdp43 inclusions', 'amyotrophic lateral sclerosis', 'plasma cell myeloma', 'pilocytic astrocytoma', 'frontotemporal dementia', 'endogenous depression', 'anxiety disorder', 'ovarian cancer', 'myopathy', 'glioblastoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'neurodegenerative disease', 'malignant glioma', 'spina bifida', 'frontotemporal dementia and/or amyotrophic lateral sclerosis 1', 'bipolar disorder', 'cystic fibrosis', 'leukodystrophy, hypomyelinating, 16', 'lung adenocarcinoma', 'behavioral variant of frontotemporal dementia', 'Sjogren syndrome', 'heart disease', 'semantic dementia']
# Predicted MONDO Names: ['malignant ependymoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'leukodystrophy', 'osteosarcoma', 'Pick disease', 'Grn-related frontotemporal lobar degeneration with Tdp43 inclusions', 'amyotrophic lateral sclerosis', 'plasma cell myeloma', 'pilocytic astrocytoma', 'frontotemporal dementia', 'endogenous depression', 'anxiety disorder', 'ovarian cancer', 'myopathy', 'glioblastoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'neurodegenerative disease', 'malignant glioma', 'spina bifida', 'frontotemporal dementia and/or amyotrophic lateral sclerosis 1', 'bipolar disorder', 'cystic fibrosis', 'leukodystrophy, hypomyelinating, 16', 'lung adenocarcinoma', 'behavioral variant of frontotemporal dementia', 'Sjogren syndrome', 'heart disease', 'semantic dementia']
#
# Sample 62
# True MONDO Names: ['psoriasis', 'atypical teratoid rhabdoid tumor', 'breast cancer', 'Lynch syndrome', 'lung cancer', 'cutaneous lupus erythematosus', 'ovarian cancer', 'adenoma', 'glioblastoma', 'prostate carcinoma', 'familial colorectal cancer type X', 'systemic lupus erythematosus', 'cystic fibrosis', 'malignant mesothelioma']
# Predicted MONDO Names: []
#
# Sample 63
# True MONDO Names: ['psoriasis', 'autoimmune hepatitis', 'autoimmune disease', 'drug-induced liver injury', 'middle cerebral artery infarction', 'inflammatory bowel disease']
# Predicted MONDO Names: ['psoriasis', 'autoimmune hepatitis', 'drug-induced liver injury', 'middle cerebral artery infarction', 'inflammatory bowel disease']
#
# Sample 64
# True MONDO Names: ['large cell medulloblastoma', 'malignant ependymoma', 'congenital anemia', 'osteosarcoma', 'Cornelia de Lange syndrome 3', 'acute myeloid leukemia', 'Cornelia de Lange syndrome', 'chronic monocytic leukemia', 'Roberts syndrome', 'plasma cell myeloma', 'atypical teratoid rhabdoid tumor', 'medulloblastoma', 'trichorhinophalangeal syndrome type II', 'Cornelia de Lange syndrome 4', 'breast cancer', 'colorectal adenoma', 'lung cancer', 'lung carcinoma', 'colorectal adenocarcinoma', 'glioblastoma', 'endometrial carcinoma', 'oligodendroglioma', 'colorectal cancer', 'rheumatoid arthritis', 'invasive ductal breast carcinoma', 'endometrium carcinoma in situ', 'Cornelia de Lange syndrome 2', 'myeloid leukemia', 'astrocytic tumor', 'primitive neuroectodermal tumor', 'intellectual disability', 'lung adenocarcinoma', 'Mungan syndrome', 'malignant mesothelioma']
# Predicted MONDO Names: ['large cell medulloblastoma', 'malignant ependymoma', 'congenital anemia', 'osteosarcoma', 'Cornelia de Lange syndrome 3', 'acute myeloid leukemia', 'Cornelia de Lange syndrome', 'chronic monocytic leukemia', 'Roberts syndrome', 'plasma cell myeloma', 'atypical teratoid rhabdoid tumor', 'medulloblastoma', 'trichorhinophalangeal syndrome type II', 'Cornelia de Lange syndrome 4', 'breast cancer', 'colorectal adenoma', 'lung cancer', 'lung carcinoma', 'colorectal adenocarcinoma', 'glioblastoma', 'endometrial carcinoma', 'oligodendroglioma', 'colorectal cancer', 'rheumatoid arthritis', 'invasive ductal breast carcinoma', 'endometrium carcinoma in situ', 'Cornelia de Lange syndrome 2', 'myeloid leukemia', 'astrocytic tumor', 'primitive neuroectodermal tumor', 'intellectual disability', 'lung adenocarcinoma', 'Mungan syndrome', 'malignant mesothelioma']
#
# Total samples with zero predictions: 9

# %% [markdown]
# ## Save model as Torchfile

# %%
model.eval()
example = torch.rand(1, 1024)
traced_script_module = torch.jit.trace(model, example)
traced_script_module.save("model.pt")

# %% [markdown]
# ### Ensure model was properly saved and is working

# %%
# Load the saved model
loaded_model = torch.jit.load("model.pt")

# Create a sample input tensor
sample_input = torch.rand(1, 1024)

# Pass the sample input to the model
output = loaded_model(sample_input)

# Round each prediction in output[0]
rounded_predictions = output[0].round()

# Convert the rounded predictions to labels
reverse_vocab = create_reverse_vocab(annotations_vocab)
labels = convert_to_labels(rounded_predictions, reverse_vocab)

# Print the labels
print(len(labels))
print(labels)
# Out:
# 39
# ['coronary artery disease', 'psoriasis', 'adenocarcinoma', 'ovarian disease', 'malignant pancreatic neoplasm', 'cribriform carcinoma of breast', 'ischemia reperfusion injury', 'schizophrenia', 'pilocytic astrocytoma', 'skin basal cell carcinoma', 'gastric neoplasm', 'colonic neoplasm', 'cancer', 'ischemic disease', 'interstitial cystitis', 'malignant colon neoplasm', 'transient ischemic attack', 'lung cancer', 'autoimmune disease', 'endometriosis', 'squamous cell carcinoma', 'non-small cell lung carcinoma', 'gastric cancer', 'glioblastoma', 'ovarian neoplasm', 'tubular adenocarcinoma', 'rheumatoid arthritis', 'Crohn disease', 'ulcerative colitis', 'cystic fibrosis', 'hereditary diffuse gastric adenocarcinoma', 'head and neck cancer', 'pancreatic neoplasm', 'primary ovarian failure', 'intellectual disability', 'lung adenocarcinoma', 'Sjogren syndrome', 'benign colon neoplasm', 'prostate cancer']

# %% [markdown]
# ## Save Testing Dataset as CSV

# %%
def get_test_data(embeddings_test):
    """
    For each document in the MongoDB database where the embedding in embeddings_test corresponds to func_embedding, save the 'function' and 'mondo_names' to a pandas DataFrame.
    :param embeddings_test: The embeddings used for testing
    :return: A pandas DataFrame containing the 'function' and 'mondo_names' for each document
    """
    # Load environment variables
    load_dotenv()
    MONGO_URI = os.getenv("MONGODB_URI")
    MONGO_DB = "proteinExplorer"
    MONGO_COLLECTION = "protein_embeddings"

    # Connect to MongoDB
    client = MongoClient(MONGO_URI)
    db = client[MONGO_DB]
    collection = db[MONGO_COLLECTION]

    ids = []
    function = []
    labels = []

    for embedding in embeddings_test:
        document = collection.find_one({"func_embedding": embedding.tolist()})
        ids.append(document["_id"])
        function.append(document["function"])
        labels.append(document["mondo_names"])

    data = {"id": ids, "function": function, "mondo_names": labels}

    return pd.DataFrame(data)

# %%
test_df = get_test_data(embeddings_test)
test_df.head()
# Out:
#       id                                           function  \
# 0  23201  Microtubule-based anterograde translocator for...
# 1    967  Required for pre-mRNA splicing as component of...
# 2   4363  Together with BCKDHB forms the heterotetrameri...
# 3   1333  Component of the general transcription and DNA...
# 4    871  Catalyzes the formation of L-carnitine from ga...
#
#                                          mondo_names
# 0  [amyotrophic lateral sclerosis type 1, atrial ...
# 1                     [osteosarcoma, ovarian cancer]
# 2  [maple syrup urine disease, classic maple syru...
# 3  [attention deficit hyperactivity disorder, ina...
# 4  [astrocytic tumor, breast carcinoma, glioblast...

# %%
# convert test_df to a csv file
test_df.to_csv("test_data.csv", index=False)

# %% [markdown]
# ## Convert model to ONNX format

# %%
import onnxruntime as ort
import numpy as np
# Create an inference session
session = ort.InferenceSession("model.onnx", providers=['CPUExecutionProvider'])
print("Model input details:")
for input in session.get_inputs():
    print(input)

# Example of creating a random input matching the expected input shape
input_data = np.random.randn(1, 1024).astype(np.float32)

# Prepare the input dictionary
input_name = session.get_inputs()[0].name
input_dict = {input_name: input_data}

# Run the model
outputs = session.run(None, input_dict)

# Assuming the first output is what you need
output_data = outputs[0][0]
print("Output data:")
print(len(output_data))
# Out:
# Model input details:
# NodeArg(name='l_embeddings_', type='tensor(float)', shape=[1, 1024])
# Output data:
# 4582
