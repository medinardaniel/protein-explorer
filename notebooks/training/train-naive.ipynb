# %% [markdown]
# # Train Mondo Annotations

# %%
from transformers import AutoTokenizer, AutoModel
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import numpy as np
import torch.optim as optim
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from fetch import *
import pandas as pd

# %% [markdown]
# ## Load model and tokenizer

# %%
def split_data(embeddings, labels):
    # Split data into 80% training and 20% test
    embeddings_train, embeddings_temp, labels_train, labels_temp = train_test_split(
        embeddings, labels, test_size=0.20, random_state=42)

    # Split the 20% test into 15% validation and 5% test
    embeddings_val, embeddings_test, labels_val, labels_test = train_test_split(
        embeddings_temp, labels_temp, test_size=0.25, random_state=42)  # 0.25 * 0.20 = 0.05

    return embeddings_train, labels_train, embeddings_val, labels_val, embeddings_test, labels_test

# %% [markdown]
# ## Prepare dataset

# %%
class ProteinDataset(Dataset):
    def __init__(self, embeddings, labels):
        self.embeddings = embeddings
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.embeddings[idx], self.labels[idx]

# %% [markdown]
# ## Create a classifier

# %%
class NaiveProteinTaggingModel(nn.Module):
    def __init__(self, embedding_size, num_labels, dropout_rate=0.1):
        super(NaiveProteinTaggingModel, self).__init__()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc1 = nn.Linear(embedding_size, 128)  # Reduce the size and complexity
        self.relu = nn.ReLU()
        self.classifier = nn.Linear(128, num_labels)
        self.sigmoid = nn.Sigmoid()

    def forward(self, embeddings):
        x = self.dropout(embeddings)
        x = self.relu(self.fc1(x))
        logits = self.classifier(x)
        predictions = self.sigmoid(logits)
        return predictions

# %% [markdown]
# ## Train model

# %%
# load dataset
embedding_type = 'func_embedding'
embeddings, labels, annotations_vocab = fetch_data_multi(embedding_type, include_empty=True)

# split data
embeddings_train, labels_train, embeddings_val, labels_val, embeddings_test, labels_test = split_data(embeddings, labels)

# dataloaders
train_dataset = ProteinDataset(embeddings_train, labels_train)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

val_dataset = ProteinDataset(embeddings_val, labels_val)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

# %%
# Setup DataLoader, Model, Loss, and Optimizer
dataset = ProteinDataset(embeddings, labels)

model = NaiveProteinTaggingModel(embedding_size=embeddings.shape[1], num_labels=labels.shape[1])

criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

def train_and_validate(model, train_loader, val_loader, criterion, optimizer, epochs):
    for epoch in range(epochs):
        model.train()
        total_train_loss = 0
        for embeddings, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(embeddings)
            loss = criterion(outputs, labels.float())
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

        model.eval()
        total_val_loss = 0
        with torch.no_grad():
            for embeddings, labels in val_loader:
                outputs = model(embeddings)
                loss = criterion(outputs, labels.float())
                total_val_loss += loss.item()

        print(f'Epoch {epoch+1}, Training Loss: {total_train_loss / len(train_loader)}, Validation Loss: {total_val_loss / len(val_loader)}')

# %%
# Start training
train_and_validate(model, train_loader, val_loader, criterion, optimizer, epochs=60)
# Out:
# Epoch 1, Training Loss: 0.038854435833393416, Validation Loss: 0.01694928246568765
# Epoch 2, Training Loss: 0.01562373916877999, Validation Loss: 0.01399101394641873
# Epoch 3, Training Loss: 0.013394658546431444, Validation Loss: 0.012492694645281265
# Epoch 4, Training Loss: 0.012103700135783548, Validation Loss: 0.011425377122613769
# Epoch 5, Training Loss: 0.011068092218938456, Validation Loss: 0.010505832605285953
# Epoch 6, Training Loss: 0.010205182747275972, Validation Loss: 0.009747958455284108
# Epoch 7, Training Loss: 0.009493617834384316, Validation Loss: 0.009107810102822567
# Epoch 8, Training Loss: 0.008886558259721494, Validation Loss: 0.008565446969417745
# Epoch 9, Training Loss: 0.008373719731586711, Validation Loss: 0.008108226249352197
# Epoch 10, Training Loss: 0.00793885933733383, Validation Loss: 0.007712452212928344
# Epoch 11, Training Loss: 0.007574724283680987, Validation Loss: 0.007346264058909076
# Epoch 12, Training Loss: 0.007254518706939966, Validation Loss: 0.007080345911078698
# Epoch 13, Training Loss: 0.006986270400936442, Validation Loss: 0.006823993106033431
# Epoch 14, Training Loss: 0.00675405753401122, Validation Loss: 0.006611596913206459
# Epoch 15, Training Loss: 0.006552889495995359, Validation Loss: 0.006434191706041429
# Epoch 16, Training Loss: 0.006388035547266256, Validation Loss: 0.006251184032329463
# Epoch 17, Training Loss: 0.0062255493703469705, Validation Loss: 0.006123639088099366
# Epoch 18, Training Loss: 0.006092740885973607, Validation Loss: 0.005995396481493846
# Epoch 19, Training Loss: 0.00597472916141764, Validation Loss: 0.005873640163474723
# Epoch 20, Training Loss: 0.005857682284442662, Validation Loss: 0.005786450502666219
# Epoch 21, Training Loss: 0.005759052404628798, Validation Loss: 0.0056703236163748024
# Epoch 22, Training Loss: 0.005675356595056474, Validation Loss: 0.005584857875283881
# Epoch 23, Training Loss: 0.005582214291705588, Validation Loss: 0.005540386654917669
# Epoch 24, Training Loss: 0.005499168414105916, Validation Loss: 0.005423072509664968
# Epoch 25, Training Loss: 0.005434399340371254, Validation Loss: 0.005356576067043949
# Epoch 26, Training Loss: 0.005364373401015886, Validation Loss: 0.005280733191784447
# Epoch 27, Training Loss: 0.005301993708902349, Validation Loss: 0.005243543714334238
# Epoch 28, Training Loss: 0.005247633978064214, Validation Loss: 0.005181655568372927
# Epoch 29, Training Loss: 0.005193724272371877, Validation Loss: 0.005120966773147121
# Epoch 30, Training Loss: 0.005145059759202714, Validation Loss: 0.005069753517464593
# Epoch 31, Training Loss: 0.005096781078554616, Validation Loss: 0.00503090003795231
# Epoch 32, Training Loss: 0.005055253293460226, Validation Loss: 0.004986243908423067
# Epoch 33, Training Loss: 0.005008920392111889, Validation Loss: 0.0049651691579068735
# Epoch 34, Training Loss: 0.004966690725431458, Validation Loss: 0.00496994781721112
# Epoch 35, Training Loss: 0.004933453276197412, Validation Loss: 0.004864874484005156
# Epoch 36, Training Loss: 0.004898298983821247, Validation Loss: 0.004838031739773636
# Epoch 37, Training Loss: 0.004867737868393016, Validation Loss: 0.004814494768194608
# Epoch 38, Training Loss: 0.004835686883576381, Validation Loss: 0.004784685511771121
# Epoch 39, Training Loss: 0.004802699586253761, Validation Loss: 0.0047361542908659834
# Epoch 40, Training Loss: 0.0047732132144703236, Validation Loss: 0.004706857291155106
# Epoch 41, Training Loss: 0.004745372355885489, Validation Loss: 0.004685613980504456
# Epoch 42, Training Loss: 0.004724711243153564, Validation Loss: 0.004668815062991929
# Epoch 43, Training Loss: 0.004696490521084016, Validation Loss: 0.004633827319997825
# Epoch 44, Training Loss: 0.004672306372299883, Validation Loss: 0.0046293008286160545
# Epoch 45, Training Loss: 0.0046517238141366496, Validation Loss: 0.0045926000750222745
# Epoch 46, Training Loss: 0.004630350120034328, Validation Loss: 0.004572836782425543
# Epoch 47, Training Loss: 0.004609919933020717, Validation Loss: 0.004532858172727638
# Epoch 48, Training Loss: 0.004584794505545638, Validation Loss: 0.004533555119649957
# Epoch 49, Training Loss: 0.004565656854103862, Validation Loss: 0.004508844623033772
# Epoch 50, Training Loss: 0.004552105040896443, Validation Loss: 0.004504879956620912
# Epoch 51, Training Loss: 0.004533090419020152, Validation Loss: 0.00446540640438876
# Epoch 52, Training Loss: 0.004517121372839427, Validation Loss: 0.004460177422865041
# Epoch 53, Training Loss: 0.004503236429948842, Validation Loss: 0.0044331061931339325
# Epoch 54, Training Loss: 0.004484558276153304, Validation Loss: 0.004424130462344415
# Epoch 55, Training Loss: 0.004470534318020169, Validation Loss: 0.004404186070680815
# Epoch 56, Training Loss: 0.004453568014754121, Validation Loss: 0.004383224950770274
# Epoch 57, Training Loss: 0.004438690795442692, Validation Loss: 0.0043664343411485285
# Epoch 58, Training Loss: 0.004422677736161787, Validation Loss: 0.0043661465177571536
# Epoch 59, Training Loss: 0.004412594860343179, Validation Loss: 0.004369452324331991
# Epoch 60, Training Loss: 0.004399863184969502, Validation Loss: 0.004331248075337402

# %% [markdown]
# ## Evaluation

# %%
def evaluate_model(model, test_loader):
    model.eval()
    predictions = []
    truths = []
    with torch.no_grad():
        for embeddings, labels in test_loader:
            outputs = model(embeddings)
            predicted = torch.round(outputs)
            predictions.extend(predicted.cpu().numpy())
            truths.extend(labels.cpu().numpy())

    accuracy = accuracy_score(truths, predictions)
    precision = precision_score(truths, predictions, average='macro', zero_division=1)
    recall = recall_score(truths, predictions, average='macro', zero_division=1)
    f1 = f1_score(truths, predictions, average='macro', zero_division=1)

    return accuracy, precision, recall, f1

test_dataset = ProteinDataset(embeddings_test, labels_test)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
accuracy, precision, recall, f1 = evaluate_model(model, test_loader)
print(f'Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1 Score: {f1}')
# Out:
# Accuracy: 0.32275132275132273, Precision: 0.9725407783723214, Recall: 0.9386037764766582, F1 Score: 0.9305249751181706

# %% [markdown]
# ## Inference

# %%
def create_reverse_vocab(annotations_vocab):
    return {idx: label for label, idx in annotations_vocab.items()}

def convert_to_labels(binary_vector, reverse_vocab):
    labels = [reverse_vocab[i] for i, value in enumerate(binary_vector) if value == 1]
    return labels

def intersection_and_difference(true_labels, predicted_labels):
    # Calculate intersection and differences of two label lists
    true_set = set(true_labels)
    predicted_set = set(predicted_labels)
    intersection = true_set & predicted_set
    incorrect = predicted_set - true_set
    return len(intersection), len(true_set), len(predicted_set), len(incorrect)

import torch

def predict_and_evaluate(model, test_loader, annotations_vocab, num_samples=10):
    model.eval()
    total_intersection = 0
    total_true_labels = 0
    total_predicted_labels = 0
    total_incorrect = 0
    num_zero_prediction = 0  # To track samples with zero predicted labels
    sample_data = []
    reverse_vocab = create_reverse_vocab(annotations_vocab)

    with torch.no_grad():
        for embeddings, labels in test_loader:
            outputs = model(embeddings)
            predicted = torch.round(outputs)  # Using 0.5 as a threshold
            # Convert binary vectors to MONDO names
            predicted_labels = [convert_to_labels(pred, reverse_vocab) for pred in predicted.cpu().numpy()]
            true_labels = [convert_to_labels(true, reverse_vocab) for true in labels.cpu().numpy()]
            
            for true, pred in zip(true_labels, predicted_labels):
                inter, true_count, pred_count, incorrect = intersection_and_difference(true, pred)
                total_intersection += inter
                total_true_labels += true_count
                total_predicted_labels += pred_count
                total_incorrect += incorrect
                if len(pred) == 0:
                    num_zero_prediction += 1  # Increment if no labels were predicted
            
            # Collect samples for display
            if len(sample_data) < num_samples:
                sample_data.extend(zip(embeddings, true_labels, predicted_labels))
            if len(sample_data) >= num_samples:
                break
    
    # Calculate averages
    num_samples = len(test_loader.dataset)
    average_correct = (total_intersection / num_samples) * 100
    average_incorrect = (total_incorrect / num_samples) * 100
    print(f"Average percentage of correct MONDO names per sample: {average_correct:.2f}%")
    print(f"Average percentage of incorrect MONDO names per sample: {average_incorrect:.2f}%")
    print(f"Number of samples with zero predicted labels: {num_zero_prediction}")

    return sample_data, num_zero_prediction

# Example usage assuming model, test_loader, and annotations_vocab are defined
sample_data, num_zero_prediction = predict_and_evaluate(model, test_loader, annotations_vocab, num_samples=10)

# Print the samples and the total number of zero predicted labels
for idx, (embedding, true_label, predicted_label) in enumerate(sample_data):
    print(f"Sample {idx+1}")
    print(f"True MONDO Names: {true_label}")
    print(f"Predicted MONDO Names: {predicted_label}\n")
print(f"Total samples with zero predictions: {num_zero_prediction}")
# Out:
# Average percentage of correct MONDO names per sample: 40.87%
# Average percentage of incorrect MONDO names per sample: 2.55%
# Number of samples with zero predicted labels: 9
# Sample 1
# True MONDO Names: ['ovarian cancer', 'autism spectrum disorder', 'lung carcinoma', 'gastroesophageal reflux disease', 'lung cancer', 'endogenous depression', 'osteosarcoma', 'bone Paget disease', 'cutaneous lupus erythematosus', 'Crohn disease', 'squamous cell lung carcinoma', 'ulcerative colitis', 'Sjogren syndrome', 'osteoporosis', 'pilocytic astrocytoma', 'attention deficit hyperactivity disorder, inattentive type', 'postmenopausal osteoporosis', 'chronic obstructive pulmonary disease', 'dental caries']
# Predicted MONDO Names: ['gastroesophageal reflux disease', 'psoriasis', 'bone Paget disease', 'cutaneous lupus erythematosus', 'Crohn disease', 'squamous cell lung carcinoma', 'ulcerative colitis', 'osteoporosis', 'postmenopausal osteoporosis', 'dental caries']
#
# Sample 2
# True MONDO Names: ['large cell medulloblastoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'alcoholic pancreatitis', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'psoriasis', 'malignant glioma', 'cutaneous lupus erythematosus', 'polycystic ovary syndrome', 'glioblastoma', 'atypical teratoid rhabdoid tumor']
# Predicted MONDO Names: ['large cell medulloblastoma', 'alcoholic pancreatitis', 'medulloblastoma']
#
# Sample 3
# True MONDO Names: ['paratuberculosis', 'cerebrovascular disorder', 'hepatocellular carcinoma', 'pneumonia', 'skin vascular disease', 'autism spectrum disorder', 'rheumatoid arthritis', 'thrombocytopenia', 'thrombophilia due to thrombin defect', 'nephrosis', 'pregnancy loss, recurrent, susceptibility to, 2', 'myocardial infarction', 'disseminated intravascular coagulation', 'kidney disease', 'Alzheimer disease', 'intracranial sinus thrombosis', 'thrombophilia', 'coronary artery disease', 'hypertensive disorder', 'thrombotic disease', 'blood coagulation disease', 'venous thromboembolism', 'non-alcoholic fatty liver disease', 'osteoarthritis', 'esophageal varices', 'congenital prothrombin deficiency', 'fatty liver disease', 'alcohol abuse', 'vitamin K deficiency hemorrhagic disease', 'cirrhosis of liver', 'hemochromatosis type 1', 'pulmonary embolism', 'autoimmune disease', 'liver failure', 'vascular disease', 'obesity disorder', 'liver disease', 'hepatitis B virus infection', 'brain ischemia', 'varicose disease', 'anemia', 'inborn carbohydrate metabolic disorder', 'cancer', 'cerebral infarction', 'COVID-19', 'schizophrenia', 'hepatic encephalopathy', 'respiratory failure', 'heart disease']
# Predicted MONDO Names: ['paratuberculosis', 'cerebrovascular disorder', 'hepatocellular carcinoma', 'pneumonia', 'skin vascular disease', 'autism spectrum disorder', 'rheumatoid arthritis', 'thrombocytopenia', 'thrombophilia due to thrombin defect', 'nephrosis', 'pregnancy loss, recurrent, susceptibility to, 2', 'myocardial infarction', 'disseminated intravascular coagulation', 'kidney disease', 'Alzheimer disease', 'intracranial sinus thrombosis', 'thrombophilia', 'coronary artery disease', 'hypertensive disorder', 'thrombotic disease', 'blood coagulation disease', 'venous thromboembolism', 'non-alcoholic fatty liver disease', 'osteoarthritis', 'esophageal varices', 'congenital prothrombin deficiency', 'fatty liver disease', 'alcohol abuse', 'vitamin K deficiency hemorrhagic disease', 'cirrhosis of liver', 'hemochromatosis type 1', 'pulmonary embolism', 'autoimmune disease', 'liver failure', 'vascular disease', 'obesity disorder', 'liver disease', 'hepatitis B virus infection', 'brain ischemia', 'varicose disease', 'anemia', 'inborn carbohydrate metabolic disorder', 'cancer', 'cerebral infarction', 'COVID-19', 'schizophrenia', 'hepatic encephalopathy', 'respiratory failure', 'heart disease']
#
# Sample 4
# True MONDO Names: ['interstitial cystitis', 'esophageal squamous cell carcinoma', 'bone marrow disease', 'lymphatic system disease', 'hypoproteinemia, hypercatabolic', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'subependymal giant cell astrocytoma', 'rheumatoid arthritis', 'lung carcinoma', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'psoriasis', 'kidney disease', 'osteosarcoma', 'prostate cancer', 'mature T-cell and NK-cell non-Hodgkin lymphoma', 'lymphoplasmacytic lymphoma', 'Down syndrome', 'familial visceral amyloidosis', 'acute kidney failure', 'acquired metabolic disease', 'variant ABeta2M amyloidosis', 'autoimmune disease', 'ulcerative colitis', 'Sjogren syndrome', 'diffuse large B-cell lymphoma', 'lung adenocarcinoma', 'amyloidosis', 'juvenile dermatomyositis', 'pilocytic astrocytoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'glioblastoma', 'cancer', 'periodic fever syndrome', 'schizophrenia', 'MHC class I deficiency', 'heart disease']
# Predicted MONDO Names: ['interstitial cystitis', 'esophageal squamous cell carcinoma', 'bone marrow disease', 'lymphatic system disease', 'hypoproteinemia, hypercatabolic', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'subependymal giant cell astrocytoma', 'rheumatoid arthritis', 'lung carcinoma', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'psoriasis', 'kidney disease', 'osteosarcoma', 'prostate cancer', 'mature T-cell and NK-cell non-Hodgkin lymphoma', 'lymphoplasmacytic lymphoma', 'Down syndrome', 'familial visceral amyloidosis', 'acute kidney failure', 'acquired metabolic disease', 'variant ABeta2M amyloidosis', 'autoimmune disease', 'ulcerative colitis', 'Sjogren syndrome', 'diffuse large B-cell lymphoma', 'lung adenocarcinoma', 'amyloidosis', 'juvenile dermatomyositis', 'pilocytic astrocytoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'glioblastoma', 'cancer', 'periodic fever syndrome', 'schizophrenia', 'MHC class I deficiency', 'heart disease']
#
# Sample 5
# True MONDO Names: ['dermatomyositis', 'large cell medulloblastoma', 'Parkinson disease', 'non-small cell lung carcinoma', 'invasive ductal breast carcinoma', 'nasopharyngeal carcinoma', 'Gaucher disease', 'ovarian cancer', 'hereditary spastic paraplegia', 'lung cancer', 'psoriasis', 'medulloblastoma', 'lymphoplasmacytic lymphoma', 'atrial fibrillation', 'myopathy', 'plasma cell myeloma', 'congestive heart failure', 'lung adenocarcinoma', 'osteoporosis', 'glioblastoma', 'atypical teratoid rhabdoid tumor']
# Predicted MONDO Names: ['dermatomyositis', 'large cell medulloblastoma', 'non-small cell lung carcinoma', 'ovarian cancer', 'lung cancer', 'medulloblastoma', 'lymphoplasmacytic lymphoma', 'myopathy', 'plasma cell myeloma', 'lung adenocarcinoma']
#
# Sample 6
# True MONDO Names: ['malignant colon neoplasm', 'cerebrovascular disorder', 'hypertrophic cardiomyopathy', 'Charcot-Marie-Tooth disease', 'hemangioma', 'breast fibroadenoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'subependymal giant cell astrocytoma', 'lysosomal storage disease', 'medulloblastoma', 'sphingolipidosis', 'inborn errors of metabolism', 'angiokeratoma', 'hydrops fetalis', 'Fabry disease', 'dilated cardiomyopathy', 'glioblastoma', 'leukodystrophy']
# Predicted MONDO Names: ['hypertrophic cardiomyopathy', 'Charcot-Marie-Tooth disease', 'hemangioma', 'ovarian cancer', 'subependymal giant cell astrocytoma', 'lysosomal storage disease', 'medulloblastoma', 'sphingolipidosis', 'diabetes mellitus', 'inborn errors of metabolism', 'angiokeratoma', 'hydrops fetalis', 'Fabry disease', 'dilated cardiomyopathy', 'glioblastoma', 'leukodystrophy']
#
# Sample 7
# True MONDO Names: []
# Predicted MONDO Names: []
#
# Sample 8
# True MONDO Names: ['large cell medulloblastoma', 'malignant pancreatic neoplasm', 'gastric carcinoma', 'non-small cell lung carcinoma', 'invasive ductal breast carcinoma', 'ovarian cancer', 'swine influenza', 'oligodendroglioma', 'malignant glioma', 'medulloblastoma', 'osteosarcoma', 'facioscapulohumeral muscular dystrophy', 'testicular germ cell tumor', 'malignant ependymoma', 'myopathy', 'pancreatic ductal adenocarcinoma', 'juvenile dermatomyositis', 'adenoma', 'glioblastoma', 'exocrine pancreatic carcinoma', 'cystic fibrosis', 'atypical teratoid rhabdoid tumor']
# Predicted MONDO Names: ['breast carcinoma', 'large cell medulloblastoma', 'malignant pancreatic neoplasm', 'invasive ductal breast carcinoma', 'ovarian cancer', 'lung cancer', 'osteosarcoma', 'breast cancer', 'malignant ependymoma', 'myopathy', 'plasma cell myeloma', 'pancreatic ductal adenocarcinoma', 'lung adenocarcinoma', 'juvenile dermatomyositis', 'atypical teratoid rhabdoid tumor']
#
# Sample 9
# True MONDO Names: []
# Predicted MONDO Names: []
#
# Sample 10
# True MONDO Names: ['large cell medulloblastoma', 'encephalitis', 'psoriasis', 'medulloblastoma', 'osteosarcoma', 'B-cell chronic lymphocytic leukemia', 'HIV infectious disease']
# Predicted MONDO Names: ['encephalitis', 'psoriasis', 'osteosarcoma', 'HIV infectious disease']
#
# Sample 11
# True MONDO Names: ['malignant colon neoplasm', 'breast carcinoma', 'hepatocellular carcinoma', 'large cell medulloblastoma', 'malignant mesothelioma', 'ductal breast carcinoma in situ', 'malignant pancreatic neoplasm', 'non-small cell lung carcinoma', 'interstitial lung disease', 'esophageal adenocarcinoma', 'invasive ductal breast carcinoma', 'atopic eczema', 'nasopharyngeal carcinoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'primitive neuroectodermal tumor', 'lung cancer', 'psoriasis', 'malignant glioma', 'medulloblastoma', 'endometriosis', 'adrenal cortex carcinoma', 'breast cancer', 'malignant ependymoma', 'polycystic ovary syndrome', 'Sjogren syndrome', 'lung adenocarcinoma', 'IgA glomerulonephritis', 'pilocytic astrocytoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'glioblastoma', 'idiopathic pulmonary fibrosis', 'atypical teratoid rhabdoid tumor']
# Predicted MONDO Names: ['malignant colon neoplasm', 'breast carcinoma', 'hepatocellular carcinoma', 'large cell medulloblastoma', 'malignant mesothelioma', 'ductal breast carcinoma in situ', 'malignant pancreatic neoplasm', 'non-small cell lung carcinoma', 'interstitial lung disease', 'esophageal adenocarcinoma', 'invasive ductal breast carcinoma', 'atopic eczema', 'nasopharyngeal carcinoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'primitive neuroectodermal tumor', 'lung cancer', 'psoriasis', 'malignant glioma', 'medulloblastoma', 'endometriosis', 'adrenal cortex carcinoma', 'breast cancer', 'malignant ependymoma', 'polycystic ovary syndrome', 'Sjogren syndrome', 'lung adenocarcinoma', 'IgA glomerulonephritis', 'pilocytic astrocytoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'glioblastoma', 'idiopathic pulmonary fibrosis', 'atypical teratoid rhabdoid tumor']
#
# Sample 12
# True MONDO Names: ['hyperandrogenism', 'maturity-onset diabetes of the young type 10', 'cardiac arrest', 'neurenteric cyst', 'kidney failure', 'cerebrovascular disorder', 'blindness (disorder)', 'neural tube defect', 'hypertrophic cardiomyopathy', 'tethered spinal cord syndrome', 'type 2 diabetes mellitus', 'metabolic acidosis', 'inherited lipid metabolism disorder', 'Parkinson disease', 'cognitive disorder', 'diarrheal disease', 'permanent neonatal diabetes mellitus 1', 'muscle tissue disease', 'anovulation', 'hyperinsulinism', 'hepatitis', 'diabetic ketoacidosis', 'craniorachischisis', 'pancreatic insulinoma', 'arthritic joint disease', 'DEND syndrome', 'prostate carcinoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'lung disease', 'gestational diabetes', 'breast disease', 'visual epilepsy', 'diastematomyelia', 'hypotensive disorder', 'atherosclerosis', 'dementia', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'hypothyroidism', 'metabolic disease', 'bipolar disorder', 'kidney disease', 'Alzheimer disease', 'autonomic neuropathy', 'lipodystrophy', 'coronary artery disease', 'glucose intolerance', 'prediabetes syndrome', 'cervical cancer', 'diabetes mellitus', 'type 1 diabetes mellitus 2', 'hypertensive disorder', 'hypoglycemia', 'sleep-wake disorder', 'prostate cancer', 'non-alcoholic fatty liver disease', 'ventricular fibrillation', 'neurodegenerative disease', 'urinary bladder disease', 'hyperglycemia', 'maturity-onset diabetes of the young', 'heart failure', 'fatty liver disease', 'hypertriglyceridemia', 'myopathy', 'hyperproinsulinemia', 'acute liver failure', 'acute kidney failure', 'acquired metabolic disease', 'maturity-onset diabetes of the young type 1', 'diabetic retinopathy', 'iniencephaly', 'infertility disorder', 'acromegaly', 'cystic kidney disease', 'pancreatitis', 'potassium deficiency disease', 'autoimmune disease', 'polycystic ovary syndrome', 'type 1 diabetes mellitus', 'muscular disease', 'obesity disorder', 'liver disease', 'congestive heart failure', 'palsy', 'rhabdomyolysis', 'osteoporosis', 'skin disease', 'diabetic kidney disease', 'permanent neonatal diabetes mellitus', 'Phelan-McDermid syndrome', 'anemia', 'Lewy body dementia', 'hyperaldosteronism', 'hyperinsulinemic hypoglycemia', 'eating disorder', 'pancreatic intraductal papillary-mucinous carcinoma', 'neonatal diabetes mellitus', 'peripheral vascular disease', 'metabolic syndrome X', 'peripheral neuropathy', 'cancer', 'panic disorder', 'heart disease']
# Predicted MONDO Names: ['hyperandrogenism', 'maturity-onset diabetes of the young type 10', 'cardiac arrest', 'neurenteric cyst', 'kidney failure', 'cerebrovascular disorder', 'blindness (disorder)', 'neural tube defect', 'hypertrophic cardiomyopathy', 'tethered spinal cord syndrome', 'type 2 diabetes mellitus', 'metabolic acidosis', 'inherited lipid metabolism disorder', 'Parkinson disease', 'cognitive disorder', 'diarrheal disease', 'permanent neonatal diabetes mellitus 1', 'muscle tissue disease', 'anovulation', 'hyperinsulinism', 'hepatitis', 'diabetic ketoacidosis', 'craniorachischisis', 'pancreatic insulinoma', 'arthritic joint disease', 'DEND syndrome', 'prostate carcinoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'lung disease', 'gestational diabetes', 'breast disease', 'visual epilepsy', 'diastematomyelia', 'hypotensive disorder', 'atherosclerosis', 'dementia', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'hypothyroidism', 'metabolic disease', 'bipolar disorder', 'kidney disease', 'Alzheimer disease', 'autonomic neuropathy', 'lipodystrophy', 'coronary artery disease', 'glucose intolerance', 'prediabetes syndrome', 'cervical cancer', 'diabetes mellitus', 'type 1 diabetes mellitus 2', 'hypertensive disorder', 'hypoglycemia', 'sleep-wake disorder', 'prostate cancer', 'non-alcoholic fatty liver disease', 'ventricular fibrillation', 'neurodegenerative disease', 'urinary bladder disease', 'hyperglycemia', 'maturity-onset diabetes of the young', 'heart failure', 'fatty liver disease', 'hypertriglyceridemia', 'myopathy', 'hyperproinsulinemia', 'acute liver failure', 'acute kidney failure', 'acquired metabolic disease', 'maturity-onset diabetes of the young type 1', 'diabetic retinopathy', 'iniencephaly', 'infertility disorder', 'acromegaly', 'cystic kidney disease', 'pancreatitis', 'potassium deficiency disease', 'autoimmune disease', 'polycystic ovary syndrome', 'type 1 diabetes mellitus', 'muscular disease', 'obesity disorder', 'liver disease', 'congestive heart failure', 'palsy', 'rhabdomyolysis', 'osteoporosis', 'skin disease', 'diabetic kidney disease', 'permanent neonatal diabetes mellitus', 'Phelan-McDermid syndrome', 'anemia', 'Lewy body dementia', 'hyperaldosteronism', 'hyperinsulinemic hypoglycemia', 'eating disorder', 'pancreatic intraductal papillary-mucinous carcinoma', 'neonatal diabetes mellitus', 'peripheral vascular disease', 'metabolic syndrome X', 'peripheral neuropathy', 'cancer', 'panic disorder', 'heart disease']
#
# Sample 13
# True MONDO Names: ['paratuberculosis', 'cerebrovascular disorder', 'hepatocellular carcinoma', 'pneumonia', 'skin vascular disease', 'autism spectrum disorder', 'rheumatoid arthritis', 'thrombocytopenia', 'thrombophilia due to thrombin defect', 'nephrosis', 'pregnancy loss, recurrent, susceptibility to, 2', 'myocardial infarction', 'disseminated intravascular coagulation', 'kidney disease', 'Alzheimer disease', 'intracranial sinus thrombosis', 'thrombophilia', 'coronary artery disease', 'hypertensive disorder', 'thrombotic disease', 'blood coagulation disease', 'venous thromboembolism', 'non-alcoholic fatty liver disease', 'osteoarthritis', 'esophageal varices', 'congenital prothrombin deficiency', 'fatty liver disease', 'alcohol abuse', 'vitamin K deficiency hemorrhagic disease', 'cirrhosis of liver', 'hemochromatosis type 1', 'pulmonary embolism', 'autoimmune disease', 'liver failure', 'vascular disease', 'obesity disorder', 'liver disease', 'hepatitis B virus infection', 'brain ischemia', 'varicose disease', 'anemia', 'inborn carbohydrate metabolic disorder', 'cancer', 'cerebral infarction', 'COVID-19', 'schizophrenia', 'hepatic encephalopathy', 'respiratory failure', 'heart disease']
# Predicted MONDO Names: ['paratuberculosis', 'cerebrovascular disorder', 'hepatocellular carcinoma', 'pneumonia', 'skin vascular disease', 'autism spectrum disorder', 'rheumatoid arthritis', 'thrombocytopenia', 'thrombophilia due to thrombin defect', 'nephrosis', 'pregnancy loss, recurrent, susceptibility to, 2', 'myocardial infarction', 'disseminated intravascular coagulation', 'kidney disease', 'Alzheimer disease', 'intracranial sinus thrombosis', 'thrombophilia', 'coronary artery disease', 'hypertensive disorder', 'thrombotic disease', 'blood coagulation disease', 'venous thromboembolism', 'non-alcoholic fatty liver disease', 'osteoarthritis', 'esophageal varices', 'congenital prothrombin deficiency', 'fatty liver disease', 'alcohol abuse', 'vitamin K deficiency hemorrhagic disease', 'cirrhosis of liver', 'hemochromatosis type 1', 'pulmonary embolism', 'autoimmune disease', 'liver failure', 'vascular disease', 'obesity disorder', 'liver disease', 'hepatitis B virus infection', 'brain ischemia', 'varicose disease', 'anemia', 'inborn carbohydrate metabolic disorder', 'cancer', 'cerebral infarction', 'COVID-19', 'schizophrenia', 'hepatic encephalopathy', 'respiratory failure', 'heart disease']
#
# Sample 14
# True MONDO Names: ['ductal breast carcinoma in situ', 'breast fibroadenoma', 'invasive ductal breast carcinoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'factor X deficiency', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'psoriasis', 'congenital factor X deficiency', 'thrombotic disease', 'blood coagulation disease', 'atrial fibrillation', 'pulmonary embolism', 'pancreatic ductal adenocarcinoma', 'lung adenocarcinoma']
# Predicted MONDO Names: ['ductal breast carcinoma in situ', 'breast fibroadenoma', 'invasive ductal breast carcinoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'factor X deficiency', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'psoriasis', 'congenital factor X deficiency', 'thrombotic disease', 'blood coagulation disease', 'atrial fibrillation', 'pulmonary embolism', 'pancreatic ductal adenocarcinoma', 'lung adenocarcinoma']
#
# Sample 15
# True MONDO Names: ['malignant mesothelioma', 'ovarian cancer', 'malignant glioma', 'osteosarcoma', 'prostate cancer', 'malignant ependymoma', 'astrocytic tumor', 'pilocytic astrocytoma', 'glioblastoma', 'atypical teratoid rhabdoid tumor', 'schizophrenia']
# Predicted MONDO Names: ['dermatomyositis', 'large cell medulloblastoma', 'non-small cell lung carcinoma', 'ovarian cancer', 'lung cancer', 'medulloblastoma', 'lymphoplasmacytic lymphoma', 'myopathy', 'plasma cell myeloma', 'lung adenocarcinoma']
#
# Sample 16
# True MONDO Names: ['idiopathic scoliosis']
# Predicted MONDO Names: ['autism spectrum disorder', 'lung cancer', 'hypertensive disorder', 'breast cancer', 'lung adenocarcinoma']
#
# Sample 17
# True MONDO Names: ['hyperthyroidism', 'transient ischemic attack', 'depressive disorder', 'alcoholic fatty liver disease', 'proteinuria', 'primary ovarian failure', 'cerebrovascular disorder', 'iron deficiency anemia', 'melancholia', 'type 2 diabetes mellitus', 'Parkinson disease', 'hepatitis', 'idiopathic interstitial pneumonia', 'ovarian cancer', 'asthma', 'anterior horn disease', 'Turner syndrome', 'hypotensive disorder', 'contact dermatitis', 'hearing loss disorder', 'ischemic disease', 'atherosclerosis', 'dementia', 'nephrosis', 'pulmonary fibrosis', 'bipolar disorder', 'perinatal asphyxia', 'malignant glioma', 'myocardial infarction', 'endogenous depression', 'fetal growth restriction', 'spinal cord injury', 'retinal degeneration', 'scrapie', 'diabetes mellitus', 'hypertensive disorder', 'lateral sclerosis', 'neurodegenerative disease', 'lymphoplasmacytic lymphoma', 'maturity-onset diabetes of the young', 'amyotrophic lateral sclerosis', 'heart failure', 'fatty liver disease', 'aortic disease', 'nutritional deficiency disease', 'ischemia reperfusion injury', 'Down syndrome', 'progressive external ophthalmoplegia', 'nervous system disorder', 'motor neuron disease', 'acute kidney failure', 'plasma cell myeloma', 'diabetic retinopathy', 'mixed glioma', 'muscular atrophy', 'obesity disorder', 'liver disease', 'myelomeningocele', 'pancreatic ductal adenocarcinoma', 'congestive heart failure', 'glioma', 'intestinal schistosomiasis', 'amyotrophic lateral sclerosis type 1', 'brain ischemia', 'arteriosclerosis disorder', 'MELAS syndrome', 'neurotic disorder', 'juvenile primary lateral sclerosis', 'drug-induced liver injury', 'Marfan syndrome', 'ovarian neoplasm', 'schizophrenia']
# Predicted MONDO Names: ['hyperthyroidism', 'transient ischemic attack', 'depressive disorder', 'alcoholic fatty liver disease', 'proteinuria', 'primary ovarian failure', 'cerebrovascular disorder', 'iron deficiency anemia', 'melancholia', 'type 2 diabetes mellitus', 'Parkinson disease', 'hepatitis', 'idiopathic interstitial pneumonia', 'ovarian cancer', 'asthma', 'anterior horn disease', 'Turner syndrome', 'hypotensive disorder', 'contact dermatitis', 'hearing loss disorder', 'ischemic disease', 'atherosclerosis', 'dementia', 'nephrosis', 'pulmonary fibrosis', 'bipolar disorder', 'perinatal asphyxia', 'malignant glioma', 'myocardial infarction', 'endogenous depression', 'fetal growth restriction', 'spinal cord injury', 'retinal degeneration', 'scrapie', 'diabetes mellitus', 'hypertensive disorder', 'lateral sclerosis', 'neurodegenerative disease', 'lymphoplasmacytic lymphoma', 'maturity-onset diabetes of the young', 'amyotrophic lateral sclerosis', 'heart failure', 'fatty liver disease', 'aortic disease', 'nutritional deficiency disease', 'ischemia reperfusion injury', 'Down syndrome', 'progressive external ophthalmoplegia', 'nervous system disorder', 'motor neuron disease', 'acute kidney failure', 'plasma cell myeloma', 'diabetic retinopathy', 'mixed glioma', 'muscular atrophy', 'obesity disorder', 'liver disease', 'myelomeningocele', 'pancreatic ductal adenocarcinoma', 'congestive heart failure', 'glioma', 'intestinal schistosomiasis', 'amyotrophic lateral sclerosis type 1', 'brain ischemia', 'arteriosclerosis disorder', 'MELAS syndrome', 'neurotic disorder', 'juvenile primary lateral sclerosis', 'drug-induced liver injury', 'Marfan syndrome', 'ovarian neoplasm', 'schizophrenia']
#
# Sample 18
# True MONDO Names: ['Duchenne muscular dystrophy', 'large cell medulloblastoma', 'non-small cell lung carcinoma', 'ovarian cancer', 'subependymal giant cell astrocytoma', 'primitive neuroectodermal tumor', 'lung cancer', 'psoriasis', 'malignant glioma', 'medulloblastoma', 'osteosarcoma', 'breast cancer', 'Crohn disease', 'malignant ependymoma', 'myopathy', 'plasma cell myeloma', 'ulcerative colitis', 'pancreatic ductal adenocarcinoma', 'lung adenocarcinoma', 'IgA glomerulonephritis', 'pilocytic astrocytoma', 'chronic obstructive pulmonary disease', 'glioblastoma', 'atypical teratoid rhabdoid tumor']
# Predicted MONDO Names: ['ovarian cancer', 'osteoarthritis susceptibility 1', 'cataract']
#
# Sample 19
# True MONDO Names: ['malignant colon neoplasm', "Hodgkin's lymphoma, lymphocytic depletion", 'dermatomyositis', 'breast carcinoma', 'large cell medulloblastoma', 'malignant mesothelioma', 'ductal breast carcinoma in situ', 'interstitial cystitis', 'malignant pancreatic neoplasm', 'non-small cell lung carcinoma', "Hodgkin's lymphoma, mixed cellularity", 'esophageal adenocarcinoma', 'invasive ductal breast carcinoma', 'Huntington disease', 'nasopharyngeal carcinoma', 'ovarian cancer', 'primitive neuroectodermal tumor', 'lung cancer', 'psoriasis', 'oligodendroglioma', 'pituitary cancer', 'malignant glioma', 'medulloblastoma', 'nodular lymphocyte predominant Hodgkin lymphoma', 'adrenal cortex carcinoma', 'diabetes mellitus', 'osteosarcoma', 'breast cancer', 'Crohn disease', 'amyotrophic lateral sclerosis', 'Emery-Dreifuss muscular dystrophy', 'myopathy', 'sarcoidosis', 'polycystic ovary syndrome', 'ulcerative colitis', 'pancreatic ductal adenocarcinoma', 'lung adenocarcinoma', "Hodgkin's lymphoma, lymphocytic-histiocytic predominance", 'juvenile dermatomyositis', 'astrocytic tumor', 'pilocytic astrocytoma', 'attention deficit hyperactivity disorder, inattentive type', 'Hodgkins lymphoma', 'glioblastoma', 'head and neck cancer', 'atypical teratoid rhabdoid tumor']
# Predicted MONDO Names: ["Hodgkin's lymphoma, lymphocytic depletion", 'large cell medulloblastoma', 'interstitial cystitis', 'malignant pancreatic neoplasm', 'non-small cell lung carcinoma', "Hodgkin's lymphoma, mixed cellularity", 'invasive ductal breast carcinoma', 'Huntington disease', 'nasopharyngeal carcinoma', 'ovarian cancer', 'tuberculosis', 'primitive neuroectodermal tumor', 'lung cancer', 'oligodendroglioma', 'malignant glioma', 'medulloblastoma', 'nodular lymphocyte predominant Hodgkin lymphoma', 'adrenal cortex carcinoma', 'B-cell chronic lymphocytic leukemia', 'Emery-Dreifuss muscular dystrophy', 'colorectal carcinoma', 'myopathy', 'ulcerative colitis', 'pancreatic ductal adenocarcinoma', "Hodgkin's lymphoma, lymphocytic-histiocytic predominance", 'astrocytic tumor', 'pilocytic astrocytoma', 'glioblastoma', 'gastric cancer', 'head and neck cancer', 'cystic fibrosis', 'colorectal cancer', 'atypical teratoid rhabdoid tumor']
#
# Sample 20
# True MONDO Names: ['breast carcinoma', 'large cell medulloblastoma', 'ductal breast carcinoma in situ', 'interstitial cystitis', 'malignant pancreatic neoplasm', 'non-small cell lung carcinoma', 'invasive ductal breast carcinoma', 'atopic eczema', 'nasopharyngeal carcinoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'primitive neuroectodermal tumor', 'psoriasis', 'oligodendroglioma', 'malignant glioma', 'medulloblastoma', 'endometriosis', 'adrenal cortex carcinoma', 'breast cancer', 'Crohn disease', 'malignant ependymoma', 'Sjogren syndrome', 'lung adenocarcinoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'glioblastoma', 'cystic fibrosis', 'atypical teratoid rhabdoid tumor', 'sinusitis']
# Predicted MONDO Names: ['large cell medulloblastoma', 'ductal breast carcinoma in situ', 'non-small cell lung carcinoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'psoriasis', 'medulloblastoma', 'breast cancer', 'atypical teratoid rhabdoid tumor']
#
# Sample 21
# True MONDO Names: ['malignant colon neoplasm', 'hepatocellular carcinoma', 'malignant pancreatic neoplasm', 'gastric carcinoma', 'invasive ductal breast carcinoma', 'ovarian cancer', 'subependymal giant cell astrocytoma', 'psoriasis', 'colonic neoplasm', 'diabetes mellitus', 'benign colon neoplasm', 'B-cell chronic lymphocytic leukemia', 'urinary bladder cancer', 'peripheral nervous system disease', 'urinary bladder neoplasm', 'glioblastoma', 'gastric cancer', 'peripheral neuropathy', 'exocrine pancreatic carcinoma']
# Predicted MONDO Names: ['malignant colon neoplasm', 'hepatocellular carcinoma', 'malignant pancreatic neoplasm', 'gastric carcinoma', 'invasive ductal breast carcinoma', 'ovarian cancer', 'subependymal giant cell astrocytoma', 'psoriasis', 'colonic neoplasm', 'diabetes mellitus', 'benign colon neoplasm', 'B-cell chronic lymphocytic leukemia', 'urinary bladder cancer', 'peripheral nervous system disease', 'urinary bladder neoplasm', 'glioblastoma', 'gastric cancer', 'peripheral neuropathy', 'exocrine pancreatic carcinoma']
#
# Sample 22
# True MONDO Names: []
# Predicted MONDO Names: []
#
# Sample 23
# True MONDO Names: ['large cell medulloblastoma', 'rheumatoid arthritis', 'malignant glioma', 'osteosarcoma', 'Crohn disease', 'inflammatory bowel disease', 'polycystic ovary syndrome', 'Sjogren syndrome', 'juvenile dermatomyositis', 'primary biliary cholangitis', 'glioblastoma', 'atypical teratoid rhabdoid tumor']
# Predicted MONDO Names: ['large cell medulloblastoma', 'rheumatoid arthritis', 'malignant glioma', 'osteosarcoma', 'Crohn disease', 'inflammatory bowel disease', 'juvenile dermatomyositis', 'primary biliary cholangitis', 'glioblastoma', 'atypical teratoid rhabdoid tumor']
#
# Sample 24
# True MONDO Names: ['breast carcinoma', 'hepatocellular carcinoma', 'MALT lymphoma', 'collecting duct carcinoma', 'invasive ductal breast carcinoma', 'ovarian cancer', 'subependymal giant cell astrocytoma', 'rheumatoid arthritis', 'lysosomal storage disease', 'lung carcinoma', 'neuronal ceroid lipofuscinosis 10', 'lung cancer', 'myocardial infarction', 'kidney disease', 'Alzheimer disease', 'osteoarthritis susceptibility 1', 'papillary renal cell carcinoma', 'diabetes mellitus', 'sarcomatoid renal cell carcinoma', 'prostate cancer', 'inborn errors of metabolism', 'inflammatory bowel disease', 'neurodegenerative disease', 'osteoarthritis', 'myopathy', 'clear cell renal carcinoma', 'ulcerative colitis', 'amyotrophic lateral sclerosis type 1', 'neuronal ceroid lipofuscinosis', 'renal carcinoma', 'intellectual disability', 'glioblastoma', 'renal cell carcinoma', 'chromophobe renal cell carcinoma']
# Predicted MONDO Names: ['large cell medulloblastoma', 'collecting duct carcinoma', 'ovarian cancer', 'lysosomal storage disease', 'neuronal ceroid lipofuscinosis 10', 'lung cancer', 'psoriasis', 'Alzheimer disease', 'osteoarthritis susceptibility 1', 'papillary renal cell carcinoma', 'osteosarcoma', 'sarcomatoid renal cell carcinoma', 'prostate cancer', 'neurodegenerative disease', 'clear cell renal carcinoma', 'ulcerative colitis', 'amyotrophic lateral sclerosis type 1', 'neuronal ceroid lipofuscinosis', 'renal carcinoma', 'renal cell carcinoma', 'chromophobe renal cell carcinoma']
#
# Sample 25
# True MONDO Names: ['thyroid cancer', 'malignant colon neoplasm', 'kidney failure', 'cerebrovascular disorder', 'granular cell carcinoma', 'cutaneous melanoma', 'colon carcinoma', 'breast carcinoma', 'hepatocellular carcinoma', 'type 2 diabetes mellitus', 'large cell medulloblastoma', 'ductal breast carcinoma in situ', 'pancreatic neoplasm', 'interstitial cystitis', 'inherited lipid metabolism disorder', 'MALT lymphoma', 'malignant pancreatic neoplasm', 'non-small cell lung carcinoma', 'Hashimoto thyroiditis', 'hyperinsulinism', 'liver cancer', 'breast fibroadenoma', 'ACTH-dependent Cushing syndrome', 'thyroid adenoma', 'esophageal adenocarcinoma', 'invasive ductal breast carcinoma', 'ileocolitis', 'atopic eczema', 'thyroid cancer, nonmedullary, 2', 'pancreatic intraductal papillary-mucinous neoplasm', 'acute lung injury', 'tuberculosis', 'glioma susceptibility 1', 'gastric neoplasm', 'lung carcinoma', 'melanoma', 'hereditary diffuse gastric adenocarcinoma', 'ischemic disease', 'primitive neuroectodermal tumor', 'atherosclerosis', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'psoriasis', 'thyroid gland papillary carcinoma', 'colonic neoplasm', 'metabolic disease', 'malignant glioma', 'medulloblastoma', 'familial partial lipodystrophy', 'kidney disease', 'Alzheimer disease', 'osteoarthritis susceptibility 1', 'leprosy', 'cribriform carcinoma of breast', 'lipodystrophy', 'tubular adenocarcinoma', 'coronary artery disease', 'prediabetes syndrome', 'diabetes mellitus', 'osteosarcoma', 'congenital generalized lipodystrophy', 'lysosomal lipid storage disorder', 'hypertensive disorder', 'benign colon neoplasm', 'lipoatrophic diabetes', 'non-alcoholic fatty liver disease', 'monogenic obesity', 'Crohn disease', 'neurodegenerative disease', 'hyperglycemia', 'maturity-onset diabetes of the young', 'osteoarthritis', 'PPARG-related familial partial lipodystrophy', 'pustulosis palmaris et plantaris', 'heart failure', 'Barrett esophagus', 'colorectal carcinoma', 'malignant ependymoma', 'ischemia reperfusion injury', 'T-cell non-Hodgkin lymphoma', 'acute kidney failure', 'acquired metabolic disease', 'polycystic kidney disease 2', 'autoimmune disease', 'ulcerative colitis', 'obesity disorder', 'liver disease', 'subarachnoid hemorrhage', 'congestive heart failure', 'giant cell glioblastoma', 'Cushing disease due to pituitary adenoma', 'liver neoplasm', 'lung adenocarcinoma', 'arteriosclerosis disorder', "Crohn's colitis", 'thyroid gland carcinoma', 'diabetic kidney disease', 'glomerulonephritis', 'adenocarcinoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'cribriform carcinoma', 'gastric cancer', 'leukostasis', 'inborn carbohydrate metabolic disorder', 'cancer', 'colorectal cancer', 'autosomal dominant polycystic kidney disease', 'antiphospholipid syndrome', 'schizophrenia', 'gliosarcoma']
# Predicted MONDO Names: ['thyroid cancer', 'malignant colon neoplasm', 'kidney failure', 'cerebrovascular disorder', 'granular cell carcinoma', 'cutaneous melanoma', 'colon carcinoma', 'breast carcinoma', 'hepatocellular carcinoma', 'type 2 diabetes mellitus', 'large cell medulloblastoma', 'ductal breast carcinoma in situ', 'pancreatic neoplasm', 'interstitial cystitis', 'inherited lipid metabolism disorder', 'MALT lymphoma', 'malignant pancreatic neoplasm', 'non-small cell lung carcinoma', 'Hashimoto thyroiditis', 'hyperinsulinism', 'liver cancer', 'breast fibroadenoma', 'ACTH-dependent Cushing syndrome', 'thyroid adenoma', 'esophageal adenocarcinoma', 'invasive ductal breast carcinoma', 'ileocolitis', 'atopic eczema', 'thyroid cancer, nonmedullary, 2', 'pancreatic intraductal papillary-mucinous neoplasm', 'acute lung injury', 'tuberculosis', 'glioma susceptibility 1', 'gastric neoplasm', 'lung carcinoma', 'melanoma', 'hereditary diffuse gastric adenocarcinoma', 'ischemic disease', 'primitive neuroectodermal tumor', 'atherosclerosis', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'psoriasis', 'thyroid gland papillary carcinoma', 'colonic neoplasm', 'metabolic disease', 'malignant glioma', 'medulloblastoma', 'familial partial lipodystrophy', 'kidney disease', 'Alzheimer disease', 'osteoarthritis susceptibility 1', 'leprosy', 'cribriform carcinoma of breast', 'lipodystrophy', 'tubular adenocarcinoma', 'coronary artery disease', 'prediabetes syndrome', 'diabetes mellitus', 'osteosarcoma', 'congenital generalized lipodystrophy', 'lysosomal lipid storage disorder', 'hypertensive disorder', 'benign colon neoplasm', 'lipoatrophic diabetes', 'non-alcoholic fatty liver disease', 'monogenic obesity', 'Crohn disease', 'neurodegenerative disease', 'hyperglycemia', 'maturity-onset diabetes of the young', 'osteoarthritis', 'PPARG-related familial partial lipodystrophy', 'pustulosis palmaris et plantaris', 'heart failure', 'Barrett esophagus', 'colorectal carcinoma', 'malignant ependymoma', 'ischemia reperfusion injury', 'T-cell non-Hodgkin lymphoma', 'acute kidney failure', 'acquired metabolic disease', 'polycystic kidney disease 2', 'autoimmune disease', 'ulcerative colitis', 'obesity disorder', 'liver disease', 'subarachnoid hemorrhage', 'congestive heart failure', 'giant cell glioblastoma', 'Cushing disease due to pituitary adenoma', 'liver neoplasm', 'lung adenocarcinoma', 'arteriosclerosis disorder', "Crohn's colitis", 'thyroid gland carcinoma', 'diabetic kidney disease', 'glomerulonephritis', 'adenocarcinoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'cribriform carcinoma', 'gastric cancer', 'leukostasis', 'inborn carbohydrate metabolic disorder', 'cancer', 'colorectal cancer', 'autosomal dominant polycystic kidney disease', 'antiphospholipid syndrome', 'schizophrenia', 'gliosarcoma']
#
# Sample 26
# True MONDO Names: ['malignant mesothelioma', 'esophageal squamous cell carcinoma', 'gastric neoplasm', 'lung carcinoma', 'hereditary diffuse gastric adenocarcinoma', 'benign mesothelioma', 'xeroderma pigmentosum', 'malignant glioma', 'medulloblastoma', 'osteosarcoma', 'spinocerebellar ataxia, autosomal recessive 26', 'stomatitis', 'prostate cancer', 'neurodegenerative disease', 'mixed glioma', 'mesothelioma', 'glioma', 'gastric cancer', 'cancer', 'colorectal cancer', 'childhood acute lymphoblastic leukemia', 'schizophrenia']
# Predicted MONDO Names: ['ovarian cancer', 'gastric neoplasm', 'psoriasis', 'benign mesothelioma', 'xeroderma pigmentosum', 'osteosarcoma', 'spinocerebellar ataxia, autosomal recessive 26', 'stomatitis', 'mesothelioma']
#
# Sample 27
# True MONDO Names: ['gout', 'thyroid cancer', 'urticaria', 'depressive disorder', 'malignant colon neoplasm', 'dermatomyositis', 'cerebrovascular disorder', 'granular cell carcinoma', 'anthracosis', 'breast carcinoma', 'hepatocellular carcinoma', 'type 2 diabetes mellitus', 'malignant mesothelioma', 'interstitial cystitis', 'pneumonitis', 'inherited lipid metabolism disorder', 'lymphopenia', 'diarrheal disease', 'malignant pancreatic neoplasm', 'HIV wasting syndrome', 'MERRF syndrome', 'muscle tissue disease', 'gastric carcinoma', 'non-small cell lung carcinoma', 'idiopathic interstitial pneumonia', 'interstitial lung disease', 'thyroid adenoma', 'colitis', 'pyogenic arthritis-pyoderma gangrenosum-acne syndrome', 'pneumonia', 'arthritic joint disease', 'lymphatic system disease', 'learning disability', 'atopic eczema', 'brain injury', 'synovitis', 'mood disorder', 'asthma', 'major depressive disorder', 'visual epilepsy', 'rheumatoid arthritis', 'tuberculosis', 'gastric neoplasm', 'lung carcinoma', 'hypotensive disorder', 'hereditary diffuse gastric adenocarcinoma', 'atherosclerosis', 'dementia', 'lung cancer', 'psoriasis', 'toxic encephalopathy', 'colonic neoplasm', 'peritonitis', 'pulmonary fibrosis', 'gastrointestinal mucositis', 'bipolar disorder', 'familial Mediterranean fever', 'burn', 'Kearns-Sayre syndrome', 'malignant glioma', 'mevalonic aciduria', 'myocardial infarction', 'cutaneous leishmaniasis', 'extrahepatic cholestasis', 'kidney disease', 'pleurisy', 'endometriosis', 'eye disease', 'Alzheimer disease', 'multiple sclerosis', 'osteoarthritis susceptibility 1', 'bronchopulmonary dysplasia', 'cribriform carcinoma of breast', 'allergic rhinitis', 'hemolytic-uremic syndrome', 'tubular adenocarcinoma', 'coronary artery disease', 'epilepsy', 'infectious meningitis', 'hypertensive disorder', 'allergic disease', 'hypoglycemia', 'thrombotic disease', 'benign colon neoplasm', 'leukopenia', 'sleep-wake disorder', 'silicosis', 'non-alcoholic fatty liver disease', 'breast cancer', 'cutaneous lupus erythematosus', 'Crohn disease', 'influenza', 'neurodegenerative disease', 'hyperglycemia', 'osteoarthritis', 'pustulosis palmaris et plantaris', 'heart failure', 'Barrett esophagus', 'myocardial ischemia', 'dermatitis, atopic', 'malignant ependymoma', 'ischemia reperfusion injury', 'myopathy', 'lung benign neoplasm', 'progressive external ophthalmoplegia', 'visceral leishmaniasis', 'pulmonary edema', 'polymyositis', 'neutropenia', 'Leber hereditary optic neuropathy', 'pancreatitis', 'autoimmune disease', 'muscular disease', 'ulcerative colitis', 'alopecia areata', 'obesity disorder', 'liver disease', 'benign neoplasm', 'congestive heart failure', 'chronic atrophic gastritis', 'inherited disease susceptibility', 'gastric ulcer', 'giant cell glioblastoma', 'inborn mitochondrial myopathy', 'manganese poisoning', 'vasculitis', 'lung adenocarcinoma', 'brain ischemia', 'heart valve disease', 'juvenile dermatomyositis', 'peptic ulcer disease', 'skin disease', 'thyroid gland carcinoma', 'MELAS syndrome', 'glomerulonephritis', 'adenocarcinoma', 'adenoma', 'drug-induced liver injury', 'pilocytic astrocytoma', 'postmenopausal osteoporosis', 'periodontitis', 'chronic obstructive pulmonary disease', 'cribriform carcinoma', 'middle cerebral artery infarction', 'glioblastoma', 'cardiomyopathy', 'gastric cancer', 'peripheral neuropathy', 'exocrine pancreatic carcinoma', 'trigeminal neuralgia', 'acne', 'HIV infectious disease', 'head and neck cancer', 'inborn carbohydrate metabolic disorder', 'cystic fibrosis', 'cancer', 'calcinosis', 'COVID-19', 'adult acute respiratory distress syndrome', 'schizophrenia', 'heart disease']
# Predicted MONDO Names: ['gout', 'thyroid cancer', 'urticaria', 'depressive disorder', 'malignant colon neoplasm', 'dermatomyositis', 'cerebrovascular disorder', 'granular cell carcinoma', 'anthracosis', 'breast carcinoma', 'hepatocellular carcinoma', 'type 2 diabetes mellitus', 'malignant mesothelioma', 'interstitial cystitis', 'pneumonitis', 'inherited lipid metabolism disorder', 'lymphopenia', 'diarrheal disease', 'malignant pancreatic neoplasm', 'HIV wasting syndrome', 'MERRF syndrome', 'muscle tissue disease', 'gastric carcinoma', 'non-small cell lung carcinoma', 'idiopathic interstitial pneumonia', 'interstitial lung disease', 'thyroid adenoma', 'colitis', 'pyogenic arthritis-pyoderma gangrenosum-acne syndrome', 'pneumonia', 'arthritic joint disease', 'lymphatic system disease', 'learning disability', 'atopic eczema', 'brain injury', 'synovitis', 'mood disorder', 'asthma', 'major depressive disorder', 'visual epilepsy', 'rheumatoid arthritis', 'tuberculosis', 'gastric neoplasm', 'lung carcinoma', 'hypotensive disorder', 'hereditary diffuse gastric adenocarcinoma', 'atherosclerosis', 'dementia', 'lung cancer', 'psoriasis', 'toxic encephalopathy', 'colonic neoplasm', 'peritonitis', 'pulmonary fibrosis', 'gastrointestinal mucositis', 'bipolar disorder', 'familial Mediterranean fever', 'burn', 'Kearns-Sayre syndrome', 'malignant glioma', 'mevalonic aciduria', 'myocardial infarction', 'cutaneous leishmaniasis', 'extrahepatic cholestasis', 'kidney disease', 'pleurisy', 'endometriosis', 'eye disease', 'Alzheimer disease', 'multiple sclerosis', 'osteoarthritis susceptibility 1', 'bronchopulmonary dysplasia', 'cribriform carcinoma of breast', 'allergic rhinitis', 'hemolytic-uremic syndrome', 'tubular adenocarcinoma', 'coronary artery disease', 'epilepsy', 'infectious meningitis', 'hypertensive disorder', 'allergic disease', 'hypoglycemia', 'thrombotic disease', 'benign colon neoplasm', 'leukopenia', 'sleep-wake disorder', 'silicosis', 'non-alcoholic fatty liver disease', 'breast cancer', 'cutaneous lupus erythematosus', 'Crohn disease', 'influenza', 'neurodegenerative disease', 'hyperglycemia', 'osteoarthritis', 'pustulosis palmaris et plantaris', 'heart failure', 'Barrett esophagus', 'myocardial ischemia', 'dermatitis, atopic', 'malignant ependymoma', 'ischemia reperfusion injury', 'myopathy', 'lung benign neoplasm', 'progressive external ophthalmoplegia', 'visceral leishmaniasis', 'pulmonary edema', 'polymyositis', 'neutropenia', 'Leber hereditary optic neuropathy', 'pancreatitis', 'autoimmune disease', 'muscular disease', 'ulcerative colitis', 'alopecia areata', 'obesity disorder', 'liver disease', 'benign neoplasm', 'congestive heart failure', 'chronic atrophic gastritis', 'inherited disease susceptibility', 'gastric ulcer', 'giant cell glioblastoma', 'inborn mitochondrial myopathy', 'manganese poisoning', 'vasculitis', 'lung adenocarcinoma', 'brain ischemia', 'heart valve disease', 'juvenile dermatomyositis', 'peptic ulcer disease', 'skin disease', 'thyroid gland carcinoma', 'MELAS syndrome', 'glomerulonephritis', 'adenocarcinoma', 'adenoma', 'drug-induced liver injury', 'pilocytic astrocytoma', 'postmenopausal osteoporosis', 'periodontitis', 'chronic obstructive pulmonary disease', 'cribriform carcinoma', 'middle cerebral artery infarction', 'glioblastoma', 'cardiomyopathy', 'gastric cancer', 'peripheral neuropathy', 'exocrine pancreatic carcinoma', 'trigeminal neuralgia', 'acne', 'HIV infectious disease', 'head and neck cancer', 'inborn carbohydrate metabolic disorder', 'cystic fibrosis', 'cancer', 'calcinosis', 'COVID-19', 'adult acute respiratory distress syndrome', 'schizophrenia', 'heart disease']
#
# Sample 28
# True MONDO Names: ['Duchenne muscular dystrophy', 'malignant colon neoplasm', 'epilepsy with generalized tonic-clonic seizures', 'granular cell carcinoma', 'hepatocellular carcinoma', 'large cell medulloblastoma', 'malignant mesothelioma', 'esophageal squamous cell carcinoma', 'MALT lymphoma', 'malignant pancreatic neoplasm', 'gastric carcinoma', 'non-small cell lung carcinoma', 'limb-girdle muscular dystrophy', 'osteopetrosis', 'pancreatic intraductal papillary-mucinous neoplasm', 'asthma', 'open-angle glaucoma', 'Lennox-Gastaut syndrome', 'tuberculosis', 'gastric neoplasm', 'lung carcinoma', 'hereditary diffuse gastric adenocarcinoma', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'renal tubular acidosis', 'pituitary cancer', 'medulloblastoma', 'ocular hypertension', 'cribriform carcinoma of breast', 'tubular adenocarcinoma', 'autosomal recessive osteopetrosis 3', 'breast cancer', 'Barrett esophagus', 'Down syndrome', 'childhood absence epilepsy', 'ulcerative colitis', 'lung adenocarcinoma', 'osteoporosis', 'angle-closure glaucoma', 'adenocarcinoma', 'intellectual disability', 'cribriform carcinoma', 'gastric cancer', 'exocrine pancreatic carcinoma', 'cystic fibrosis']
# Predicted MONDO Names: ['Duchenne muscular dystrophy', 'malignant colon neoplasm', 'epilepsy with generalized tonic-clonic seizures', 'granular cell carcinoma', 'hepatocellular carcinoma', 'large cell medulloblastoma', 'malignant mesothelioma', 'esophageal squamous cell carcinoma', 'MALT lymphoma', 'malignant pancreatic neoplasm', 'gastric carcinoma', 'non-small cell lung carcinoma', 'limb-girdle muscular dystrophy', 'osteopetrosis', 'pancreatic intraductal papillary-mucinous neoplasm', 'asthma', 'open-angle glaucoma', 'Lennox-Gastaut syndrome', 'tuberculosis', 'gastric neoplasm', 'lung carcinoma', 'hereditary diffuse gastric adenocarcinoma', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'renal tubular acidosis', 'pituitary cancer', 'medulloblastoma', 'ocular hypertension', 'cribriform carcinoma of breast', 'tubular adenocarcinoma', 'autosomal recessive osteopetrosis 3', 'breast cancer', 'Barrett esophagus', 'Down syndrome', 'childhood absence epilepsy', 'ulcerative colitis', 'lung adenocarcinoma', 'osteoporosis', 'angle-closure glaucoma', 'adenocarcinoma', 'intellectual disability', 'cribriform carcinoma', 'gastric cancer', 'exocrine pancreatic carcinoma', 'cystic fibrosis']
#
# Sample 29
# True MONDO Names: ['ovarian cancer', 'attention deficit hyperactivity disorder, inattentive type', 'chronic obstructive pulmonary disease']
# Predicted MONDO Names: ['ovarian cancer', 'osteosarcoma']
#
# Sample 30
# ...
#
# Sample 46
# True MONDO Names: ['aplastic anemia', 'ovarian cancer', 'hematopoietic and lymphoid system neoplasm', 'Diamond-Blackfan anemia', 'lung cancer', 'psoriasis', 'medulloblastoma', 'Diamond-Blackfan anemia 15 with mandibulofacial dysostosis', 'inherited aplastic anemia', 'osteosarcoma', 'cutaneous lupus erythematosus', 'congenital anemia', 'metabolic syndrome X', 'heart disease']
# Predicted MONDO Names: ['lung cancer']
#
# Sample 47
# True MONDO Names: []
# Predicted MONDO Names: []
#
# Sample 48
# True MONDO Names: ['malignant colon neoplasm', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'gastric neoplasm', 'hereditary diffuse gastric adenocarcinoma', 'Behcet disease', 'Diamond-Blackfan anemia', 'lung cancer', 'psoriasis', 'medulloblastoma', 'gallbladder disease', 'diabetes mellitus', 'osteosarcoma', 'non-alcoholic fatty liver disease', 'Crohn disease', 'inflammatory bowel disease', 'lymphoplasmacytic lymphoma', 'myopathy', 'congenital anemia', 'plasma cell myeloma', 'cholelithiasis', 'attention deficit hyperactivity disorder, inattentive type', 'dental caries', 'gastric cancer', 'colorectal cancer']
# Predicted MONDO Names: []
#
# Sample 49
# True MONDO Names: ['large cell medulloblastoma', 'lung cancer', 'Crohn disease', 'glioblastoma']
# Predicted MONDO Names: ['ovarian cancer', 'lung cancer', 'plasma cell myeloma', 'lung adenocarcinoma']
#
# Sample 50
# True MONDO Names: ['aplastic anemia', 'prostate carcinoma', 'hematopoietic and lymphoid system neoplasm', 'Diamond-Blackfan anemia', 'Diamond-Blackfan anemia 17', 'inherited aplastic anemia', 'congenital anemia']
# Predicted MONDO Names: ['aplastic anemia', 'hematopoietic and lymphoid system neoplasm', 'Diamond-Blackfan anemia', 'lung cancer', 'Diamond-Blackfan anemia 17', 'inherited aplastic anemia', 'diabetes mellitus', 'congenital anemia']
#
# Sample 51
# True MONDO Names: ['hepatocellular carcinoma', 'malignant pancreatic neoplasm', 'gastric carcinoma', 'ovarian cancer', 'tuberculosis', 'lymphoplasmacytic lymphoma', 'peripheral nervous system disease', 'attention deficit hyperactivity disorder, inattentive type', 'gastric cancer', 'peripheral neuropathy', 'exocrine pancreatic carcinoma']
# Predicted MONDO Names: ['ovarian cancer']
#
# Sample 52
# True MONDO Names: ['Graves disease', 'hepatocellular carcinoma', 'malignant mesothelioma', 'ductal breast carcinoma in situ', 'interstitial cystitis', 'malignant pancreatic neoplasm', 'gastric carcinoma', 'invasive ductal breast carcinoma', 'ovarian cancer', 'atrial fibrillation, familial, 1', 'atrial fibrillation, familial, 9', 'tuberculosis', 'primitive neuroectodermal tumor', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'psoriasis', 'oligodendroglioma', 'catecholaminergic polymorphic ventricular tachycardia', 'medulloblastoma', 'short QT syndrome type 3', 'Andersen-Tawil syndrome', 'familial atrial fibrillation', 'endometriosis', 'familial periodic paralysis', 'adrenal cortex carcinoma', 'breast cancer', 'atrial fibrillation', 'malignant ependymoma', 'Down syndrome', 'sarcoidosis', 'ulcerative colitis', 'ventricular tachycardia', 'long QT syndrome', 'short QT syndrome', 'lung adenocarcinoma', 'skin disease', 'astrocytic tumor', 'cardiomyopathy', 'short QT syndrome type 1', 'gastric cancer', 'exocrine pancreatic carcinoma', 'cystic fibrosis', 'autosomal dominant cardiac arrhythmia (Kuhn)', 'heart disease']
# Predicted MONDO Names: ['Pick disease', 'large cell medulloblastoma', 'malignant mesothelioma', 'non-small cell lung carcinoma', 'atrial fibrillation, familial, 9', 'lung carcinoma', 'Becker muscular dystrophy', 'primitive neuroectodermal tumor', 'oligodendroglioma', 'catecholaminergic polymorphic ventricular tachycardia', 'bipolar disorder', 'malignant glioma', 'medulloblastoma', 'short QT syndrome type 3', 'Andersen-Tawil syndrome', 'familial periodic paralysis', 'epilepsy', 'breast cancer', 'malignant ependymoma', 'Down syndrome', 'ventricular tachycardia', 'long QT syndrome', 'short QT syndrome', 'lung adenocarcinoma', 'astrocytic tumor', 'pilocytic astrocytoma', 'intellectual disability', 'short QT syndrome type 1', 'autosomal dominant cardiac arrhythmia (Kuhn)', 'atypical teratoid rhabdoid tumor']
#
# Sample 53
# True MONDO Names: ['disorder of glutamate decarboxylase', 'breast carcinoma', 'coloboma', 'bone disease', 'erectile dysfunction', 'gastric neoplasm', 'hereditary diffuse gastric adenocarcinoma', 'acute myeloid leukemia', 'epilepsy', 'breast cancer', 'pyridoxine-dependent epilepsy', 'pyridoxine-dependent epilepsy caused by ALDH7A1 mutant', 'osteoporosis', 'intellectual disability', 'chronic kidney disease', 'gastric cancer', 'cystic fibrosis', 'colorectal cancer']
# Predicted MONDO Names: ['disorder of glutamate decarboxylase', 'coloboma', 'bone disease', 'erectile dysfunction', 'gastric neoplasm', 'hereditary diffuse gastric adenocarcinoma', 'acute myeloid leukemia', 'pyridoxine-dependent epilepsy', 'pyridoxine-dependent epilepsy caused by ALDH7A1 mutant', 'pancreatic ductal adenocarcinoma', 'osteoporosis', 'intellectual disability', 'gastric cancer']
#
# Sample 54
# True MONDO Names: []
# Predicted MONDO Names: []
#
# Sample 55
# True MONDO Names: ['ovarian cancer', 'lung cancer', 'psoriasis', 'medulloblastoma', 'osteosarcoma']
# Predicted MONDO Names: ['ovarian cancer', 'medulloblastoma', 'osteosarcoma']
#
# Sample 56
# True MONDO Names: ['Duchenne muscular dystrophy', 'dermatomyositis', 'large cell medulloblastoma', 'ductal breast carcinoma in situ', 'interstitial cystitis', 'malignant pancreatic neoplasm', 'non-small cell lung carcinoma', 'limb-girdle muscular dystrophy', 'amelogenesis imperfecta type 1H', 'nasopharyngeal carcinoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'lung carcinoma', 'Becker muscular dystrophy', 'hereditary spastic paraplegia', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'cholangitis', 'malignant glioma', 'breast cancer', 'chronic hepatitis C virus infection', 'inflammatory bowel disease', 'Emery-Dreifuss muscular dystrophy', 'myopathy', 'amelogenesis imperfecta', 'autoimmune disease', 'liver disease', 'pancreatic ductal adenocarcinoma', 'lung adenocarcinoma', 'intellectual disability', 'pancreatic intraductal papillary-mucinous carcinoma', 'glioblastoma', 'pulmonary emphysema', 'head and neck cancer', 'atypical teratoid rhabdoid tumor', 'membranous glomerulonephritis']
# Predicted MONDO Names: ['malignant colon neoplasm', 'breast carcinoma', 'large cell medulloblastoma', 'malignant pancreatic neoplasm', 'non-small cell lung carcinoma', 'limb-girdle muscular dystrophy', 'amelogenesis imperfecta type 1H', 'nasopharyngeal carcinoma', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'lung carcinoma', 'Becker muscular dystrophy', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'cholangitis', 'malignant glioma', 'medulloblastoma', 'osteosarcoma', 'breast cancer', 'chronic hepatitis C virus infection', 'malignant ependymoma', 'amelogenesis imperfecta', 'ulcerative colitis', 'pancreatic ductal adenocarcinoma', 'lung adenocarcinoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'pulmonary emphysema', 'atypical teratoid rhabdoid tumor']
#
# Sample 57
# True MONDO Names: ['large cell medulloblastoma', 'malignant mesothelioma', 'interstitial cystitis', 'gastric carcinoma', 'non-small cell lung carcinoma', 'ovarian cancer', 'tuberculosis', 'lung carcinoma', 'psoriasis', 'pituitary cancer', 'medulloblastoma', 'osteosarcoma', 'breast cancer', 'malignant ependymoma', 'Sjogren syndrome', 'IgA glomerulonephritis', 'pilocytic astrocytoma', 'atypical teratoid rhabdoid tumor']
# Predicted MONDO Names: ['breast carcinoma', 'large cell medulloblastoma', 'malignant mesothelioma', 'non-small cell lung carcinoma', 'invasive ductal breast carcinoma', 'ovarian cancer', 'lung cancer', 'psoriasis', 'malignant glioma', 'medulloblastoma', 'osteosarcoma', 'malignant ependymoma', 'hematologic disease', 'pilocytic astrocytoma', 'glioblastoma', 'atypical teratoid rhabdoid tumor']
#
# Sample 58
# True MONDO Names: ['Duchenne muscular dystrophy', 'dermatomyositis', 'breast carcinoma', 'ductal breast carcinoma in situ', 'interstitial cystitis', 'malignant pancreatic neoplasm', 'non-small cell lung carcinoma', 'limb-girdle muscular dystrophy', 'esophageal adenocarcinoma', 'invasive ductal breast carcinoma', 'ovarian cancer', 'tuberculosis', 'lung carcinoma', 'Becker muscular dystrophy', 'primitive neuroectodermal tumor', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'psoriasis', 'malignant glioma', 'medulloblastoma', 'diabetes mellitus', 'osteosarcoma', 'B-cell chronic lymphocytic leukemia', 'breast cancer', 'cutaneous lupus erythematosus', 'Crohn disease', 'lymphoplasmacytic lymphoma', 'Barrett esophagus', 'Emery-Dreifuss muscular dystrophy', 'malignant ependymoma', 'familial visceral amyloidosis', 'acquired metabolic disease', 'ulcerative colitis', 'Sjogren syndrome', 'nephrosclerosis', 'lung adenocarcinoma', 'amyloidosis', 'juvenile dermatomyositis', 'pilocytic astrocytoma', 'attention deficit hyperactivity disorder, inattentive type', 'pancreatic intraductal papillary-mucinous carcinoma', 'chronic kidney disease', 'glioblastoma', 'periodic fever syndrome', 'atypical teratoid rhabdoid tumor', 'sinusitis']
# Predicted MONDO Names: ['Duchenne muscular dystrophy', 'dermatomyositis', 'breast carcinoma', 'ductal breast carcinoma in situ', 'interstitial cystitis', 'malignant pancreatic neoplasm', 'non-small cell lung carcinoma', 'limb-girdle muscular dystrophy', 'esophageal adenocarcinoma', 'invasive ductal breast carcinoma', 'ovarian cancer', 'tuberculosis', 'lung carcinoma', 'Becker muscular dystrophy', 'primitive neuroectodermal tumor', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'psoriasis', 'malignant glioma', 'medulloblastoma', 'diabetes mellitus', 'osteosarcoma', 'B-cell chronic lymphocytic leukemia', 'breast cancer', 'cutaneous lupus erythematosus', 'Crohn disease', 'lymphoplasmacytic lymphoma', 'Barrett esophagus', 'Emery-Dreifuss muscular dystrophy', 'malignant ependymoma', 'familial visceral amyloidosis', 'acquired metabolic disease', 'ulcerative colitis', 'Sjogren syndrome', 'nephrosclerosis', 'lung adenocarcinoma', 'amyloidosis', 'juvenile dermatomyositis', 'pilocytic astrocytoma', 'attention deficit hyperactivity disorder, inattentive type', 'pancreatic intraductal papillary-mucinous carcinoma', 'chronic kidney disease', 'glioblastoma', 'periodic fever syndrome', 'atypical teratoid rhabdoid tumor', 'sinusitis']
#
# Sample 59
# True MONDO Names: ['ovarian cancer', 'lung cancer', 'medulloblastoma', 'diabetes mellitus', 'lymphoplasmacytic lymphoma', 'plasma cell myeloma', 'chronic obstructive pulmonary disease', 'heart disease']
# Predicted MONDO Names: ['ovarian cancer', 'lung cancer', 'medulloblastoma', 'lymphoplasmacytic lymphoma']
#
# Sample 60
# True MONDO Names: ['acute myeloid leukemia']
# Predicted MONDO Names: ['large cell medulloblastoma', 'medulloblastoma', 'breast cancer']
#
# Sample 61
# True MONDO Names: ['large cell medulloblastoma', 'malignant mesothelioma', 'malignant pancreatic neoplasm', 'interstitial lung disease', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'subependymal giant cell astrocytoma', 'dementia', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'psoriasis', 'toxic encephalopathy', 'Alzheimer disease', 'osteosarcoma', 'Crohn disease', 'malignant ependymoma', 'pancreatic ductal adenocarcinoma', 'amyloidosis', 'pancreatic intraductal papillary-mucinous carcinoma', 'atypical teratoid rhabdoid tumor', 'schizophrenia']
# Predicted MONDO Names: ['large cell medulloblastoma', 'malignant mesothelioma', 'malignant pancreatic neoplasm', 'interstitial lung disease', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'subependymal giant cell astrocytoma', 'dementia', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'psoriasis', 'toxic encephalopathy', 'Alzheimer disease', 'osteosarcoma', 'Crohn disease', 'malignant ependymoma', 'pancreatic ductal adenocarcinoma', 'amyloidosis', 'pancreatic intraductal papillary-mucinous carcinoma', 'atypical teratoid rhabdoid tumor', 'schizophrenia']
#
# Sample 62
# True MONDO Names: ['Parkinson disease', 'undifferentiated carcinoma', 'systemic lupus erythematosus', 'myositis', 'rheumatoid arthritis', 'myocardial infarction', 'peripheral arterial disease', 'cleft lip', 'carcinoma of esophagus', 'carcinoma', 'systemic sclerosis', 'sarcomatoid carcinoma', 'mammary neoplasms, animal', 'colorectal cancer', 'heart disease']
# Predicted MONDO Names: []
#
# Sample 63
# True MONDO Names: ['paratuberculosis', 'Duchenne muscular dystrophy', 'malignant colon neoplasm', 'breast carcinoma', 'malignant mesothelioma', 'ductal breast carcinoma in situ', 'interstitial cystitis', 'adrenoleukodystrophy', 'malignant pancreatic neoplasm', 'breast fibroadenoma', 'esophageal adenocarcinoma', 'invasive ductal breast carcinoma', 'Finnish type amyloidosis', 'Gaucher disease', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'tuberculosis', 'lattice corneal dystrophy', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'psoriasis', 'benign mesothelioma', 'medulloblastoma', 'endometriosis', 'osteosarcoma', 'breast cancer', 'atrial fibrillation', 'Emery-Dreifuss muscular dystrophy', 'malignant ependymoma', 'acquired metabolic disease', 'mesothelioma', 'ulcerative colitis', 'pancreatic ductal adenocarcinoma', 'amyloidosis', 'osteoporosis', 'astrocytic tumor', 'drug-induced liver injury', 'pilocytic astrocytoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'acute coronary syndrome', 'chronic obstructive pulmonary disease', 'periodic fever syndrome', 'schizophrenia']
# Predicted MONDO Names: ['paratuberculosis', 'Duchenne muscular dystrophy', 'malignant colon neoplasm', 'breast carcinoma', 'malignant mesothelioma', 'ductal breast carcinoma in situ', 'interstitial cystitis', 'adrenoleukodystrophy', 'malignant pancreatic neoplasm', 'breast fibroadenoma', 'esophageal adenocarcinoma', 'invasive ductal breast carcinoma', 'Finnish type amyloidosis', 'Gaucher disease', 'pancreatic intraductal papillary-mucinous neoplasm', 'ovarian cancer', 'tuberculosis', 'lattice corneal dystrophy', 'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia', 'lung cancer', 'psoriasis', 'benign mesothelioma', 'medulloblastoma', 'endometriosis', 'osteosarcoma', 'breast cancer', 'atrial fibrillation', 'Emery-Dreifuss muscular dystrophy', 'malignant ependymoma', 'acquired metabolic disease', 'mesothelioma', 'ulcerative colitis', 'pancreatic ductal adenocarcinoma', 'amyloidosis', 'osteoporosis', 'astrocytic tumor', 'drug-induced liver injury', 'pilocytic astrocytoma', 'pancreatic intraductal papillary-mucinous carcinoma', 'acute coronary syndrome', 'chronic obstructive pulmonary disease', 'periodic fever syndrome', 'schizophrenia']
#
# Sample 64
# True MONDO Names: ['ankylosing spondylitis', 'malignant colon neoplasm', 'dermatomyositis', 'Hashimoto thyroiditis', 'systemic lupus erythematosus', 'myositis', 'ovarian cancer', 'juvenile idiopathic arthritis', 'hypothyroidism', 'psoriasis', 'Crohn disease', 'inflammatory bowel disease', 'ulcerative colitis', 'systemic sclerosis', 'primary biliary cholangitis']
# Predicted MONDO Names: ['ankylosing spondylitis', 'Hashimoto thyroiditis', 'systemic lupus erythematosus', 'myositis', 'ovarian cancer', 'hypothyroidism', 'Crohn disease', 'inflammatory bowel disease', 'systemic sclerosis', 'primary biliary cholangitis']
#
# Total samples with zero predictions: 9
