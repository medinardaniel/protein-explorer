# %% [markdown]
# # Get Protein Data
# This notebook uses the list of entry IDs in each of the text files in the protein-data folder to fetch the protein data from PDB and Uniprot.

# %%
import requests
import json
import os
import time
from requests.exceptions import ConnectionError
from datetime import datetime

# %% [markdown]
# ## Fetch Data from PDB
# Fetch data from PDB using the entity IDs from the text files in the protein-data folder.

# %% [markdown]
# ### Get list of Protein Entry IDs

# %%
def read_protein_entry_ids(folder_path):
    """
    Reads the list of protein entry IDs in each file of the folder path
    Input: folder_path (str) - path to the folder containing the files
    Output: protein_entry_ids (list) - list of separated protein entry IDs
    """
    protein_entry_ids = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            full_path = os.path.join(folder_path, filename)
            with open(full_path, 'r') as file:
                for line in file:
                    # Splitting each line by comma and stripping whitespace
                    ids = line.strip().split(',')
                    # Extending the list by adding all ids found in the line
                    protein_entry_ids.extend([id.strip() for id in ids if id.strip()])
                
    return protein_entry_ids

# %% [markdown]
# ### Make API call to PDB for each Protein Entry ID
# Use the list protein_entry_ids to fetch the protein information for each protein from PDB.

# %%
def get_uniprot_annotations(entry_id, entity_id):
    """
    Get UniProt annotations for a given entry ID and entity ID
    Input: entry_id (str) - Protein entry ID
           entity_id (str) - Polymer entity ID
    Output: uniprot_data (dict) - Dictionary containing UniProt annotations
    """
    url = f'https://data.rcsb.org/rest/v1/core/uniprot/{entry_id}/{entity_id}'
    uniprot_data = {}  # Initialize uniprot_data outside try-except

    try:
        response = requests.get(url)
        response.raise_for_status()  # This will raise an HTTPError for bad responses

    except requests.HTTPError as e:  # Catching HTTP errors
        if e.response.status_code == 404:  # Specific check for a 'Not Found' error
            print(f"Data for {entry_id} - {entity_id} not found (404). Skipping...")
            return uniprot_data  # Return the empty dictionary since there's no data
        else:
            print(f"Failed to fetch data for {entry_id} - {entity_id}. Response status code: {e.response.status_code}")
            return uniprot_data  # Return the empty dictionary since there's no data

    # If the response is successful, parse the JSON and extract the data
    data = response.json()
    rcsb_uniprot_protein = data[0].get('rcsb_uniprot_protein', {})
    rcsb_uniprot_feature = data[0].get('rcsb_uniprot_feature', {})
    rcsb_uniprot_annotation = data[0].get('rcsb_uniprot_annotation', {})
    uniprot_data = {
        'rcsb_uniprot_protein': rcsb_uniprot_protein,
        'rcsb_uniprot_feature': rcsb_uniprot_feature,
        'rcsb_uniprot_annotation': rcsb_uniprot_annotation
    }

    return uniprot_data

# %%
def get_protein_data(entry_id):
    """
    Get protein data for a given entry ID
    """
        
    url = f"https://data.rcsb.org/rest/v1/core/entry/{entry_id}"
    response = requests.get(url)
    data = response.json()
    
    # Extracting required information
    protein_info = {
        'entry_id': entry_id,
        'polymer_entities': [],
        'binding_affinity': data.get('rcsb_binding_affinity', []),
        'uniprot_annotations': {}  # Initialize as empty dictionary
    }

    if 'rcsb_entry_container_identifiers' in data:
        entity_ids = data['rcsb_entry_container_identifiers'].get('polymer_entity_ids', [])

        # Extract polymer entity information if available
        for entity_id in entity_ids:
            polymer_url = f"https://data.rcsb.org/rest/v1/core/polymer_entity/{entry_id}/{entity_id}"
            polymer_response = requests.get(polymer_url)
            if polymer_response.status_code == 200:
                polymer_data = polymer_response.json()
                sequence = polymer_data.get('entity_poly', {}).get('pdbx_seq_one_letter_code', 'N/A').replace('\n', '')
                entity_type = polymer_data.get('entity_poly', {}).get('type', 'N/A')
                protein_info['polymer_entities'].append({
                    'entity_id': entity_id,
                    'type': entity_type,
                    'sequence': sequence
                })

            # Get uniprot annotations for each entity ID and add to protein_info
            protein_info['uniprot_annotations'][entity_id] = get_uniprot_annotations(entry_id, entity_id)
    
    return protein_info

# %% [markdown]
# ### Get data loop

# %%
def data_fetcher(input_dir, output_dir, last_print_time=None):
    """
    Fetches protein data for given entry IDs and saves it as JSON.
    """
    protein_entry_ids = read_protein_entry_ids(input_dir)
    max_retries = 5  # Set maximum number of retries per entry

    for entry_id in protein_entry_ids:
        # Skip if the data has already been fetched
        if os.path.exists(os.path.join(output_dir, f"{entry_id}.json")):
            print(f"Data for {entry_id} already exists. Skipping...")
            continue
        for attempt in range(max_retries):
            try:
                # Attempt to fetch data
                protein_data = get_protein_data(entry_id)
                # If successful, break out of the retry loop
                break
            except ConnectionError:
                # If a connection error occurred, wait and then retry
                print(f"Connection error for {entry_id}, attempt {attempt + 1}/{max_retries}. Retrying...")
                time.sleep(5)  # Wait for 5 seconds before retrying
            except Exception as e:
                # If another type of exception occurred, break and don't retry
                print(f"An error occurred for {entry_id}: {e}. Skipping...")
                break
        else:
            # If the loop completes normally, without breaking, then all attempts failed.
            print(f"Failed to fetch data for {entry_id} after {max_retries} attempts.")
            continue  # Skip to the next entry ID
        
        # Save the successfully fetched data
        num_files = len(os.listdir(output_dir))
        output_file = os.path.join(output_dir, f"{entry_id}.json")
        with open(output_file, 'w') as file:
            json.dump(protein_data, file, indent=4)
            current_print_time = time.time()
            print(f"Data successfully saved to {output_file}. Time:{datetime.now().strftime('%m-%d %H:%M:%S')} Total files:{num_files}")

        if last_print_time and current_print_time - last_print_time > 300:
            print("More than 5 minutes have passed since the last fetch. Re-starting the fetch process...")
            # exit loop and start the function over again
            return data_fetcher(input_dir, output_dir, current_print_time)
    
        # Wait for 1 second before fetching the next entry
        # time.sleep(1)

        # update the last_print_time with the current_print_time
        last_print_time = current_print_time
    
    print("Finished fetching data for all protein entry IDs.")

# %%
data_fetcher('protein_entry_ids', '../protein_data')
# Out:
# Data for 5AK4 already exists. Skipping...
# Data for 5AK5 already exists. Skipping...
# Data for 5AK6 already exists. Skipping...
# Data for 5AKE already exists. Skipping...
# Data for 5AKG already exists. Skipping...
# Data for 5AKH already exists. Skipping...
# Data for 5AKI already exists. Skipping...
# Data for 5AKJ already exists. Skipping...
# Data for 5AKK already exists. Skipping...
# Data for 5AKL already exists. Skipping...
# Data for 5AKS already exists. Skipping...
# Data for 5AKT already exists. Skipping...
# Data for 5AKU already exists. Skipping...
# Data for 5AKV already exists. Skipping...
# Data for 5AKW already exists. Skipping...
# Data for 5AKX already exists. Skipping...
# Data for 5AKY already exists. Skipping...
# Data for 5AKZ already exists. Skipping...
# Data for 5AL0 already exists. Skipping...
# Data for 5AL1 already exists. Skipping...
# Data for 5AL2 already exists. Skipping...
# Data for 5AL3 already exists. Skipping...
# Data for 5AL4 already exists. Skipping...
# Data for 5AL5 already exists. Skipping...
# Data for 5AL8 already exists. Skipping...
# Data for 5ALB already exists. Skipping...
# Data for 5ALC already exists. Skipping...
# Data for 5ALD already exists. Skipping...
# Data for 5ALE already exists. Skipping...
# Data for 5ALF already exists. Skipping...
# Data for 5ALG already exists. Skipping...
# Data for 5ALH already exists. Skipping...
# Data for 5ALI already exists. Skipping...
# Data for 5ALJ already exists. Skipping...
# Data for 5ALK already exists. Skipping...
# Data for 5ALL already exists. Skipping...
# Data for 5ALM already exists. Skipping...
# Data for 5ALN already exists. Skipping...
# Data for 5ALO already exists. Skipping...
# Data for 5ALP already exists. Skipping...
# Data for 5ALQ already exists. Skipping...
# Data for 5ALR already exists. Skipping...
# Data for 5ALS already exists. Skipping...
# Data for 5ALT already exists. Skipping...
# Data for 5ALU already exists. Skipping...
# Data for 5ALV already exists. Skipping...
# Data for 5ALW already exists. Skipping...
# Data for 5ALX already exists. Skipping...
# Data for 5ALY already exists. Skipping...
# Data for 5ALZ already exists. Skipping...
# Data for 5AM0 already exists. Skipping...
# Data for 5AM1 already exists. Skipping...
# Data for 5AM2 already exists. Skipping...
# Data for 5AM3 already exists. Skipping...
# Data for 5AM4 already exists. Skipping...
# Data for 5AM5 already exists. Skipping...
# Data for 5AM6 already exists. Skipping...
# Data for 5AM7 already exists. Skipping...
# Data for 5AM8 already exists. Skipping...
# Data for 5AM9 already exists. Skipping...
# Data for 5AMA already exists. Skipping...
# Data for 5AMB already exists. Skipping...
# Data for 5AMC already exists. Skipping...
# Data for 5AMD already exists. Skipping...
# Data for 5AME already exists. Skipping...
# Data for 5AMF already exists. Skipping...
# Data for 5AMG already exists. Skipping...
# Data for 5AML already exists. Skipping...
# Data for 5AMN already exists. Skipping...
# Data for 5AN4 already exists. Skipping...
# Data for 5AN9 already exists. Skipping...
# Data for 5ANB already exists. Skipping...
# Data for 5ANC already exists. Skipping...
# Data for 5AND already exists. Skipping...
# Data for 5ANE already exists. Skipping...
# Data for 5ANG already exists. Skipping...
# Data for 5ANI already exists. Skipping...
# Data for 5ANJ already exists. Skipping...
# Data for 5ANK already exists. Skipping...
# Data for 5ANL already exists. Skipping...
# Data for 5ANM already exists. Skipping...
# Data for 5ANO already exists. Skipping...
# Data for 5ANQ already exists. Skipping...
# Data for 5ANR already exists. Skipping...
# Data for 5ANS already exists. Skipping...
# Data for 5ANT already exists. Skipping...
# Data for 5ANU already exists. Skipping...
# Data for 5ANV already exists. Skipping...
# Data for 5ANW already exists. Skipping...
# Data for 5AO0 already exists. Skipping...
# Data for 5AO1 already exists. Skipping...
# Data for 5AO2 already exists. Skipping...
# Data for 5AO3 already exists. Skipping...
# Data for 5AO4 already exists. Skipping...
# Data for 5AO5 already exists. Skipping...
# Data for 5AO6 already exists. Skipping...
# Data for 5AOI already exists. Skipping...
# Data for 5AOJ already exists. Skipping...
# Data for 5AOK already exists. Skipping...
# Data for 5AOL already exists. Skipping...
# Data for 5AOM already exists. Skipping...
# Data for 5AOX already exists. Skipping...
# Data for 5AP0 already exists. Skipping...
# Data for 5AP1 already exists. Skipping...
# Data for 5AP2 already exists. Skipping...
# Data for 5AP3 already exists. Skipping...
# Data for 5AP4 already exists. Skipping...
# Data for 5AP5 already exists. Skipping...
# Data for 5AP6 already exists. Skipping...
# Data for 5AP7 already exists. Skipping...
# Data for 5APA already exists. Skipping...
# Data for 5APH already exists. Skipping...
# Data for 5APJ already exists. Skipping...
# Data for 5APK already exists. Skipping...
# Data for 5AQ0 already exists. Skipping...
# Data for 5AQF already exists. Skipping...
# Data for 5AQG already exists. Skipping...
# Data for 5AQH already exists. Skipping...
# Data for 5AQI already exists. Skipping...
# Data for 5AQJ already exists. Skipping...
# Data for 5AQK already exists. Skipping...
# Data for 5AQL already exists. Skipping...
# Data for 5AQM already exists. Skipping...
# Data for 5AQN already exists. Skipping...
# Data for 5AQO already exists. Skipping...
# Data for 5AQP already exists. Skipping...
# Data for 5AQQ already exists. Skipping...
# Data for 5AQR already exists. Skipping...
# Data for 5AQS already exists. Skipping...
# Data for 5AQT already exists. Skipping...
# Data for 5AQU already exists. Skipping...
# Data for 5AQV already exists. Skipping...
# Data for 5AQW already exists. Skipping...
# Data for 5AQX already exists. Skipping...
# Data for 5AQY already exists. Skipping...
# Data for 5AQZ already exists. Skipping...
# Data for 5AR0 already exists. Skipping...
# Data for 5AR2 already exists. Skipping...
# Data for 5AR3 already exists. Skipping...
# Data for 5AR4 already exists. Skipping...
# Data for 5AR5 already exists. Skipping...
# Data for 5AR7 already exists. Skipping...
# Data for 5AR8 already exists. Skipping...
# Data for 5ARF already exists. Skipping...
# Data for 5ARG already exists. Skipping...
# Data for 5AUL already exists. Skipping...
# Data for 5AUT already exists. Skipping...
# Data for 5AUU already exists. Skipping...
# Data for 5AUV already exists. Skipping...
# Data for 5AUW already exists. Skipping...
# Data for 5AUX already exists. Skipping...
# Data for 5AUY already exists. Skipping...
# Data for 5AUZ already exists. Skipping...
# Data for 5AV0 already exists. Skipping...
# Data for 5AV1 already exists. Skipping...
# Data for 5AV2 already exists. Skipping...
# Data for 5AV3 already exists. Skipping...
# Data for 5AV4 already exists. Skipping...
# Data for 5AV5 already exists. Skipping...
# Data for 5AV6 already exists. Skipping...
# Data for 5AV8 already exists. Skipping...
# Data for 5AV9 already exists. Skipping...
# Data for 5AVB already exists. Skipping...
# Data for 5AVC already exists. Skipping...
# Data for 5AVI already exists. Skipping...
# Data for 5AVL already exists. Skipping...
# Data for 5AWA already exists. Skipping...
# Data for 5AWB already exists. Skipping...
# Data for 5AWC already exists. Skipping...
# Data for 5AWD already exists. Skipping...
# Data for 5AWJ already exists. Skipping...
# Data for 5AWK already exists. Skipping...
# Data for 5AWN already exists. Skipping...
# Data for 5AWR already exists. Skipping...
# Data for 5AWS already exists. Skipping...
# Data for 5AWT already exists. Skipping...
# Data for 5AWU already exists. Skipping...
# Data for 5AWX already exists. Skipping...
# Data for 5AX3 already exists. Skipping...
# Data for 5AX8 already exists. Skipping...
# Data for 5AX9 already exists. Skipping...
# Data for 5AXP already exists. Skipping...
# Data for 5AXQ already exists. Skipping...
# Data for 5AY8 already exists. Skipping...
# Data for 5AYF already exists. Skipping...
# Data for 5AYG already exists. Skipping...
# Data for 5AYR already exists. Skipping...
# Data for 5AYT already exists. Skipping...
# Data for 5AYX already exists. Skipping...
# Data for 5AYY already exists. Skipping...
# Data for 5AYZ already exists. Skipping...
# Data for 5AZ5 already exists. Skipping...
# Data for 5AZE already exists. Skipping...
# Data for 5AZT already exists. Skipping...
# Data for 5AZV already exists. Skipping...
# Data for 5AZW already exists. Skipping...
# Data for 5B0H already exists. Skipping...
# Data for 5B0X already exists. Skipping...
# Data for 5B0Y already exists. Skipping...
# Data for 5B0Z already exists. Skipping...
# Data for 5B16 already exists. Skipping...
# Data for 5B1L already exists. Skipping...
# Data for 5B1M already exists. Skipping...
# Data for 5B1W already exists. Skipping...
# Data for 5B1X already exists. Skipping...
# Data for 5B1Z already exists. Skipping...
# Data for 5B24 already exists. Skipping...
# Data for 5B25 already exists. Skipping...
# Data for 5B27 already exists. Skipping...
# Data for 5B28 already exists. Skipping...
# Data for 5B29 already exists. Skipping...
# Data for 5B2G already exists. Skipping...
# Data for 5B2I already exists. Skipping...
# Data for 5B2J already exists. Skipping...
# Data for 5B2K already exists. Skipping...
# Data for 5B2L already exists. Skipping...
# Data for 5B2M already exists. Skipping...
# Data for 5B2Z already exists. Skipping...
# Data for 5B30 already exists. Skipping...
# Data for 5B31 already exists. Skipping...
# Data for 5B32 already exists. Skipping...
# Data for 5B33 already exists. Skipping...
# Data for 5B38 already exists. Skipping...
# Data for 5B39 already exists. Skipping...
# Data for 5B3W already exists. Skipping...
# Data for 5B3X already exists. Skipping...
# Data for 5B3Y already exists. Skipping...
# Data for 5B3Z already exists. Skipping...
# Data for 5B40 already exists. Skipping...
# Data for 5B41 already exists. Skipping...
# Data for 5B4K already exists. Skipping...
# Data for 5B4L already exists. Skipping...
# Data for 5B4O already exists. Skipping...
# Data for 5B4P already exists. Skipping...
# Data for 5B4W already exists. Skipping...
# Data for 5B4X already exists. Skipping...
# Data for 5B4Y already exists. Skipping...
# Data for 5B5B already exists. Skipping...
# Data for 5B5O already exists. Skipping...
# Data for 5B5P already exists. Skipping...
# Data for 5B5W already exists. Skipping...
# Data for 5B6C already exists. Skipping...
# Data for 5B6G already exists. Skipping...
# Data for 5B6M already exists. Skipping...
# Data for 5B6N already exists. Skipping...
# Data for 5B71 already exists. Skipping...
# Data for 5B73 already exists. Skipping...
# Data for 5B75 already exists. Skipping...
# Data for 5B76 already exists. Skipping...
# Data for 5B77 already exists. Skipping...
# Data for 5B78 already exists. Skipping...
# Data for 5B79 already exists. Skipping...
# Data for 5B7A already exists. Skipping...
# Data for 5B7V already exists. Skipping...
# Data for 5B83 already exists. Skipping...
# Data for 5B8A already exists. Skipping...
# Data for 5B8B already exists. Skipping...
# Data for 5B8C already exists. Skipping...
# Data for 5B8D already exists. Skipping...
# Data for 5BJT already exists. Skipping...
# Data for 5BJZ already exists. Skipping...
# Data for 5BK0 already exists. Skipping...
# Data for 5BK1 already exists. Skipping...
# Data for 5BK2 already exists. Skipping...
# Data for 5BK3 already exists. Skipping...
# Data for 5BK5 already exists. Skipping...
# Data for 5BK8 already exists. Skipping...
# Data for 5BKF already exists. Skipping...
# Data for 5BKG already exists. Skipping...
# Data for 5BMF already exists. Skipping...
# Data for 5BML already exists. Skipping...
# Data for 5BMS already exists. Skipping...
# Data for 5BMU already exists. Skipping...
# Data for 5BMY already exists. Skipping...
# Data for 5BN8 already exists. Skipping...
# Data for 5BN9 already exists. Skipping...
# Data for 5BNB already exists. Skipping...
# Data for 5BNG already exists. Skipping...
# Data for 5BNH already exists. Skipping...
# Data for 5BNJ already exists. Skipping...
# Data for 5BNL already exists. Skipping...
# Data for 5BNQ already exists. Skipping...
# Data for 5BNV already exists. Skipping...
# Data for 5BNW already exists. Skipping...
# Data for 5BNX already exists. Skipping...
# Data for 5BO0 already exists. Skipping...
# Data for 5BO1 already exists. Skipping...
# Data for 5BO4 already exists. Skipping...
# Data for 5BO6 already exists. Skipping...
# Data for 5BO7 already exists. Skipping...
# Data for 5BO8 already exists. Skipping...
# Data for 5BO9 already exists. Skipping...
# Data for 5BOJ already exists. Skipping...
# Data for 5BOL already exists. Skipping...
# Data for 5BOM already exists. Skipping...
# Data for 5BON already exists. Skipping...
# Data for 5BOQ already exists. Skipping...
# Data for 5BOT already exists. Skipping...
# Data for 5BOW already exists. Skipping...
# Data for 5BOY already exists. Skipping...
# Data for 5BPA already exists. Skipping...
# Data for 5BPB already exists. Skipping...
# Data for 5BPC already exists. Skipping...
# Data for 5BPL already exists. Skipping...
# Data for 5BPM already exists. Skipping...
# Data for 5BPN already exists. Skipping...
# Data for 5BPO already exists. Skipping...
# Data for 5BPP already exists. Skipping...
# Data for 5BPQ already exists. Skipping...
# Data for 5BPU already exists. Skipping...
# Data for 5BPW already exists. Skipping...
# Data for 5BPY already exists. Skipping...
# Data for 5BQ0 already exists. Skipping...
# Data for 5BQ7 already exists. Skipping...
# Data for 5BQ8 already exists. Skipping...
# Data for 5BQB already exists. Skipping...
# Data for 5BQC already exists. Skipping...
# Data for 5BQD already exists. Skipping...
# Data for 5BQE already exists. Skipping...
# Data for 5BQG already exists. Skipping...
# Data for 5BQH already exists. Skipping...
# Data for 5BQI already exists. Skipping...
# Data for 5BQM already exists. Skipping...
# Data for 5BQQ already exists. Skipping...
# Data for 5BQX already exists. Skipping...
# Data for 5BRK already exists. Skipping...
# Data for 5BRM already exists. Skipping...
# Data for 5BRN already exists. Skipping...
# Data for 5BRO already exists. Skipping...
# Data for 5BRR already exists. Skipping...
# Data for 5BRU already exists. Skipping...
# Data for 5BRV already exists. Skipping...
# Data for 5BRW already exists. Skipping...
# Data for 5BRZ already exists. Skipping...
# Data for 5BS0 already exists. Skipping...
# Data for 5BS7 already exists. Skipping...
# Data for 5BS9 already exists. Skipping...
# Data for 5BSA already exists. Skipping...
# Data for 5BSC already exists. Skipping...
# Data for 5BSI already exists. Skipping...
# Data for 5BSJ already exists. Skipping...
# Data for 5BSK already exists. Skipping...
# Data for 5BT2 already exists. Skipping...
# Data for 5BT3 already exists. Skipping...
# Data for 5BT4 already exists. Skipping...
# Data for 5BT5 already exists. Skipping...
# Data for 5BTE already exists. Skipping...
# Data for 5BTM already exists. Skipping...
# Data for 5BTQ already exists. Skipping...
# Data for 5BTR already exists. Skipping...
# Data for 5BTS already exists. Skipping...
# Data for 5BTV already exists. Skipping...
# Data for 5BUA already exists. Skipping...
# Data for 5BUC already exists. Skipping...
# Data for 5BUE already exists. Skipping...
# Data for 5BUG already exists. Skipping...
# Data for 5BUI already exists. Skipping...
# Data for 5BUJ already exists. Skipping...
# Data for 5BUO already exists. Skipping...
# Data for 5BV6 already exists. Skipping...
# Data for 5BV7 already exists. Skipping...
# Data for 5BV8 already exists. Skipping...
# Data for 5BVD already exists. Skipping...
# Data for 5BVE already exists. Skipping...
# Data for 5BVF already exists. Skipping...
# Data for 5BVJ already exists. Skipping...
# Data for 5BVK already exists. Skipping...
# Data for 5BVN already exists. Skipping...
# Data for 5BVO already exists. Skipping...
# Data for 5BVP already exists. Skipping...
# Data for 5BVW already exists. Skipping...
# Data for 5BW7 already exists. Skipping...
# Data for 5BWA already exists. Skipping...
# Data for 5BWL already exists. Skipping...
# Data for 5BWM already exists. Skipping...
# Data for 5BWN already exists. Skipping...
# Data for 5BWO already exists. Skipping...
# Data for 5BWR already exists. Skipping...
# Data for 5BWT already exists. Skipping...
# Data for 5BWU already exists. Skipping...
# Data for 5BWV already exists. Skipping...
# Data for 5BWW already exists. Skipping...
# Data for 5BWX already exists. Skipping...
# Data for 5BWZ already exists. Skipping...
# Data for 5BX0 already exists. Skipping...
# Data for 5BX1 already exists. Skipping...
# Data for 5BX6 already exists. Skipping...
# Data for 5BX7 already exists. Skipping...
# Data for 5BXB already exists. Skipping...
# Data for 5BXC already exists. Skipping...
# Data for 5BXD already exists. Skipping...
# Data for 5BXF already exists. Skipping...
# Data for 5BXH already exists. Skipping...
# Data for 5BXJ already exists. Skipping...
# Data for 5BXO already exists. Skipping...
# Data for 5BXU already exists. Skipping...
# Data for 5BXV already exists. Skipping...
# Data for 5BYA already exists. Skipping...
# Data for 5BYB already exists. Skipping...
# Data for 5BYC already exists. Skipping...
# Data for 5BYD already exists. Skipping...
# Data for 5BYE already exists. Skipping...
# Data for 5BYF already exists. Skipping...
# Data for 5BYG already exists. Skipping...
# Data for 5BYI already exists. Skipping...
# Data for 5BYY already exists. Skipping...
# Data for 5BYZ already exists. Skipping...
# Data for 5BZ6 already exists. Skipping...
# Data for 5BZD already exists. Skipping...
# Data for 5BZW already exists. Skipping...
# Data for 5BZX already exists. Skipping...
# Data for 5BZZ already exists. Skipping...
# Data for 5C01 already exists. Skipping...
# Data for 5C03 already exists. Skipping...
# Data for 5C07 already exists. Skipping...
# Data for 5C08 already exists. Skipping...
# Data for 5C09 already exists. Skipping...
# Data for 5C0A already exists. Skipping...
# Data for 5C0B already exists. Skipping...
# Data for 5C0C already exists. Skipping...
# Data for 5C0D already exists. Skipping...
# Data for 5C0E already exists. Skipping...
# Data for 5C0F already exists. Skipping...
# Data for 5C0G already exists. Skipping...
# Data for 5C0I already exists. Skipping...
# Data for 5C0J already exists. Skipping...
# Data for 5C0K already exists. Skipping...
# Data for 5C0L already exists. Skipping...
# Data for 5C0M already exists. Skipping...
# Data for 5C0S already exists. Skipping...
# Data for 5C0V already exists. Skipping...
# Data for 5C11 already exists. Skipping...
# Data for 5C13 already exists. Skipping...
# Data for 5C14 already exists. Skipping...
# Data for 5C16 already exists. Skipping...
# Data for 5C18 already exists. Skipping...
# Data for 5C19 already exists. Skipping...
# Data for 5C1A already exists. Skipping...
# Data for 5C1B already exists. Skipping...
# Data for 5C1D already exists. Skipping...
# Data for 5C1G already exists. Skipping...
# Data for 5C1H already exists. Skipping...
# Data for 5C1L already exists. Skipping...
# Data for 5C1Q already exists. Skipping...
# Data for 5C1V already exists. Skipping...
# Data for 5C1W already exists. Skipping...
# Data for 5C1Z already exists. Skipping...
# Data for 5C23 already exists. Skipping...
# Data for 5C26 already exists. Skipping...
# Data for 5C27 already exists. Skipping...
# Data for 5C28 already exists. Skipping...
# Data for 5C29 already exists. Skipping...
# Data for 5C2A already exists. Skipping...
# Data for 5C2B already exists. Skipping...
# Data for 5C2E already exists. Skipping...
# Data for 5C2H already exists. Skipping...
# Data for 5C2J already exists. Skipping...
# Data for 5C2K already exists. Skipping...
# Data for 5C36 already exists. Skipping...
# Data for 5C37 already exists. Skipping...
# Data for 5C38 already exists. Skipping...
# Data for 5C3A already exists. Skipping...
# Data for 5C3B already exists. Skipping...
# Data for 5C3D already exists. Skipping...
# Data for 5C3F already exists. Skipping...
# Data for 5C3G already exists. Skipping...
# Data for 5C3H already exists. Skipping...
# Data for 5C3I already exists. Skipping...
# Data for 5C3K already exists. Skipping...
# Data for 5C3T already exists. Skipping...
# Data for 5C3Y already exists. Skipping...
# Data for 5C3Z already exists. Skipping...
# Data for 5C40 already exists. Skipping...
# Data for 5C41 already exists. Skipping...
# Data for 5C46 already exists. Skipping...
# Data for 5C47 already exists. Skipping...
# Data for 5C48 already exists. Skipping...
# Data for 5C49 already exists. Skipping...
# Data for 5C4B already exists. Skipping...
# Data for 5C4C already exists. Skipping...
# Data for 5C4D already exists. Skipping...
# Data for 5C4E already exists. Skipping...
# Data for 5C4F already exists. Skipping...
# Data for 5C4G already exists. Skipping...
# Data for 5C4M already exists. Skipping...
# Data for 5C4O already exists. Skipping...
# Data for 5C4S already exists. Skipping...
# Data for 5C4T already exists. Skipping...
# Data for 5C4U already exists. Skipping...
# Data for 5C4V already exists. Skipping...
# Data for 5C50 already exists. Skipping...
# Data for 5C51 already exists. Skipping...
# Data for 5C52 already exists. Skipping...
# Data for 5C53 already exists. Skipping...
# Data for 5C56 already exists. Skipping...
# Data for 5C5A already exists. Skipping...
# Data for 5C5B already exists. Skipping...
# Data for 5C5C already exists. Skipping...
# Data for 5C5P already exists. Skipping...
# Data for 5C5Q already exists. Skipping...
# Data for 5C5R already exists. Skipping...
# Data for 5C5S already exists. Skipping...
# Data for 5C5X already exists. Skipping...
# Data for 5C65 already exists. Skipping...
# Data for 5C67 already exists. Skipping...
# Data for 5C6C already exists. Skipping...
# Data for 5C6D already exists. Skipping...
# Data for 5C6H already exists. Skipping...
# Data for 5C6S already exists. Skipping...
# Data for 5C6T already exists. Skipping...
# Data for 5C6W already exists. Skipping...
# Data for 5C7A already exists. Skipping...
# Data for 5C7B already exists. Skipping...
# Data for 5C7C already exists. Skipping...
# Data for 5C7D already exists. Skipping...
# Data for 5C7G already exists. Skipping...
# Data for 5C7J already exists. Skipping...
# Data for 5C7K already exists. Skipping...
# Data for 5C7L already exists. Skipping...
# Data for 5C7M already exists. Skipping...
# Data for 5C7N already exists. Skipping...
# Data for 5C7O already exists. Skipping...
# Data for 5C7X already exists. Skipping...
# Data for 5C7Z already exists. Skipping...
# Data for 5C83 already exists. Skipping...
# Data for 5C84 already exists. Skipping...
# Data for 5C85 already exists. Skipping...
# Data for 5C87 already exists. Skipping...
# Data for 5C89 already exists. Skipping...
# Data for 5C8H already exists. Skipping...
# Data for 5C8I already exists. Skipping...
# Data for 5C8J already exists. Skipping...
# Data for 5C8K already exists. Skipping...
# Data for 5C8M already exists. Skipping...
# Data for 5C8N already exists. Skipping...
# Data for 5C8R already exists. Skipping...
# Data for 5C8W already exists. Skipping...
# Data for 5C91 already exists. Skipping...
# Data for 5C97 already exists. Skipping...
# Data for 5C9C already exists. Skipping...
# Data for 5C9J already exists. Skipping...
# Data for 5C9K already exists. Skipping...
# Data for 5C9N already exists. Skipping...
# Data for 5C9V already exists. Skipping...
# Data for 5C9Z already exists. Skipping...
# Data for 5CA2 already exists. Skipping...
# Data for 5CA7 already exists. Skipping...
# Data for 5CAC already exists. Skipping...
# Data for 5CAL already exists. Skipping...
# Data for 5CAN already exists. Skipping...
# Data for 5CAO already exists. Skipping...
# Data for 5CAP already exists. Skipping...
# Data for 5CAQ already exists. Skipping...
# Data for 5CAS already exists. Skipping...
# Data for 5CAU already exists. Skipping...
# Data for 5CAV already exists. Skipping...
# Data for 5CAW already exists. Skipping...
# Data for 5CAY already exists. Skipping...
# Data for 5CB1 already exists. Skipping...
# Data for 5CBA already exists. Skipping...
# Data for 5CBE already exists. Skipping...
# Data for 5CBL already exists. Skipping...
# Data for 5CBT already exists. Skipping...
# Data for 5CBU already exists. Skipping...
# Data for 5CBV already exists. Skipping...
# Data for 5CBW already exists. Skipping...
# Data for 5CC0 already exists. Skipping...
# Data for 5CC1 already exists. Skipping...
# Data for 5CCB already exists. Skipping...
# Data for 5CCK already exists. Skipping...
# Data for 5CCL already exists. Skipping...
# Data for 5CCM already exists. Skipping...
# Data for 5CCN already exists. Skipping...
# Data for 5CCQ already exists. Skipping...
# Data for 5CCR already exists. Skipping...
# Data for 5CCS already exists. Skipping...
# Data for 5CCW already exists. Skipping...
# Data for 5CCX already exists. Skipping...
# Data for 5CD1 already exists. Skipping...
# Data for 5CD3 already exists. Skipping...
# Data for 5CD5 already exists. Skipping...
# Data for 5CDB already exists. Skipping...
# Data for 5CDW already exists. Skipping...
# Data for 5CE1 already exists. Skipping...
# Data for 5CE4 already exists. Skipping...
# Data for 5CEH already exists. Skipping...
# Data for 5CEI already exists. Skipping...
# Data for 5CEK already exists. Skipping...
# Data for 5CEM already exists. Skipping...
# Data for 5CEN already exists. Skipping...
# Data for 5CEO already exists. Skipping...
# Data for 5CEP already exists. Skipping...
# Data for 5CEQ already exists. Skipping...
# Data for 5CEX already exists. Skipping...
# Data for 5CEY already exists. Skipping...
# Data for 5CEZ already exists. Skipping...
# Data for 5CF0 already exists. Skipping...
# Data for 5CF4 already exists. Skipping...
# Data for 5CF5 already exists. Skipping...
# Data for 5CF6 already exists. Skipping...
# Data for 5CF8 already exists. Skipping...
# Data for 5CFA already exists. Skipping...
# Data for 5CFB already exists. Skipping...
# Data for 5CFG already exists. Skipping...
# Data for 5CFH already exists. Skipping...
# Data for 5CFW already exists. Skipping...
# Data for 5CG5 already exists. Skipping...
# Data for 5CG6 already exists. Skipping...
# Data for 5CGC already exists. Skipping...
# Data for 5CGD already exists. Skipping...
# Data for 5CGP already exists. Skipping...
# Data for 5CGY already exists. Skipping...
# Data for 5CHG already exists. Skipping...
# Data for 5CHL already exists. Skipping...
# Data for 5CHN already exists. Skipping...
# Data for 5CHX already exists. Skipping...
# Data for 5CHZ already exists. Skipping...
# Data for 5CI7 already exists. Skipping...
# Data for 5CI8 already exists. Skipping...
# Data for 5CI9 already exists. Skipping...
# Data for 5CIL already exists. Skipping...
# Data for 5CIN already exists. Skipping...
# Data for 5CIP already exists. Skipping...
# Data for 5CIQ already exists. Skipping...
# Data for 5CIR already exists. Skipping...
# Data for 5CIT already exists. Skipping...
# Data for 5CIU already exists. Skipping...
# Data for 5CIW already exists. Skipping...
# Data for 5CJ0 already exists. Skipping...
# Data for 5CJ1 already exists. Skipping...
# Data for 5CJ2 already exists. Skipping...
# Data for 5CJ4 already exists. Skipping...
# Data for 5CJ6 already exists. Skipping...
# Data for 5CJ7 already exists. Skipping...
# Data for 5CJ8 already exists. Skipping...
# Data for 5CJB already exists. Skipping...
# Data for 5CJF already exists. Skipping...
# Data for 5CJO already exists. Skipping...
# Data for 5CJP already exists. Skipping...
# Data for 5CJQ already exists. Skipping...
# Data for 5CJS already exists. Skipping...
# Data for 5CJX already exists. Skipping...
# Data for 5CKA already exists. Skipping...
# Data for 5CKG already exists. Skipping...
# Data for 5CKY already exists. Skipping...
# Data for 5CL1 already exists. Skipping...
# Data for 5CLL already exists. Skipping...
# Data for 5CLM already exists. Skipping...
# Data for 5CLP already exists. Skipping...
# Data for 5CLQ already exists. Skipping...
# Data for 5CLS already exists. Skipping...
# Data for 5CLT already exists. Skipping...
# Data for 5CLU already exists. Skipping...
# Data for 5CLW already exists. Skipping...
# Data for 5CLX already exists. Skipping...
# Data for 5CLY already exists. Skipping...
# Data for 5CLZ already exists. Skipping...
# Data for 5CM1 already exists. Skipping...
# Data for 5CM4 already exists. Skipping...
# Data for 5CMD already exists. Skipping...
# Data for 5CMF already exists. Skipping...
# Data for 5CMG already exists. Skipping...
# Data for 5CMH already exists. Skipping...
# Data for 5CMI already exists. Skipping...
# Data for 5CMJ already exists. Skipping...
# Data for 5CMM already exists. Skipping...
# Data for 5CMN already exists. Skipping...
# Data for 5CMP already exists. Skipping...
# Data for 5CMQ already exists. Skipping...
# Data for 5CMR already exists. Skipping...
# Data for 5CMX already exists. Skipping...
# Data for 5CN3 already exists. Skipping...
# Data for 5CNH already exists. Skipping...
# Data for 5CNI already exists. Skipping...
# Data for 5CNJ already exists. Skipping...
# Data for 5CNK already exists. Skipping...
# Data for 5CNM already exists. Skipping...
# Data for 5CNN already exists. Skipping...
# Data for 5CNO already exists. Skipping...
# Data for 5CNY already exists. Skipping...
# Data for 5CO0 already exists. Skipping...
# Data for 5CO2 already exists. Skipping...
# Data for 5CO6 already exists. Skipping...
# Data for 5CO9 already exists. Skipping...
# Data for 5COC already exists. Skipping...
# Data for 5COE already exists. Skipping...
# Data for 5COI already exists. Skipping...
# Data for 5COR already exists. Skipping...
# Data for 5COY already exists. Skipping...
# Data for 5CP2 already exists. Skipping...
# Data for 5CP5 already exists. Skipping...
# Data for 5CP9 already exists. Skipping...
# Data for 5CPE already exists. Skipping...
# Data for 5CPI already exists. Skipping...
# Data for 5CPJ already exists. Skipping...
# Data for 5CPK already exists. Skipping...
# Data for 5CPR already exists. Skipping...
# Data for 5CQ2 already exists. Skipping...
# Data for 5CQ3 already exists. Skipping...
# Data for 5CQ4 already exists. Skipping...
# Data for 5CQ5 already exists. Skipping...
# Data for 5CQ6 already exists. Skipping...
# Data for 5CQ7 already exists. Skipping...
# Data for 5CQ8 already exists. Skipping...
# Data for 5CQA already exists. Skipping...
# Data for 5CQD already exists. Skipping...
# Data for 5CQH already exists. Skipping...
# Data for 5CQI already exists. Skipping...
# Data for 5CQK already exists. Skipping...
# Data for 5CQL already exists. Skipping...
# Data for 5CQM already exists. Skipping...
# Data for 5CQN already exists. Skipping...
# Data for 5CQO already exists. Skipping...
# Data for 5CQP already exists. Skipping...
# Data for 5CQR already exists. Skipping...
# Data for 5CQT already exists. Skipping...
# Data for 5CQU already exists. Skipping...
# Data for 5CQW already exists. Skipping...
# Data for 5CQZ already exists. Skipping...
# Data for 5CR0 already exists. Skipping...
# Data for 5CR1 already exists. Skipping...
# Data for 5CR5 already exists. Skipping...
# Data for 5CR7 already exists. Skipping...
# Data for 5CRA already exists. Skipping...
# Data for 5CRD already exists. Skipping...
# Data for 5CRE already exists. Skipping...
# Data for 5CRG already exists. Skipping...
# Data for 5CRH already exists. Skipping...
# Data for 5CRJ already exists. Skipping...
# Data for 5CRK already exists. Skipping...
# Data for 5CRM already exists. Skipping...
# Data for 5CRU already exists. Skipping...
# Data for 5CRV already exists. Skipping...
# Data for 5CRW already exists. Skipping...
# Data for 5CRZ already exists. Skipping...
# Data for 5CS1 already exists. Skipping...
# Data for 5CS3 already exists. Skipping...
# Data for 5CS5 already exists. Skipping...
# Data for 5CS6 already exists. Skipping...
# Data for 5CS7 already exists. Skipping...
# Data for 5CS8 already exists. Skipping...
# Data for 5CS9 already exists. Skipping...
# Data for 5CSB already exists. Skipping...
# Data for 5CSF already exists. Skipping...
# Data for 5CSG already exists. Skipping...
# Data for 5CSH already exists. Skipping...
# Data for 5CSI already exists. Skipping...
# Data for 5CSJ already exists. Skipping...
# Data for 5CSN already exists. Skipping...
# Data for 5CSP already exists. Skipping...
# Data for 5CSQ already exists. Skipping...
# Data for 5CSV already exists. Skipping...
# Data for 5CSW already exists. Skipping...
# Data for 5CSX already exists. Skipping...
# Data for 5CSZ already exists. Skipping...
# Data for 5CT0 already exists. Skipping...
# Data for 5CT1 already exists. Skipping...
# Data for 5CT2 already exists. Skipping...
# Data for 5CT3 already exists. Skipping...
# Data for 5CT7 already exists. Skipping...
# Data for 5CTD already exists. Skipping...
# Data for 5CTI already exists. Skipping...
# Data for 5CTL already exists. Skipping...
# Data for 5CTP already exists. Skipping...
# Data for 5CTQ already exists. Skipping...
# Data for 5CTR already exists. Skipping...
# Data for 5CTT already exists. Skipping...
# Data for 5CU0 already exists. Skipping...
# Data for 5CU2 already exists. Skipping...
# Data for 5CU3 already exists. Skipping...
# Data for 5CU4 already exists. Skipping...
# Data for 5CU5 already exists. Skipping...
# Data for 5CU6 already exists. Skipping...
# Data for 5CU8 already exists. Skipping...
# Data for 5CUA already exists. Skipping...
# Data for 5CUB already exists. Skipping...
# Data for 5CUC already exists. Skipping...
# Data for 5CUD already exists. Skipping...
# Data for 5CUE already exists. Skipping...
# Data for 5CUF already exists. Skipping...
# Data for 5CUG already exists. Skipping...
# Data for 5CUH already exists. Skipping...
# Data for 5CUI already exists. Skipping...
# Data for 5CUJ already exists. Skipping...
# Data for 5CUM already exists. Skipping...
# Data for 5CUS already exists. Skipping...
# Data for 5CUZ already exists. Skipping...
# Data for 5CV0 already exists. Skipping...
# Data for 5CVA already exists. Skipping...
# Data for 5CVB already exists. Skipping...
# Data for 5CVD already exists. Skipping...
# Data for 5CVE already exists. Skipping...
# Data for 5CVF already exists. Skipping...
# Data for 5CVG already exists. Skipping...
# Data for 5CVH already exists. Skipping...
# Data for 5CVL already exists. Skipping...
# Data for 5CVM already exists. Skipping...
# Data for 5CVN already exists. Skipping...
# Data for 5CVO already exists. Skipping...
# Data for 5CWR already exists. Skipping...
# Data for 5CWS already exists. Skipping...
# Data for 5CWZ already exists. Skipping...
# Data for 5CX3 already exists. Skipping...
# Data for 5CX9 already exists. Skipping...
# Data for 5CXA already exists. Skipping...
# Data for 5CXH already exists. Skipping...
# Data for 5CXV already exists. Skipping...
# Data for 5CXY already exists. Skipping...
# Data for 5CXZ already exists. Skipping...
# Data for 5CY3 already exists. Skipping...
# Data for 5CY9 already exists. Skipping...
# Data for 5CYH already exists. Skipping...
# Data for 5CYI already exists. Skipping...
# Data for 5CYJ already exists. Skipping...
# Data for 5CYO already exists. Skipping...
# Data for 5CYP already exists. Skipping...
# Data for 5CYS already exists. Skipping...
# Data for 5CZH already exists. Skipping...
# Data for 5CZI already exists. Skipping...
# Data for 5CZM already exists. Skipping...
# Data for 5CZR already exists. Skipping...
# Data for 5CZV already exists. Skipping...
# Data for 5CZX already exists. Skipping...
# Data for 5D0C already exists. Skipping...
# Data for 5D0I already exists. Skipping...
# Data for 5D0J already exists. Skipping...
# Data for 5D0K already exists. Skipping...
# Data for 5D0M already exists. Skipping...
# Data for 5D0R already exists. Skipping...
# Data for 5D14 already exists. Skipping...
# Data for 5D1B already exists. Skipping...
# Data for 5D1C already exists. Skipping...
# Data for 5D1D already exists. Skipping...
# Data for 5D1J already exists. Skipping...
# Data for 5D1K already exists. Skipping...
# Data for 5D1L already exists. Skipping...
# Data for 5D1M already exists. Skipping...
# Data for 5D1Q already exists. Skipping...
# Data for 5D1X already exists. Skipping...
# Data for 5D1Y already exists. Skipping...
# Data for 5D1Z already exists. Skipping...
# Data for 5D24 already exists. Skipping...
# Data for 5D25 already exists. Skipping...
# Data for 5D26 already exists. Skipping...
# Data for 5D27 already exists. Skipping...
# Data for 5D29 already exists. Skipping...
# Data for 5D2B already exists. Skipping...
# Data for 5D2D already exists. Skipping...
# Data for 5D2L already exists. Skipping...
# Data for 5D2M already exists. Skipping...
# Data for 5D2N already exists. Skipping...
# Data for 5D39 already exists. Skipping...
# Data for 5D3A already exists. Skipping...
# Data for 5D3C already exists. Skipping...
# Data for 5D3E already exists. Skipping...
# Data for 5D3F already exists. Skipping...
# Data for 5D3H already exists. Skipping...
# Data for 5D3J already exists. Skipping...
# Data for 5D3L already exists. Skipping...
# Data for 5D3N already exists. Skipping...
# Data for 5D3O already exists. Skipping...
# Data for 5D3P already exists. Skipping...
# Data for 5D3Q already exists. Skipping...
# Data for 5D3R already exists. Skipping...
# Data for 5D3S already exists. Skipping...
# Data for 5D3T already exists. Skipping...
# Data for 5D3V already exists. Skipping...
# Data for 5D3W already exists. Skipping...
# Data for 5D3X already exists. Skipping...
# Data for 5D3Y already exists. Skipping...
# Data for 5D41 already exists. Skipping...
# Data for 5D45 already exists. Skipping...
# Data for 5D47 already exists. Skipping...
# Data for 5D48 already exists. Skipping...
# Data for 5D4A already exists. Skipping...
# Data for 5D4K already exists. Skipping...
# Data for 5D4Q already exists. Skipping...
# Data for 5D5A already exists. Skipping...
# Data for 5D5B already exists. Skipping...
# Data for 5D5K already exists. Skipping...
# Data for 5D5M already exists. Skipping...
# Data for 5D5U already exists. Skipping...
# Data for 5D5V already exists. Skipping...
# Data for 5D5W already exists. Skipping...
# Data for 5D65 already exists. Skipping...
# Data for 5D67 already exists. Skipping...
# Data for 5D68 already exists. Skipping...
# Data for 5D69 already exists. Skipping...
# Data for 5D6B already exists. Skipping...
# Data for 5D6C already exists. Skipping...
# Data for 5D6D already exists. Skipping...
# Data for 5D6E already exists. Skipping...
# Data for 5D6F already exists. Skipping...
# Data for 5D6L already exists. Skipping...
# Data for 5D6W already exists. Skipping...
# Data for 5D6X already exists. Skipping...
# Data for 5D6Y already exists. Skipping...
# Data for 5D70 already exists. Skipping...
# Data for 5D71 already exists. Skipping...
# Data for 5D72 already exists. Skipping...
# Data for 5D75 already exists. Skipping...
# Data for 5D7A already exists. Skipping...
# Data for 5D7F already exists. Skipping...
# Data for 5D7G already exists. Skipping...
# Data for 5D7I already exists. Skipping...
# Data for 5D7J already exists. Skipping...
# Data for 5D7K already exists. Skipping...
# Data for 5D7L already exists. Skipping...
# Data for 5D7N already exists. Skipping...
# Data for 5D7O already exists. Skipping...
# Data for 5D7P already exists. Skipping...
# Data for 5D7Q already exists. Skipping...
# Data for 5D7S already exists. Skipping...
# Data for 5D7V already exists. Skipping...
# Data for 5D7X already exists. Skipping...
# Data for 5D8E already exists. Skipping...
# Data for 5D8F already exists. Skipping...
# Data for 5D8K already exists. Skipping...
# Data for 5D8L already exists. Skipping...
# Data for 5D94 already exists. Skipping...
# Data for 5D9G already exists. Skipping...
# Data for 5D9K already exists. Skipping...
# Data for 5D9L already exists. Skipping...
# Data for 5D9Q already exists. Skipping...
# Data for 5D9S already exists. Skipping...
# Data for 5D9Y already exists. Skipping...
# Data for 5DA3 already exists. Skipping...
# Data for 5DAB already exists. Skipping...
# Data for 5DAD already exists. Skipping...
# Data for 5DAF already exists. Skipping...
# Data for 5DAG already exists. Skipping...
# Data for 5DAH already exists. Skipping...
# Data for 5DAK already exists. Skipping...
# Data for 5DAL already exists. Skipping...
# Data for 5DB0 already exists. Skipping...
# Data for 5DB1 already exists. Skipping...
# Data for 5DB2 already exists. Skipping...
# Data for 5DB3 already exists. Skipping...
# Data for 5DB6 already exists. Skipping...
# Data for 5DB7 already exists. Skipping...
# Data for 5DB8 already exists. Skipping...
# Data for 5DB9 already exists. Skipping...
# Data for 5DBA already exists. Skipping...
# Data for 5DBB already exists. Skipping...
# Data for 5DBC already exists. Skipping...
# Data for 5DBM already exists. Skipping...
# Data for 5DBR already exists. Skipping...
# Data for 5DC0 already exists. Skipping...
# Data for 5DC4 already exists. Skipping...
# Data for 5DC5 already exists. Skipping...
# Data for 5DC6 already exists. Skipping...
# Data for 5DC7 already exists. Skipping...
# Data for 5DC8 already exists. Skipping...
# Data for 5DC9 already exists. Skipping...
# Data for 5DCG already exists. Skipping...
# Data for 5DCN already exists. Skipping...
# Data for 5DCP already exists. Skipping...
# Data for 5DCZ already exists. Skipping...
# Data for 5DD9 already exists. Skipping...
# Data for 5DDA already exists. Skipping...
# Data for 5DDB already exists. Skipping...
# Data for 5DDC already exists. Skipping...
# Data for 5DDD already exists. Skipping...
# Data for 5DDE already exists. Skipping...
# Data for 5DDF already exists. Skipping...
# Data for 5DDH already exists. Skipping...
# Data for 5DDL already exists. Skipping...
# Data for 5DDM already exists. Skipping...
# Data for 5DDO already exists. Skipping...
# Data for 5DDP already exists. Skipping...
# Data for 5DDQ already exists. Skipping...
# Data for 5DDR already exists. Skipping...
# Data for 5DDY already exists. Skipping...
# Data for 5DDZ already exists. Skipping...
# Data for 5DE1 already exists. Skipping...
# Data for 5DE2 already exists. Skipping...
# Data for 5DE5 already exists. Skipping...
# Data for 5DE8 already exists. Skipping...
# Data for 5DEA already exists. Skipping...
# Data for 5DEF already exists. Skipping...
# Data for 5DEG already exists. Skipping...
# Data for 5DEJ already exists. Skipping...
# Data for 5DET already exists. Skipping...
# Data for 5DEU already exists. Skipping...
# Data for 5DEW already exists. Skipping...
# Data for 5DEY already exists. Skipping...
# Data for 5DF6 already exists. Skipping...
# Data for 5DFB already exists. Skipping...
# Data for 5DFC already exists. Skipping...
# Data for 5DFD already exists. Skipping...
# Data for 5DFF already exists. Skipping...
# Data for 5DFH already exists. Skipping...
# Data for 5DFI already exists. Skipping...
# Data for 5DFJ already exists. Skipping...
# Data for 5DFL already exists. Skipping...
# Data for 5DFP already exists. Skipping...
# Data for 5DFT already exists. Skipping...
# Data for 5DFV already exists. Skipping...
# Data for 5DFW already exists. Skipping...
# Data for 5DG0 already exists. Skipping...
# Data for 5DG1 already exists. Skipping...
# Data for 5DG2 already exists. Skipping...
# Data for 5DG4 already exists. Skipping...
# Data for 5DG5 already exists. Skipping...
# Data for 5DG7 already exists. Skipping...
# Data for 5DG8 already exists. Skipping...
# Data for 5DG9 already exists. Skipping...
# Data for 5DGA already exists. Skipping...
# Data for 5DGB already exists. Skipping...
# Data for 5DGH already exists. Skipping...
# Data for 5DGI already exists. Skipping...
# Data for 5DGM already exists. Skipping...
# Data for 5DGN already exists. Skipping...
# Data for 5DGO already exists. Skipping...
# Data for 5DGS already exists. Skipping...
# Data for 5DGY already exists. Skipping...
# Data for 5DGZ already exists. Skipping...
# Data for 5DH3 already exists. Skipping...
# Data for 5DH4 already exists. Skipping...
# Data for 5DH5 already exists. Skipping...
# Data for 5DH9 already exists. Skipping...
# Data for 5DHA already exists. Skipping...
# Data for 5DHF already exists. Skipping...
# Data for 5DHG already exists. Skipping...
# Data for 5DHH already exists. Skipping...
# Data for 5DHJ already exists. Skipping...
# Data for 5DI1 already exists. Skipping...
# Data for 5DI7 already exists. Skipping...
# Data for 5DI8 already exists. Skipping...
# Data for 5DI9 already exists. Skipping...
# Data for 5DIA already exists. Skipping...
# Data for 5DID already exists. Skipping...
# Data for 5DIE already exists. Skipping...
# Data for 5DIF already exists. Skipping...
# Data for 5DIG already exists. Skipping...
# Data for 5DIN already exists. Skipping...
# Data for 5DIQ already exists. Skipping...
# Data for 5DIS already exists. Skipping...
# Data for 5DIT already exists. Skipping...
# Data for 5DIU already exists. Skipping...
# Data for 5DIV already exists. Skipping...
# Data for 5DIY already exists. Skipping...
# Data for 5DJ0 already exists. Skipping...
# Data for 5DJ2 already exists. Skipping...
# Data for 5DJ4 already exists. Skipping...
# Data for 5DJ6 already exists. Skipping...
# Data for 5DJ8 already exists. Skipping...
# Data for 5DJA already exists. Skipping...
# Data for 5DJC already exists. Skipping...
# Data for 5DJD already exists. Skipping...
# Data for 5DJL already exists. Skipping...
# Data for 5DJM already exists. Skipping...
# Data for 5DJP already exists. Skipping...
# Data for 5DJR already exists. Skipping...
# Data for 5DJV already exists. Skipping...
# Data for 5DJX already exists. Skipping...
# Data for 5DJY already exists. Skipping...
# Data for 5DJZ already exists. Skipping...
# Data for 5DK0 already exists. Skipping...
# Data for 5DK2 already exists. Skipping...
# Data for 5DK3 already exists. Skipping...
# Data for 5DK8 already exists. Skipping...
# Data for 5DK9 already exists. Skipping...
# Data for 5DKA already exists. Skipping...
# Data for 5DKB already exists. Skipping...
# Data for 5DKC already exists. Skipping...
# Data for 5DKD already exists. Skipping...
# Data for 5DKE already exists. Skipping...
# Data for 5DKG already exists. Skipping...
# Data for 5DKH already exists. Skipping...
# Data for 5DKS already exists. Skipping...
# Data for 5DKW already exists. Skipping...
# Data for 5DL4 already exists. Skipping...
# Data for 5DLF already exists. Skipping...
# Data for 5DLG already exists. Skipping...
# Data for 5DLI already exists. Skipping...
# Data for 5DLQ already exists. Skipping...
# Data for 5DLR already exists. Skipping...
# Data for 5DLS already exists. Skipping...
# Data for 5DLX already exists. Skipping...
# Data for 5DLZ already exists. Skipping...
# Data for 5DMC already exists. Skipping...
# Data for 5DMF already exists. Skipping...
# Data for 5DMG already exists. Skipping...
# Data for 5DMI already exists. Skipping...
# Data for 5DMJ already exists. Skipping...
# Data for 5DMZ already exists. Skipping...
# Data for 5DN2 already exists. Skipping...
# Data for 5DN3 already exists. Skipping...
# Data for 5DNF already exists. Skipping...
# Data for 5DNR already exists. Skipping...
# Data for 5DO4 already exists. Skipping...
# Data for 5DO7 already exists. Skipping...
# Data for 5DO9 already exists. Skipping...
# Data for 5DOG already exists. Skipping...
# Data for 5DOH already exists. Skipping...
# Data for 5DOS already exists. Skipping...
# Data for 5DOT already exists. Skipping...
# Data for 5DOU already exists. Skipping...
# Data for 5DOW already exists. Skipping...
# Data for 5DP0 already exists. Skipping...
# Data for 5DPQ already exists. Skipping...
# Data for 5DPR already exists. Skipping...
# Data for 5DPS already exists. Skipping...
# Data for 5DPT already exists. Skipping...
# Data for 5DPV already exists. Skipping...
# Data for 5DPW already exists. Skipping...
# Data for 5DQ0 already exists. Skipping...
# Data for 5DQ8 already exists. Skipping...
# Data for 5DQC already exists. Skipping...
# Data for 5DQE already exists. Skipping...
# Data for 5DQG already exists. Skipping...
# Data for 5DQH already exists. Skipping...
# Data for 5DQI already exists. Skipping...
# Data for 5DQO already exists. Skipping...
# Data for 5DQS already exists. Skipping...
# Data for 5DQY already exists. Skipping...
# Data for 5DR2 already exists. Skipping...
# Data for 5DR5 already exists. Skipping...
# Data for 5DR6 already exists. Skipping...
# Data for 5DR9 already exists. Skipping...
# Data for 5DRD already exists. Skipping...
# Data for 5DRJ already exists. Skipping...
# Data for 5DRM already exists. Skipping...
# Data for 5DRS already exists. Skipping...
# Data for 5DRT already exists. Skipping...
# Data for 5DRV already exists. Skipping...
# Data for 5DRW already exists. Skipping...
# Data for 5DRX already exists. Skipping...
# Data for 5DRY already exists. Skipping...
# Data for 5DRZ already exists. Skipping...
# Data for 5DS3 already exists. Skipping...
# Data for 5DSE already exists. Skipping...
# Data for 5DSG already exists. Skipping...
# Data for 5DSH already exists. Skipping...
# Data for 5DSK already exists. Skipping...
# Data for 5DSL already exists. Skipping...
# Data for 5DSM already exists. Skipping...
# Data for 5DSO already exists. Skipping...
# Data for 5DSP already exists. Skipping...
# Data for 5DSQ already exists. Skipping...
# Data for 5DSR already exists. Skipping...
# ...
# Data for 8TP3 already exists. Skipping...
# Data for 8TP4 already exists. Skipping...
# Data for 8TP5 already exists. Skipping...
# Data for 8TP6 already exists. Skipping...
# Data for 8TP7 already exists. Skipping...
# Data for 8TP9 already exists. Skipping...
# Data for 8TPA already exists. Skipping...
# Data for 8TQO already exists. Skipping...
# Data for 8TQZ already exists. Skipping...
# Data for 8TRE already exists. Skipping...
# Data for 8TRS already exists. Skipping...
# Data for 8TRT already exists. Skipping...
# Data for 8TS5 already exists. Skipping...
# Data for 8TS7 already exists. Skipping...
# Data for 8TS8 already exists. Skipping...
# Data for 8TS9 already exists. Skipping...
# Data for 8TSA already exists. Skipping...
# Data for 8TSB already exists. Skipping...
# Data for 8TSC already exists. Skipping...
# Data for 8TSD already exists. Skipping...
# Data for 8TTB already exists. Skipping...
# Data for 8TTW already exists. Skipping...
# Data for 8TU6 already exists. Skipping...
# Data for 8TU9 already exists. Skipping...
# Data for 8TUC already exists. Skipping...
# Data for 8TUI already exists. Skipping...
# Data for 8TUL already exists. Skipping...
# Data for 8TUP already exists. Skipping...
# Data for 8TWE already exists. Skipping...
# Data for 8TWI already exists. Skipping...
# Data for 8TXE already exists. Skipping...
# Data for 8TXG already exists. Skipping...
# Data for 8TXH already exists. Skipping...
# Data for 8TXV already exists. Skipping...
# Data for 8TXW already exists. Skipping...
# Data for 8TXX already exists. Skipping...
# Data for 8TXY already exists. Skipping...
# Data for 8TXZ already exists. Skipping...
# Data for 8TY1 already exists. Skipping...
# Data for 8TYP already exists. Skipping...
# Data for 8TYQ already exists. Skipping...
# Data for 8TZB already exists. Skipping...
# Data for 8TZC already exists. Skipping...
# Data for 8TZE already exists. Skipping...
# Data for 8TZF already exists. Skipping...
# Data for 8TZG already exists. Skipping...
# Data for 8TZH already exists. Skipping...
# Data for 8TZO already exists. Skipping...
# Data for 8TZP already exists. Skipping...
# Data for 8TZR already exists. Skipping...
# Data for 8TZS already exists. Skipping...
# Data for 8U13 already exists. Skipping...
# Data for 8U14 already exists. Skipping...
# Data for 8U15 already exists. Skipping...
# Data for 8U16 already exists. Skipping...
# Data for 8U17 already exists. Skipping...
# Data for 8U1E already exists. Skipping...
# Data for 8U1F already exists. Skipping...
# Data for 8U1U already exists. Skipping...
# Data for 8U1X already exists. Skipping...
# Data for 8U26 already exists. Skipping...
# Data for 8U27 already exists. Skipping...
# Data for 8U2C already exists. Skipping...
# Data for 8U2D already exists. Skipping...
# Data for 8U2E already exists. Skipping...
# Data for 8U37 already exists. Skipping...
# Data for 8U4U already exists. Skipping...
# Data for 8U4V already exists. Skipping...
# Data for 8U5B already exists. Skipping...
# Data for 8U5G already exists. Skipping...
# Data for 8U5M already exists. Skipping...
# Data for 8U5Y already exists. Skipping...
# Data for 8U61 already exists. Skipping...
# Data for 8U7E already exists. Skipping...
# Data for 8U7H already exists. Skipping...
# Data for 8U7L already exists. Skipping...
# Data for 8U7M already exists. Skipping...
# Data for 8U7Q already exists. Skipping...
# Data for 8U7V already exists. Skipping...
# Data for 8U7W already exists. Skipping...
# Data for 8U7X already exists. Skipping...
# Data for 8U7Z already exists. Skipping...
# Data for 8U80 already exists. Skipping...
# Data for 8U81 already exists. Skipping...
# Data for 8U82 already exists. Skipping...
# Data for 8U83 already exists. Skipping...
# Data for 8U84 already exists. Skipping...
# Data for 8U89 already exists. Skipping...
# Data for 8U8A already exists. Skipping...
# Data for 8U8B already exists. Skipping...
# Data for 8U8O already exists. Skipping...
# Data for 8U8Y already exists. Skipping...
# Data for 8U9G already exists. Skipping...
# Data for 8UAC already exists. Skipping...
# Data for 8UAK already exists. Skipping...
# Data for 8UAP already exists. Skipping...
# Data for 8UAQ already exists. Skipping...
# Data for 8UBR already exists. Skipping...
# Data for 8UC6 already exists. Skipping...
# Data for 8UC9 already exists. Skipping...
# Data for 8UCD already exists. Skipping...
# Data for 8UD9 already exists. Skipping...
# Data for 8UDG already exists. Skipping...
# Data for 8UDT already exists. Skipping...
# Data for 8UDU already exists. Skipping...
# Data for 8UDV already exists. Skipping...
# Data for 8UF2 already exists. Skipping...
# Data for 8UF7 already exists. Skipping...
# Data for 8UFB already exists. Skipping...
# Data for 8UFC already exists. Skipping...
# Data for 8UG1 already exists. Skipping...
# Data for 8UG3 already exists. Skipping...
# Data for 8UH0 already exists. Skipping...
# Data for 8UHB already exists. Skipping...
# Data for 8UJY already exists. Skipping...
# Data for 8UN3 already exists. Skipping...
# Data for 8UN4 already exists. Skipping...
# Data for 8UN5 already exists. Skipping...
# Data for 8UPF already exists. Skipping...
# Data for 8UQ2 already exists. Skipping...
# Data for 8UQ3 already exists. Skipping...
# Data for 8UQ4 already exists. Skipping...
# Data for 8UQ5 already exists. Skipping...
# Data for 8UQ8 already exists. Skipping...
# Data for 8UQ9 already exists. Skipping...
# Data for 8UQA already exists. Skipping...
# Data for 8UQB already exists. Skipping...
# Data for 8UQC already exists. Skipping...
# Data for 8UQD already exists. Skipping...
# Data for 8UQE already exists. Skipping...
# Data for 8UQN already exists. Skipping...
# Data for 8UQO already exists. Skipping...
# Data for 8UQR already exists. Skipping...
# Data for 8UT1 already exists. Skipping...
# Data for 8UTB already exists. Skipping...
# Data for 8UV0 already exists. Skipping...
# Data for 8UW3 already exists. Skipping...
# Data for 8UWP already exists. Skipping...
# Data for 8UX1 already exists. Skipping...
# Data for 8UXC already exists. Skipping...
# Data for 8UXE already exists. Skipping...
# Data for 8UXF already exists. Skipping...
# Data for 8UXG already exists. Skipping...
# Data for 8UXH already exists. Skipping...
# Data for 8UXI already exists. Skipping...
# Data for 8UXL already exists. Skipping...
# Data for 8UXM already exists. Skipping...
# Data for 8UZJ already exists. Skipping...
# Data for 8V04 already exists. Skipping...
# Data for 8V15 already exists. Skipping...
# Data for 8V1F already exists. Skipping...
# Data for 8V1L already exists. Skipping...
# Data for 8V1P already exists. Skipping...
# Data for 8V2I already exists. Skipping...
# Data for 8V2N already exists. Skipping...
# Data for 8V80 already exists. Skipping...
# Data for 8V82 already exists. Skipping...
# Data for 8V86 already exists. Skipping...
# Data for 8V88 already exists. Skipping...
# Data for 8V89 already exists. Skipping...
# Data for 8V8A already exists. Skipping...
# Data for 8V8C already exists. Skipping...
# Data for 8V8D already exists. Skipping...
# Data for 8V9U already exists. Skipping...
# Data for 8VE0 already exists. Skipping...
# Data for 8VFU already exists. Skipping...
# Data for 8VG3 already exists. Skipping...
# Data for 8VIS already exists. Skipping...
# Data for 8VKO already exists. Skipping...
# Data for 8VKP already exists. Skipping...
# Data for 8VKZ already exists. Skipping...
# Data for 8VL7 already exists. Skipping...
# Data for 8VQ3 already exists. Skipping...
# Data for 8VQ4 already exists. Skipping...
# Data for 8W1N already exists. Skipping...
# Data for 8W2W already exists. Skipping...
# Data for 8W41 already exists. Skipping...
# Data for 8W42 already exists. Skipping...
# Data for 8W43 already exists. Skipping...
# Data for 8W44 already exists. Skipping...
# Data for 8W45 already exists. Skipping...
# Data for 8W46 already exists. Skipping...
# Data for 8W47 already exists. Skipping...
# Data for 8W48 already exists. Skipping...
# Data for 8W4J already exists. Skipping...
# Data for 8W4Q already exists. Skipping...
# Data for 8W4R already exists. Skipping...
# Data for 8W4S already exists. Skipping...
# Data for 8W4T already exists. Skipping...
# Data for 8W4U already exists. Skipping...
# Data for 8W59 already exists. Skipping...
# Data for 8W5A already exists. Skipping...
# Data for 8W77 already exists. Skipping...
# Data for 8W83 already exists. Skipping...
# Data for 8W84 already exists. Skipping...
# Data for 8W85 already exists. Skipping...
# Data for 8W86 already exists. Skipping...
# Data for 8W87 already exists. Skipping...
# Data for 8W88 already exists. Skipping...
# Data for 8W89 already exists. Skipping...
# Data for 8W8A already exists. Skipping...
# Data for 8W8B already exists. Skipping...
# Data for 8W8Q already exists. Skipping...
# Data for 8W8R already exists. Skipping...
# Data for 8W8S already exists. Skipping...
# Data for 8W9W already exists. Skipping...
# Data for 8W9Y already exists. Skipping...
# Data for 8WA8 already exists. Skipping...
# Data for 8WA9 already exists. Skipping...
# Data for 8WAA already exists. Skipping...
# Data for 8WAK already exists. Skipping...
# Data for 8WAL already exists. Skipping...
# Data for 8WAN already exists. Skipping...
# Data for 8WAO already exists. Skipping...
# Data for 8WAP already exists. Skipping...
# Data for 8WAQ already exists. Skipping...
# Data for 8WAR already exists. Skipping...
# Data for 8WAS already exists. Skipping...
# Data for 8WAT already exists. Skipping...
# Data for 8WAU already exists. Skipping...
# Data for 8WAV already exists. Skipping...
# Data for 8WAW already exists. Skipping...
# Data for 8WAX already exists. Skipping...
# Data for 8WAY already exists. Skipping...
# Data for 8WAZ already exists. Skipping...
# Data for 8WB0 already exists. Skipping...
# Data for 8WC3 already exists. Skipping...
# Data for 8WC4 already exists. Skipping...
# Data for 8WC5 already exists. Skipping...
# Data for 8WC6 already exists. Skipping...
# Data for 8WC7 already exists. Skipping...
# Data for 8WC8 already exists. Skipping...
# Data for 8WC9 already exists. Skipping...
# Data for 8WCA already exists. Skipping...
# Data for 8WCB already exists. Skipping...
# Data for 8WD2 already exists. Skipping...
# Data for 8WD3 already exists. Skipping...
# Data for 8WD4 already exists. Skipping...
# Data for 8WDT already exists. Skipping...
# Data for 8WDX already exists. Skipping...
# Data for 8WE3 already exists. Skipping...
# Data for 8WE6 already exists. Skipping...
# Data for 8WE7 already exists. Skipping...
# Data for 8WE8 already exists. Skipping...
# Data for 8WE9 already exists. Skipping...
# Data for 8WEA already exists. Skipping...
# Data for 8WEJ already exists. Skipping...
# Data for 8WF4 already exists. Skipping...
# Data for 8WFE already exists. Skipping...
# Data for 8WFF already exists. Skipping...
# Data for 8WFG already exists. Skipping...
# Data for 8WFQ already exists. Skipping...
# Data for 8WFR already exists. Skipping...
# Data for 8WFY already exists. Skipping...
# Data for 8WG5 already exists. Skipping...
# Data for 8WGF already exists. Skipping...
# Data for 8WGV already exists. Skipping...
# Data for 8WGW already exists. Skipping...
# Data for 8WIU already exists. Skipping...
# Data for 8WJY already exists. Skipping...
# Data for 8WPG already exists. Skipping...
# Data for 8WPP already exists. Skipping...
# Data for 8WPU already exists. Skipping...
# Data for 8WQR already exists. Skipping...
# Data for 8WR5 already exists. Skipping...
# Data for 8WR8 already exists. Skipping...
# Data for 8WRA already exists. Skipping...
# Data for 8WRB already exists. Skipping...
# Data for 8WRH already exists. Skipping...
# Data for 8WRL already exists. Skipping...
# Data for 8WRM already exists. Skipping...
# Data for 8WRO already exists. Skipping...
# Data for 8WRZ already exists. Skipping...
# Data for 8WSM already exists. Skipping...
# Data for 8WSQ already exists. Skipping...
# Data for 8WSW already exists. Skipping...
# Data for 8WTD already exists. Skipping...
# Data for 8WTF already exists. Skipping...
# Data for 8WTJ already exists. Skipping...
# Data for 8WU8 already exists. Skipping...
# Data for 8WUA already exists. Skipping...
# Data for 8WUG already exists. Skipping...
# Data for 8WUY already exists. Skipping...
# Data for 8WW2 already exists. Skipping...
# Data for 8WWX already exists. Skipping...
# Data for 8WX2 already exists. Skipping...
# Data for 8WX3 already exists. Skipping...
# Data for 8WX4 already exists. Skipping...
# Data for 8WX5 already exists. Skipping...
# Data for 8WXY already exists. Skipping...
# Data for 8WY3 already exists. Skipping...
# Data for 8WY7 already exists. Skipping...
# Data for 8WYG already exists. Skipping...
# Data for 8WZD already exists. Skipping...
# Data for 8X0T already exists. Skipping...
# Data for 8X1V already exists. Skipping...
# Data for 8X23 already exists. Skipping...
# Data for 8X2A already exists. Skipping...
# Data for 8X2L already exists. Skipping...
# Data for 8X2P already exists. Skipping...
# Data for 8X2Q already exists. Skipping...
# Data for 8X2R already exists. Skipping...
# Data for 8X2S already exists. Skipping...
# Data for 8X2T already exists. Skipping...
# Data for 8X34 already exists. Skipping...
# Data for 8X43 already exists. Skipping...
# Data for 8X4F already exists. Skipping...
# Data for 8X5J already exists. Skipping...
# Data for 8X5K already exists. Skipping...
# Data for 8X5L already exists. Skipping...
# Data for 8X5M already exists. Skipping...
# Data for 8X5X already exists. Skipping...
# Data for 8X5Y already exists. Skipping...
# Data for 8X5Z already exists. Skipping...
# Data for 8X63 already exists. Skipping...
# Data for 8X64 already exists. Skipping...
# Data for 8X6P already exists. Skipping...
# Data for 8X6R already exists. Skipping...
# Data for 8X70 already exists. Skipping...
# Data for 8X72 already exists. Skipping...
# Data for 8X87 already exists. Skipping...
# Data for 8X88 already exists. Skipping...
# Data for 8XAM already exists. Skipping...
# Data for 8XB9 already exists. Skipping...
# Data for 8XBH already exists. Skipping...
# Data for 8XBI already exists. Skipping...
# Data for 8XEJ already exists. Skipping...
# Data for 8XFL already exists. Skipping...
# Data for 8XFM already exists. Skipping...
# Data for 8XJ0 already exists. Skipping...
# Data for 8XJ4 already exists. Skipping...
# Data for 8XJK already exists. Skipping...
# Data for 8XJL already exists. Skipping...
# Data for 8XJM already exists. Skipping...
# Data for 8XJN already exists. Skipping...
# Data for 8XJO already exists. Skipping...
# Data for 8XOX already exists. Skipping...
# Data for 8XOY already exists. Skipping...
# Data for 8XPT already exists. Skipping...
# Data for 8XPV already exists. Skipping...
# Data for 8XPZ already exists. Skipping...
# Data for 8XU4 already exists. Skipping...
# Data for 8XU5 already exists. Skipping...
# Data for 8Y0W already exists. Skipping...
# Data for 8Y0X already exists. Skipping...
# Data for 8Y4Z already exists. Skipping...
# Data for 8Y6B already exists. Skipping...
# Data for 8YA8 already exists. Skipping...
# Data for 966C already exists. Skipping...
# Data for 9API already exists. Skipping...
# Data for 9CA2 already exists. Skipping...
# Data for 9GSS already exists. Skipping...
# Data for 9ICA already exists. Skipping...
# Data for 9ICB already exists. Skipping...
# Data for 9ICC already exists. Skipping...
# Data for 9ICE already exists. Skipping...
# Data for 9ICF already exists. Skipping...
# Data for 9ICG already exists. Skipping...
# Data for 9ICH already exists. Skipping...
# Data for 9ICI already exists. Skipping...
# Data for 9ICJ already exists. Skipping...
# Data for 9ICK already exists. Skipping...
# Data for 9ICL already exists. Skipping...
# Data for 9ICM already exists. Skipping...
# Data for 9ICN already exists. Skipping...
# Data for 9ICO already exists. Skipping...
# Data for 9ICP already exists. Skipping...
# Data for 9ICQ already exists. Skipping...
# Data for 9ICR already exists. Skipping...
# Data for 9ICS already exists. Skipping...
# Data for 9ICT already exists. Skipping...
# Data for 9ICU already exists. Skipping...
# Data for 9ICV already exists. Skipping...
# Data for 9ICW already exists. Skipping...
# Data for 9ICX already exists. Skipping...
# Data for 9ICY already exists. Skipping...
# Data for 9ILB already exists. Skipping...
# Data for 9JDW already exists. Skipping...
# Data for 9PAI already exists. Skipping...
# Finished fetching data for all protein entry IDs.
